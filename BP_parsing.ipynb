# %% [markdown]
# # Make Corpus

# %%
import numpy as np; import pandas as pd
import pickle
from collections import defaultdict

raw = pickle.load(open('for_hyunse_re.pickle', 'rb'))

# 하나의 채널에 대한 데이터이고 Count가 지시하는 바가 동영상의 개수임
# Items는 결국 길이를 Count만큼 갖는 리스트가 되겠음.

# %%
re = []; rere = []
for item in raw: # 8개의 동영상에 대해서 돌게 됨
    for indiv_com in item['CommentThreads']: # 개별 댓글에 대해 돎
        if type(indiv_com) is dict:
            re.append(indiv_com['comment']['tidyed_text']) # comment는 댓글 관련 정보
            for rerep in indiv_com['replies']: # replies는 댓글 내의 대댓글 관련 정보쓰..
                rere.append(rerep['tidyed_text'])

# %%
total_replies = re + rere

# %%
len(total_replies)
# Out:
# 529134

# %%
import re
hangul = re.compile('[^ ㄱ-ㅣ가-힣.'']+') # # 한글과 띄어쓰기 . ''""를 제외한 모든 글자

final_total =[]
for comments in total_replies:
    final_total.append(hangul.sub('', comments)) # 한글과 띄어쓰기를 제외한 모든 글자 제외

# %% [markdown]
# # Cohesion Probability

# %%
class CohesionProbability: # 김현중 님 코드 그대로 복붙
    def __init__(self, left_min_length=1, left_max_length=10, right_min_length=1, right_max_length=6):

        self.left_min_length = left_min_length
        self.left_max_length = left_max_length
        self.right_min_length = right_min_length
        self.right_max_length = right_max_length

        self.L = defaultdict(int)
        self.R = defaultdict(int)

    def get_cohesion_probability(self, word):

        if not word:
            return (0, 0, 0, 0)

        word_len = len(word)

        l_freq = 0 if not word in self.L else self.L[word]
        r_freq = 0 if not word in self.R else self.R[word]

        if word_len == 1:
            return (0, 0, l_freq, r_freq)

        l_cohesion = 0
        r_cohesion = 0

        # forward cohesion probability (L)
        if (self.left_min_length <= word_len) and (word_len <= self.left_max_length):

            l_sub = word[:self.left_min_length]
            l_sub_freq = 0 if not l_sub in self.L else self.L[l_sub]

            if l_sub_freq > 0:
                l_cohesion = np.power((l_freq / float(l_sub_freq)), (1 / (word_len - len(l_sub) + 1.0)))

        # backward cohesion probability (R)
        if (self.right_min_length <= word_len) and (word_len <= self.right_max_length):

            r_sub = word[-1 * self.right_min_length:]
            r_sub_freq = 0 if not r_sub in self.R else self.R[r_sub]

            if r_sub_freq > 0:
                r_cohesion = np.power((r_freq / float(r_sub_freq)), (1 / (word_len - len(r_sub) + 1.0)))

        return (l_cohesion, r_cohesion, l_freq, r_freq)

    def get_all_cohesion_probabilities(self):

        cp = {}
        words = set(self.L.keys())
        for word in self.R.keys():
            words.add(word)

        for word in words:
            cp[word] = self.get_cohesion_probability(word)

        return cp

    def counter_size(self):
        return (len(self.L), len(self.R))

    def prune_extreme_case(self, min_count):

        before_size = self.counter_size()
        self.L = defaultdict(int, {k: v for k, v in self.L.items() if v > min_count})
        self.R = defaultdict(int, {k: v for k, v in self.R.items() if v > min_count})
        after_size = self.counter_size()

        return (before_size, after_size)

    def train(self, sents, num_for_pruning=0, min_count=5):

        for num_sent, sent in enumerate(sents):
            for word in sent.split():

                if not word:
                    continue

                word_len = len(word)

                for i in range(self.left_min_length, min(self.left_max_length, word_len) + 1):
                    self.L[word[:i]] += 1

                # for i in range(self.right_min_length, min(self.right_max_length, word_len)+1):
                for i in range(self.right_min_length, min(self.right_max_length, word_len)):
                    self.R[word[-i:]] += 1

            if (num_for_pruning > 0) and ((num_sent + 1) % num_for_pruning == 0):
                self.prune_extreme_case(min_count)

        if (num_for_pruning > 0) and ((num_sent + 1) % num_for_pruning == 0):
            self.prune_extreme_case(min_count)

    def extract(self, min_count=5, min_cohesion=(0.05, 0), min_droprate=0.8, remove_subword=True):

        word_to_score = self.get_all_cohesion_probabilities()
        word_to_score = {word: score for word, score in word_to_score.items()
                         if (score[0] >= min_cohesion[0])
                         and (score[1] >= min_cohesion[1])
                         and (score[2] >= min_count)}

        if not remove_subword:
            return word_to_score

        words = {}

        for word, score in sorted(word_to_score.items(), key=lambda x: len(x[0])):
            len_word = len(word)
            if len_word <= 2:
                words[word] = score
                continue

            try:
                subword = word[:-1]
                subscore = self.get_cohesion_probability(subword)
                droprate = score[2] / subscore[2]

                if (droprate >= min_droprate) and (subword in words):
                    del words[subword]

                words[word] = score

            except:
                print(word, score, subscore)
                break

        return words

    def transform(self, docs, l_word_set):

        def left_match(word):
            for i in reversed(range(1, len(word) + 1)):
                if word[:i] in l_word_set:
                    return word[:i]
            return ''

        return [[left_match(word) for sent in doc.split('  ') for word in sent.split() if left_match(word)] for doc in
                docs]

    def load(self, fname):
        try:
            with open(fname, encoding='utf-8') as f:

                next(f)  # SKIP: parameters(left_min_length left_max_length ...
                token = next(f).split()
                self.left_min_length = int(token[0])
                self.left_max_length = int(token[1])
                self.right_min_length = int(token[2])
                self.right_max_length = int(token[3])

                next(f)  # SKIP: L count
                is_right_side = False

                for line in f:

                    if '# R count' in line:
                        is_right_side = True
                        continue

                    token = line.split('\t')
                    if is_right_side:
                        self.R[token[0]] = int(token[1])
                    else:
                        self.L[token[0]] = int(token[1])

        except Exception as e:
            print(e)

    def save(self, fname):
        try:
            with open(fname, 'w', encoding='utf-8') as f:

                f.write('# parameters(left_min_length left_max_length right_min_length right_max_length)\n')
                f.write('%d %d %d %d\n' % (
                self.left_min_length, self.left_max_length, self.right_min_length, self.right_max_length))

                f.write('# L count')
                for word, freq in self.L.items():
                    f.write('%s\t%d\n' % (word, freq))

                f.write('# R count')
                for word, freq in self.R.items():
                    f.write('%s\t%d\n' % (word, freq))

        except Exception as e:
            print(e)

    def words(self):
        words = set(self.L.keys())
        words = words.union(set(self.R.keys()))
        return words
      
      
class CohesionTokenizer:
    def __init__(self, cohesion):
        self.cohesion = cohesion
        self.range_l = cohesion.left_max_length

    def tokenize(self, sentence, max_ngram=4, length_penalty=-0.05, ngram=False, debug=False):

        def flatten(tokens):
            return [word for token in tokens for word in token]

        tokens = [self._recursive_tokenize(token, max_ngram, length_penalty, ngram, debug) for token in
                  sentence.split()]
        words = flatten(tokens)

        if not debug:
            tokens = [word if type(word) == str else word[0] for word in words]

        return tokens

    def _recursive_tokenize(self, token, max_ngram=4, length_penalty=-0.05, ngram=False, debug=False):

        length = len(token)
        if length <= 2:
            return [token]

        range_l = min(self.range_l, length)

        scores = self._initialize(token, range_l, length)
        if debug:
            pprint(scores)

        result = self._find(scores)

        adds = self._add_inter_subtokens(token, result)

        if result[-1][2] != length:
            adds += self._add_first_subtoken(token, result)

        if result[0][1] != 0:
            adds += self._add_last_subtoken(token, result)

        result = sorted(result + adds, key=lambda x: x[1])

        if ngram:
            result = self._extract_ngram(result, max_ngram, length_penalty)

        return result

    def _initialize(self, token, range_l, length):
        scores = []
        for b in range(0, length - 1):
            for r in range(2, range_l + 1):
                e = b + r

                if e > length:
                    continue

                subtoken = token[b:e]
                score = self.cohesion.get_cohesion_probability(subtoken)
                # (subtoken, begin, end, cohesion_l, frequency_l, range)
                scores.append((subtoken, b, e, score[0], score[2], r))

        return sorted(scores, key=lambda x: (x[3], x[5]), reverse=True)

    def _find(self, scores):
        result = []
        num_iter = 0

        while scores:
            word, b, e, cp_l, freq_l, r = scores.pop(0)
            result.append((word, b, e, cp_l, freq_l, r))

            if not scores:
                break

            removals = []
            for i, (_1, b_, e_, _2, _3, _4) in enumerate(scores):
                if (b_ < e and b < e_) or (b_ < e and e_ > b):
                    removals.append(i)

            for i in reversed(removals):
                del scores[i]

            num_iter += 1
            if num_iter > 100: break

        return sorted(result, key=lambda x: x[1])

    def _add_inter_subtokens(self, token, result):
        adds = []
        for i, base in enumerate(result[:-1]):
            if base[2] == result[i + 1][1]:
                continue

            b = base[2]
            e = result[i + 1][1]
            subtoken = token[b:e]
            adds.append((subtoken, b, e, 0, self.cohesion.L.get(subtoken, 0), e - b))

        return adds

    def _add_first_subtoken(self, token, result):
        b = result[-1][2]
        subtoken = token[b:]
        score = self.cohesion.get_cohesion_probability(subtoken)
        return [(subtoken, b, len(token), score[0], score[2], len(subtoken))]

    def _add_last_subtoken(self, token, result):
        e = result[0][1]
        subtoken = token[0:e]
        score = self.cohesion.get_cohesion_probability(subtoken)
        return [(subtoken, 0, e, score[0], score[2], e)]

    def _extract_ngram(self, words, max_ngram=4, length_penalty=-0.05):

        def ngram_average_score(words):
            words = [word for word in words if len(word) > 1]
            scores = [word[3] for word in words]
            return max(0, np.mean(scores) + length_penalty * len(scores))

        length = len(words)
        scores = []

        if length <= 1:
            return words

        for word in words:
            scores.append(word)

        for b in range(0, length - 1):
            for r in range(2, max_ngram + 1):
                e = b + r

                if e > length:
                    continue

                ngram = words[b:e]
                ngram_str = ''.join([word[0] for word in ngram])
                ngram_str_ = '-'.join([word[0] for word in ngram])

                ngram_freq = self.cohesion.L.get(ngram_str, 0)
                if ngram_freq == 0:
                    continue

                base_freq = min([word[4] for word in ngram])
                ngram_score = np.power(ngram_freq / base_freq, 1 / (r - 1)) if base_freq > 0 else 0
                ngram_score -= r * length_penalty

                scores.append((ngram_str_, words[b][1], words[e - 1][2], ngram_score, ngram_freq, 0))

        scores = sorted(scores, key=lambda x: x[3], reverse=True)
        return self._find(scores)

# %%
cohesion = CohesionProbability()
cohesion.train(total_replies)
cohesiontokenizer = CohesionTokenizer(cohesion)
cohesion_tokenized_reviews = [cohesiontokenizer.tokenize(i) for i in total_replies]

# %%
cohesion_tokenized_reviews
# Out:
# [['아', '개마싯갯다', 'ㄹㅇ'],
#  ['너불님',
#   '이',
#   '펩시',
#   '와',
#   '부먹',
#   '충인',
#   '걸',
#   '처음',
#   '알았습니다',
#   '..',
#   '..',
#   '..',
#   '오늘',
#   '구독',
#   '취소',
#   '눌렀',
#   '습니다',
#   '..',
#   '..',
#   '..',
#   '.',
#   '어이쿠',
#   '한번',
#   '더',
#   '눌렀',
#   '네'],
#  ['이', '영상', '을', '천성', '부먹', '멋사', '님께서', '좋아', '하', '십니다', '.'],
#  ['?', '?', '?', '?', '코카', '가', '더', '낫다', '코카', '일어나라', '!!', '!!'],
#  ['코카', '편', 'ㅡㅡ', 'ㅡ안'],
#  ['코카',
#   '콜라',
#   '넼',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ',
#   '펩시',
#   '파',
#   '소리',
#   '쥘러',
#   '!!',
#   '!!',
#   '!!',
#   '!'],
#  ['자장', '면이', '되게진해보인다', 'ㅋㅋ', '근데', '탕수육', '은', '먹음직~'],
#  ['코카',
#   '콜라',
#   '펩시',
#   '부먹',
#   '찍먹',
#   '이런',
#   '얘길',
#   '해야',
#   '돼나',
#   '난',
#   '너불님',
#   '이',
#   '먹는',
#   '게',
#   '너무',
#   '흐뭇해서',
#   '아무',
#   '생각',
#   '이',
#   '안',
#   '나는',
#   '데',
#   '안',
#   '뜨거',
#   '워요',
#   '나만',
#   '피식하고',
#   '웃었나',
#   '개',
#   '귀여',
#   '워',
#   'ㅋㅋ',
#   'ㅋ'],
#  ['부먹', '..', '..', '.', '펩시', '..', '.', '코카', ',', '찍먹', '찬양', '해라', '~~~~'],
#  ['너불님', '미안해요', '부먹', '이랑', '펩시', '소리', '듣고', '유튜브', '끌뻔했어'],
#  ['아', '..', '..', '..', '난', '찍먹', '에', '코카', '인데'],
#  ['부먹',
#   '파',
#   '찍먹',
#   '파',
#   '코카',
#   '파',
#   '펩시',
#   '파',
#   '다',
#   '필요',
#   '없어',
#   '난',
#   '처먹',
#   '파닷',
#   '!!',
#   '!'],
#  ['부먹', '펩시', '불편'],
#  ['코카',
#   '도',
#   '펩시',
#   '도',
#   '아닌자는',
#   '조용',
#   '먹느라',
#   '볼이',
#   '뜐뜐',
#   '한',
#   '너불님',
#   '을',
#   '보며',
#   '배고',
#   '파',
#   '하기'],
#  ['의도치', '않은', '부먹', '은', '불편', '하다', '..', '코카', '는', '좋음', '헿헤'],
#  ['펩시', '불', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ편'],
#  ['코카', '의', '저주'],
#  ['아',
#   '..',
#   '.',
#   '탕수육',
#   '먹고',
#   '싶었',
#   '는데',
#   '..',
#   '.',
#   '그리고',
#   '전',
#   '처먹',
#   '입니다',
#   '!'],
#  ['원래', '탄산', '음료', '딸때', '천천', '따면', '소리', '잘안나는거', '아님?'],
#  ['멋사', '님', '보시면', 'ㄹㅇ', '토론회열듯'],
#  ['코카',
#   '딸때',
#   '한번',
#   '에',
#   '세게',
#   '따야',
#   '되는',
#   '데',
#   '약하',
#   '고소',
#   '심하',
#   '게',
#   '따니깐',
#   '스스스윽',
#   '소리',
#   '나지',
#   '한번',
#   '에',
#   '따면',
#   '소리',
#   '개큼',
#   'ㅇㅈ',
#   '?'],
#  ['코카', '파', '앞에', '서', '코카', '콜라', '를', '욕하', '다니', '..', '.'],
#  ['부먹', '부울편'],
#  ['코카', '디스', '불', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ편'],
#  ['콜라',
#   '는',
#   '탄산',
#   '더',
#   '톡',
#   '쏘는',
#   '게',
#   '먹고',
#   '싶을때',
#   '먹고',
#   '펩시',
#   '는',
#   '덜',
#   '쏘고',
#   '좀',
#   '단게',
#   '먹고',
#   '싶을때',
#   '먹음',
#   '결론',
#   '혼종',
#   '솔직',
#   '머든',
#   '다',
#   '맛있',
#   '어',
#   '..'],
#  ['너불님',
#   '옛날',
#   '에',
#   '돼지',
#   '님이',
#   '랑',
#   '많이',
#   '합방했었었는데',
#   '요근래',
#   '.',
#   '년',
#   '동안',
#   'bj',
#   '돼지',
#   '님',
#   '재밌',
#   '게',
#   '봤는데',
#   '안보이길래',
#   '방송',
#   '에서',
#   '도',
#   '언급도',
#   '없으',
#   '셔서',
#   'bj',
#   '돼지',
#   '님',
#   '근황이',
#   '궁금',
#   '합니다'],
#  ['너불님', '펩시', '그', '젖같은거', '좋아', '하시', '나봄'],
#  ['부먹', '불편', '코카', '너무', '좋아', '요', '~~~~'],
#  ['코카',
#   '무엇',
#   '?',
#   '불',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   '편',
#   '하',
#   '네요',
#   '번째',
#   '좋아',
#   '요',
#   '내꺼',
#   'ㅎ'],
#  ['옆에', '코카', '무엇', '?', '불편'],
#  ['오자마자',
#   '부먹',
#   '이랑',
#   '코카',
#   '봤다',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '부먹',
#   '이',
#   '어서',
#   '오!했지만',
#   '코카',
#   '여서',
#   '아',
#   '..',
#   '..',
#   '했다',
#   'ㅋㅋ',
#   '펩시',
#   '파'],
#  ['생',
#   '방송',
#   '중력님',
#   '왈',
#   '봤죠?',
#   '코카',
#   '는',
#   '가만',
#   '있는',
#   '데',
#   '펩시',
#   '가',
#   '열등감',
#   '에',
#   '코카',
#   '보고',
#   '뭐라하는걸?',
#   '중국',
#   '집에',
#   '서',
#   '코카',
#   '를',
#   '주네',
#   '보통',
#   '비싸',
#   '서',
#   '펩시',
#   '주는',
#   '데',
#   '코카',
#   '주는',
#   '중국집',
#   '을',
#   '욕하',
#   '는건',
#   '그',
#   '중국',
#   '집에',
#   '대한',
#   '모독이에요'],
#  ['코카', '가', '어때서요', '!'],
#  ['코카', '가', '피식이면', '펩시', '는', ',,', ',,', '?', '소리', '도', '안', '나는', '것인가'],
#  ['코카', '가', '얼마', '나', '탄산', '이', '많은데요오', '!!'],
#  ['이게',
#   '탄산',
#   '음류냐?',
#   '!?',
#   '하시는',
#   '데',
#   '코카',
#   '콜라',
#   '가',
#   '탄산',
#   '이',
#   '더',
#   '많다는점',
#   '..',
#   '..',
#   'ㅋ',
#   '..',
#   '.글고',
#   '소리',
#   '가',
#   '세게',
#   '안나는거는',
#   '탄산',
#   '이',
#   '덜빠져나가는거아님?'],
#  ['부먹', '펩시', '파', '손'],
#  ['너불님',
#   '..',
#   '.',
#   '펩시',
#   '는',
#   '..',
#   '.',
#   '펩시',
#   '는',
#   '..',
#   '?',
#   '펩시',
#   '버린거야',
#   '..',
#   '?',
#   '펩시',
#   '의',
#   '원귀가',
#   '방송',
#   '중에',
#   '돌아다닐거라구',
#   '..',
#   '?'],
#  ['ㅎㅏ',
#   '!',
#   '어제',
#   '만쨩',
#   '방송',
#   '에서',
#   '코카',
#   '따는',
#   '소리',
#   '생각',
#   '안나시나요',
#   '!!',
#   '!!'],
#  ['저도',
#   '부먹',
#   '..',
#   '펩시',
#   '파',
#   '..',
#   '..',
#   '.',
#   '찍먹',
#   '은',
#   '탕수육',
#   '이',
#   '부먹',
#   '보다',
#   '딱딱해서',
#   '입안이',
#   '다칠때가',
#   '있어',
#   '서ㅠ',
#   '실화',
#   '펩시',
#   '랑',
#   '코카',
#   '랑',
#   '거기서',
#   '거기',
#   '이긴한데',
#   '..',
#   '.',
#   '뭔가',
#   '펩시',
#   '가',
#   '더',
#   '맛있',
#   '음',
#   '느낌',
#   '적인',
#   '느낌',
#   '..',
#   '..',
#   '제',
#   '생각',
#   '이니',
#   '뭐라고',
#   '하지',
#   '마세요',
#   'ㅠㅠ'],
#  ['오른쪽에', '탕수육', '부먹', '있으면', '불편', '하지', '않나요?', '손에', '묻을', '수도', '있고'],
#  ['이',
#   '영상',
#   '이',
#   '왜',
#   '노랑딱지야',
#   '유투브',
#   '검토하고',
#   '다시해줘라',
#   '우리',
#   '너불',
#   '이',
#   '못먹고산다',
#   '..',
#   '..',
#   '.'],
#  ['볼거', '없어', '서', '돌아', '다니', '고', '있는', '데', '딱!', '나와', '버리', '네', 'ㄱㅇㄷ'],
#  ['역시',
#   '나와',
#   '같은',
#   '부먹',
#   '펩시',
#   '파',
#   '..',
#   '.존경',
#   '합니다',
#   '너불',
#   '신',
#   '..',
#   '..'],
#  ['짬국', '짬뽕', '국물', '언제', '먹나', '기다렸', '다', 'ㅋㅋ', 'ㅋㅋ'],
#  ['탕짜면', '너무', '좋아', '여ㅓㅓㅓㅓㅓ', '짝짝', '짝짝', '짝짝'],
#  ['ㅋㅋ', 'ㅋ', '부먹', '에', '코카', 'ㅋㅋ', '펩시', '도', '아니', '곸', 'ㅋㅋ'],
#  ['님들그거암??',
#   '코카',
#   '콜라',
#   '탄산',
#   '이',
#   '너무',
#   '많아서',
#   '흔들',
#   '다음에',
#   '따면',
#   '핵폭탄급의위력임',
#   '하지만',
#   '펩시',
#   '는흔',
#   '들어',
#   '도콩알탄',
#   'ㅇㅈ',
#   'ㅇㅈ',
#   '?',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ'],
#  ['짬뽕',
#   '파',
#   '..',
#   '서운',
#   'ㅠㅠ',
#   'ㅠ',
#   '짬뽕',
#   '먹고',
#   '시프다ㅠ',
#   'ㅜㅜ',
#   '캠먹방',
#   '너무',
#   '조아요'],
#  ['핰',
#   '너불님',
#   '냠냠',
#   '얌',
#   '오물오물',
#   '드시',
#   '는거',
#   '귀여',
#   '우셔',
#   '너불님',
#   '이',
#   '드시',
#   '는거',
#   '보까',
#   '갑자기',
#   '짜장면',
#   '먹고',
#   '싶어',
#   '지네',
#   '짜장면',
#   '시켜야지',
#   '헤헤'],
#  ['방금',
#   '밥먹',
#   '고',
#   '왔는데',
#   '너불님',
#   '너무',
#   '맛있',
#   '게',
#   '먹어',
#   '서',
#   '배고',
#   '파진다',
#   '..',
#   '.'],
#  ['너불', '만쉐이', '~~', '펩시', '만쉐이', '~~', '늪지대', '만쉐이', '~~'],
#  ['부먹',
#   '펩시',
#   '는',
#   '가라',
#   '코카',
#   '찍먹',
#   '솨리질러',
#   '그',
#   '래도',
#   '시작',
#   '은',
#   '둘다',
#   '콜라',
#   '입니다'],
#  ['너불님', '안경뭐에요?'],
#  ['어제', '탕수육', '먹었는데', '담먹', '함ㅎ', '담먹', '아시져?ㅎ', 'ㅋㅋ'],
#  ['도대체',
#   '싫어',
#   '요',
#   '누구',
#   '야',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '싫어',
#   '요',
#   '하는',
#   '사람',
#   '너무',
#   '싫어',
#   '요'],
#  ['코카', '편', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', '안'],
#  ['코카', '보단', '펩시', '지'],
#  ['일부로', '늦게', '깟다'],
#  ['너불님',
#   '혼종',
#   '은',
#   '모두',
#   '와',
#   '친',
#   '합니다',
#   '부먹',
#   '도',
#   '찍먹',
#   '도',
#   '손',
#   '잡고',
#   '혼종',
#   '이',
#   '됩시다'],
#  ['코카',
#   '가',
#   '어때서요.',
#   '코카',
#   '파인',
#   '저로선',
#   '너불님',
#   '의',
#   '취향',
#   '을',
#   '존중하는데,',
#   '솔직',
#   '기분',
#   '뭐해요.',
#   '약간',
#   '껄끄럽달까.',
#   '불편'],
#  ['난', '타짱면', '말구', '짜탕면', '먹을', '래'],
#  ['펩시',
#   '도',
#   '맛있',
#   '고',
#   '코카',
#   '도',
#   '맛있',
#   '는데',
#   '난',
#   '갠적으로',
#   '사',
#   '먹으면',
#   '펩시',
#   '를',
#   '먹어',
#   '서',
#   '펩시',
#   '가',
#   '더',
#   '좋다',
#   'ㅎ',
#   '근데',
#   '너불님',
#   '너무',
#   '맛있',
#   '게드',
#   '셔서',
#   '배고',
#   '파졌다',
#   '..',
#   '..',
#   '.'],
#  ['아', '..', '.', '탕짜면', '나도', '먹고', '싶다', '..', '.', 'ㅎㅎ'],
#  ['펩시', '너무', '좋아', '여', 'from', '너불'],
#  ['코카', '콜라', '와', '펩시', '는', '똑같', '다', '내가', '먹었는데', '똑같', '해', '내', '주관임'],
#  ['그', '와중에', '뒤에', '있는', '카게야마', '갖고', '싶다', '..'],
#  ['자',
#   '안녕하세요',
#   '너불',
#   '인',
#   '데요',
#   '좋아',
#   '요와',
#   '구독',
#   '하기',
#   '부탁드릴게요',
#   '너무',
#   '좋아',
#   '요',
#   '!!',
#   '짝!짝!짝!'],
#  ['코,', '코카', '는', '사', '..', 'ㄹ', '..', 'ㅏㅇ', '..'],
#  ['나만', '찍먹', '에', '펩시', '냐'],
#  ['너불님', '먹방', '너무', '좋아', '요', '짝짝', '짝짝'],
#  ['부먹', '은', '펩시', '고', '찍먹', '은', '코카'],
#  ['구독',
#   '하',
#   '라고해서',
#   '했는데',
#   '..',
#   '.',
#   '취소',
#   '됐다',
#   '..',
#   '그래서',
#   '한번',
#   '더',
#   '눌렸네',
#   '..',
#   '자세보기'],
#  ['너불님', '너무', '좋아', '요', '~~~', '짝짝', '짝짝'],
#  ['코카', '부먹', '불', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ편'],
#  ['부먹', '불편', '코카', '편안'],
#  ['이거',
#   '남순',
#   '핑맨',
#   '만득',
#   '너불님',
#   '이렇게',
#   'gta',
#   '끝나고',
#   '핑맨',
#   '님이',
#   '사준',
#   '건가요?',
#   '뒤를',
#   '보다가',
#   '비싸다고',
#   '사라말라하가',
#   '자러가서',
#   '모르',
#   '겠다',
#   'ㅋㅋ',
#   'ㅋㅋ'],
#  ['짜장면', '을', '막', '비비비비비ㅣ비비ㅣㅣ', '비비비', 'ㅣㅂ벼', '그러', '면', '환상'],
#  ['펩시', '파라니', '..'],
#  ['헐', '옷', '너무', '예쁘다', '..', '너불님', '도', '예쁘다', '..', '.'],
#  ['코카', '콜라', '편', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ안', '부먹', '불', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', '편'],
#  ['이부분을', '멋사', '님과', '중력님', '이', '싫어', '합니다', '.'],
#  ['펩시',
#   '부먹',
#   '은',
#   '아무것도',
#   '몰라',
#   '서',
#   '이해',
#   '해야',
#   '함',
#   'ㅇㅈ',
#   'ㅇㅈ',
#   'ㅇㅈ',
#   'ㅇㅈ',
#   '?'],
#  ['귀요미.', '너불님', '은', '포동포동', '한게.', '제일', '.', '귀여', '웡', '!'],
#  ['Im', '혼종'],
#  ['헉',
#   '부먹',
#   '너모',
#   '조아',
#   '여',
#   '~~~~~~~~',
#   '부먹',
#   '코카',
#   '파는',
#   '어찌되는것입니까',
#   '..',
#   '.',
#   'ㅜㅜ',
#   'ㅜㅠ',
#   '흑흑',
#   '오늘',
#   '도',
#   '잘볼게요',
#   '감사합니다',
#   '!!'],
#  ['나는', '찍먹', '인디', '..', '..', '.'],
#  ['너불님', '예뻐요', '?', '!!', '!!', '!'],
#  ['부먹', '불편'],
#  ['처음',
#   '부터',
#   '말',
#   '빠르',
#   '셔서',
#   '랩하',
#   '시는줄',
#   'ㅋㅋ',
#   'ㄱㅋ',
#   '그',
#   '래도',
#   '귀여',
#   '우시',
#   '다'],
#  ['부먹',
#   '코카',
#   '너어뮤',
#   '좋아',
#   '여',
#   '~~',
#   '짝짝',
#   '짝짝',
#   '짝',
#   '저는',
#   '찍먹',
#   '펩시',
#   '입니다',
#   '.'],
#  ['졸귀'],
#  ['비벼', '미친', '듯이', '비벼', '!!'],
#  ['맜있', '게', '드세요'],
#  ['아', '점심', '으로', '탕짜면', '먹을', '껄', '이미먹었다', 'ㅠㅠ'],
#  ['짜장면', '을', '파스타', '뺨치게', '먹는', '너불', '짜응', '꾸요', '워'],
#  ['탕수육', '은', '찍이요~', '콜라', '는', '코카', '요~'],
#  ['처음', '에', '너무', '씨끄러워서', '놀라', '서', '침대', '에서', '떨어', '졋닦', 'ㅋㄱㅋㄱ'],
#  ['짜장면', '탕수육', '합친게', '잇구나'],
#  ['너불님',
#   '은',
#   '볼때마다',
#   '매력있게',
#   '드시',
#   '는듯',
#   '..',
#   '.괜',
#   '나',
#   '까지',
#   '먹고',
#   '싶어',
#   '지게ㅁ'],
#  ['난', '코카', '콜라', '랑', '찍먹', '인데'],
#  ['콜라', '까진', '이해', '하는', '데', '부먹', '..', '.?'],
#  ['난', '찍먹', '인뎀', 'ㅋㅋ'],
#  ['대한',
#   '코카',
#   '찍먹',
#   '협회',
#   '에서',
#   '나',
#   '왔습',
#   '니다',
#   '지금',
#   '펩시',
#   '에',
#   '부먹',
#   '을',
#   '즐겨하신다고',
#   '제보가',
#   '들어',
#   '왔는데',
#   '그러',
#   '한',
#   '행위는',
#   '범죄',
#   '입니다',
#   '이',
#   '영상',
#   '에는',
#   '펩시',
#   '를',
#   '먹는',
#   '행위는',
#   '적발되지',
#   '않아',
#   '처벌은',
#   '불가하오나',
#   '만약',
#   '부먹',
#   '펩시',
#   '를',
#   '한다는',
#   '제보가',
#   '들어',
#   '온다면',
#   '찍먹',
#   '법',
#   '조',
#   '항과',
#   '코카',
#   '법',
#   '조항에',
#   '의거하여',
#   '한달간',
#   '짜장',
#   '없는',
#   '짜장면',
#   '형에',
#   '처해집니다',
#   '감사합니다'],
#  ['다', '필요', '없어', '!!', '!', '처먹', '파', '나와', '랏', '!!', '!!', '!'],
#  ['코카',
#   '..',
#   '..',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '오늘',
#   '도',
#   '넘나',
#   '귀여',
#   '운',
#   '너불',
#   '넴'],
#  ['천원', '이라', '닛', '..', '마싯', '겟다', '..'],
#  ['나도', '부먹', '+', '펩시'],
#  ['으어어',
#   '..',
#   '아니',
#   '니',
#   '탕짜면',
#   '!!',
#   '부럽부럽',
#   '먹고',
#   '싶다',
#   '아아',
#   '..',
#   '배고',
#   '파',
#   '..',
#   '너불님',
#   '짱',
#   '귀엽',
#   '..',
#   '크음',
#   '싱크',
#   '가',
#   '좀',
#   '안',
#   '맞는',
#   '데',
#   '..',
#   '킁',
#   '기분',
#   '탓인가',
#   '..'],
#  ['너불님',
#   '시작',
#   '할때',
#   '든',
#   '먹으실때든',
#   '귀여',
#   '우신',
#   '..',
#   '저',
#   '짜장면',
#   '부럽다',
#   '앙',
#   '..'],
#  ['저는',
#   '끔직한',
#   '혼종',
#   '으로',
#   '서',
#   '둘다',
#   '먹습니다.',
#   '부먹',
#   '과',
#   '찍먹',
#   ',',
#   '코카',
#   '와',
#   '팹시'],
#  ['여러분', '좋아', '요', '누르', '는', '습관', '너무', '좋아', '요', '~~'],
#  ['우와', '탕짜면', '~', '너무', '조아', '여', '~'],
#  ['콜라', '너불님', '이', '약하게', '깐것', '아님?'],
#  ['부먹'],
#  ['짜장면', '을', '너불님', '오른손쪽에', '놓지', '좀', '불편', '해', '보인당', '..', '.'],
#  ['곱빼긴가?',
#   '우리',
#   '동네',
#   '에는',
#   '곱빼',
#   '기',
#   '하면',
#   '짜장면',
#   '그릇',
#   '수준',
#   '으로',
#   '오는데',
#   'ㅋㅋ'],
#  ['탕짜면', '너무', '좋아', '요', '짝짝', '짝'],
#  ['앗',
#   '이',
#   '영상',
#   '이',
#   '짜장면',
#   '먹고',
#   '노란딱지',
#   '받았다던',
#   '그',
#   '영상',
#   '인가',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '유튜브',
#   '관계자가',
#   '찍먹',
#   '코카',
#   '일수도',
#   'ㅎㅎ'],
#  ['저는',
#   '볶짜면볶음밥짜장면곱',
#   '배기로',
#   '시겼는데',
#   '일반으로',
#   '줬어요',
#   '많이',
#   '배고',
#   '픈',
#   '상태',
#   '였는데'],
#  ['너불',
#   '어린이',
#   '는',
#   '부모님께',
#   '면을',
#   '끊으면',
#   '안돼',
#   '는',
#   '것이라고',
#   '올바른',
#   '것을',
#   '배운',
#   '착한어린이에요',
#   '!'],
#  ['요즘', '대세는', '빨먹아닙니까????', '?', '잘', '모르', '시넹'],
#  ['너불님', '귀엽', '고', '왜', '이렇게', '잘생', '겼지ㅣㅇ', '..', '.'],
#  ['점심', '방금', '먹었는데', '..', '..', '또', '배고', '프네', '..', '..'],
#  ['부먹',
#   '이든',
#   '찍먹',
#   '이든',
#   '코카',
#   '파든',
#   '펩시',
#   '파든',
#   '맛있',
#   '게',
#   '먹으면',
#   '불만',
#   '없습니다'],
#  ['부먹', '이라', '닛', '!!'],
#  ['너불님',
#   '진짜',
#   '잘먹으신다',
#   '!!',
#   '너무',
#   '맛있',
#   '게',
#   '먹어',
#   '서',
#   '제가',
#   '더',
#   '기분',
#   '이',
#   '좋아',
#   '요',
#   '!!',
#   '~',
#   'ㅎㅎ'],
#  ['부먹', '찍먹', '상관없', '음', '걍', '맛있', '으면', '장땡'],
#  ['타타타타탕짜면?'],
#  ['어',
#   '옷',
#   '제가',
#   '산옷이랑',
#   '똑같',
#   '아요',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '검정색으로',
#   '샀었는데'],
#  ['주문', '할때', '도', '탕짜면', '이라', '거', '하나', '요', '??'],
#  ['그냥',
#   '처먹',
#   '파',
#   ',,',
#   ',,',
#   '..',
#   '.',
#   '오늘',
#   '부터',
#   '탕수육',
#   '부먹',
#   '한다',
#   'ㅋㅋ',
#   'ㅋㄱ',
#   'ㄲ'],
#  ['콜카', '펩시', '두다', '좋아', '하는', '사람', '소리', '질러', '!애ㅓㅓ', '아아아아아아아', '!'],
#  ['으에', '탕수육', '물~렁', '..', '.'],
#  ['코카', '군요', '..', '조금', '불편', 'ㅋㅋ', 'ㅋㅋ'],
#  ['맛시께다'],
#  ['역시', '팹시', '와', '부먹', '이지', '!!', '!'],
#  ['헤헷',
#   '!!',
#   '전',
#   '오늘',
#   '차돌박이랑',
#   '야식으로는',
#   '네네',
#   '치킨',
#   '크리미언',
#   '먹어',
#   '용',
#   'ㅎㅎ'],
#  ['콜라', '살살땄잖아', '!!', '!', '살살땄잖아', '!!', '!', '한번', '에', '따면', '경쾌하단말이야!!!'],
#  ['아진찌', '사장님뭘모르시네'],
#  ['너불', '넴!', '나중에', '먹방', 'ASMR', '도', '해주세', '여ㅠ'],
#  ['맛있', '겠당', '..', '..'],
#  ['탕수', '을', '짬뽕', '에', '넣어', '드시', '면', '개', '꿀맛', '장담할수있습니다'],
#  ['아', '부먹', '..', '.', '구리다', '..', '.'],
#  ['팹시', '불편', 'ㅡㅡ'],
#  ['역시', '너불님', '우리', '위대한', '펩시', '파'],
#  ['코카', '좋아', '하는', '사람', '손~'],
#  ['나듀', '부먹', '에', '팹시', '다', '사실', '처먹', '에', '팹시', '..', '..'],
#  ['불',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡ편'],
#  ['펩시', '+', '부먹', '혼종'],
#  ['부먹', '손'],
#  ['아니', '한국말은', '좀', '끝까지', '들어'],
#  ['펩시', '는', '김빠지는', '게', '아예', '걍', '날라가는', '소리', '지', 'ㅋㅋ', 'ㅋ'],
#  ['맛있', '겠다', '..', '..', '.ㅇㅁㅇ'],
#  ['맛있', '겠네', '요', 'ㅎㅎ', '이', '고통', '제가', '알죠', 'ㅠㅠ'],
#  ['킹카', '콜라', '사랑해', '요'],
#  ['부먹', '에', '펩시', '..', '.', '불', 'ㅡㅡ', 'ㅡㅡ', '편'],
#  ['코카',
#   '콜라',
#   '비하',
#   '존나',
#   '심하',
#   '네',
#   '방송',
#   '처음',
#   '해보',
#   '나?',
#   '악어',
#   '없엇으면',
#   '이미',
#   '묻혓을듯',
#   '코카',
#   '콜라',
#   '비하',
#   '진짜',
#   '잘봣다'],
#  ['코카',
#   '콜라',
#   '의',
#   '소리',
#   '가',
#   '왜곡',
#   '되었습니다.',
#   '코카',
#   '콜라',
#   '를',
#   '한번',
#   '에',
#   '따야지',
#   '조금',
#   '따서',
#   '기다리고',
#   '있다',
#   '가',
#   '팍',
#   '따니깐',
#   '그런',
#   '소리',
#   '가',
#   '나죠',
#   '너불님',
#   '펩시',
#   '가',
#   '펩',
#   '시',
#   '..',
#   '..',
#   '..',
#   '이런',
#   '소리',
#   '가',
#   '나죠',
#   '코카',
#   '콜라',
#   '는',
#   '코',
#   '크크킄크흑',
#   '하학!',
#   '이런',
#   '아주',
#   '좋은',
#   '소리',
#   '가',
#   '난다고요',
#   '다시',
#   '는',
#   '왜곡',
#   '하지',
#   '말아주세요',
#   'ㅋㅋ',
#   'ㅋ'],
#  ['coca'],
#  ['펩시',
#   '는',
#   '사랑',
#   '이죠',
#   '그렇다고',
#   '코카',
#   '극혐',
#   '이런',
#   '거는',
#   '아닙니다',
#   '우리',
#   '펩시',
#   '부먹',
#   '파는',
#   '사랑',
#   '이죠',
#   '그리고',
#   '다른',
#   '사람',
#   '들과',
#   '있을때에는',
#   '찍먹',
#   '을',
#   '하고',
#   '코카',
#   '가',
#   '온다면',
#   '극혐',
#   '이라',
#   '면서',
#   '버리지도안고',
#   '그냥',
#   '잘',
#   '먹어',
#   '요',
#   'ㅎㅎ'],
#  ['아',
#   '..',
#   '짜장면',
#   '안먹',
#   '은지',
#   '오래됬댜',
#   '..',
#   '너불',
#   '쨩',
#   '보고',
#   '대리만족하고',
#   '가욤',
#   '..',
#   'ㅡ',
#   '요즘',
#   '너불',
#   '쨩',
#   '처럼',
#   '젓가락',
#   '뜯는당'],
#  ['라면', '에', '밥말아먹으면서', '짜장면', '먹는', '걸', '보고', '있다', '니', '..', '서럽다'],
#  ['이거',
#   '방송',
#   '에서',
#   '새벽',
#   '몇시에',
#   '드셨더라',
#   '..',
#   '.',
#   'ㅎㅎ',
#   'ㅎ',
#   '이리',
#   '맛있',
#   '게',
#   '드시',
#   '면',
#   '새벽',
#   '러',
#   '들은',
#   '배고',
#   '파집니다',
#   '..',
#   '그',
#   '래도',
#   '맛있',
#   '게',
#   '복스럽',
#   '게',
#   '먹는',
#   '걸',
#   '보니',
#   '흐뭇'],
#  ['헑',
#   '저',
#   '탕짬면',
#   '덕훈데',
#   '다이어트중이라서',
#   '어제',
#   '시키고싶은거',
#   '완전',
#   '참았는데',
#   '이거',
#   '보니',
#   '깐',
#   '넘나시키고싶다는',
#   '..',
#   '.'],
#  ['너불님',
#   '이',
#   '젓가락',
#   '책상',
#   '에',
#   '두드릴때',
#   '마리오',
#   'BGM',
#   '이',
#   '들린건',
#   '기분',
#   '탓?',
#   '따딴딴따딴탄'],
#  ['콜라',
#   '얘기',
#   '나오',
#   '니까',
#   '떠오르는',
#   '남순님',
#   '단체캠방',
#   '명언',
#   '펩',
#   '펩시',
#   '?',
#   '코카',
#   '콜라',
#   '?',
#   '시',
#   '시작',
#   '은',
#   '같은',
#   '콜라',
#   '입니다'],
#  ['아',
#   '..',
#   '갑자기',
#   '탕수육',
#   '이랑',
#   '군만두',
#   '먹고',
#   '싶다',
#   '..',
#   'ㅠㅜ',
#   'ㅠㅠ',
#   '하필',
#   '딱',
#   '점심먹은훈데',
#   '..',
#   'ㅜ'],
#  ['역시', '부먹', '펩시', '파', '그래서', '너불님', '을', '좋아', '하는', '거야', '크', '~~~~~'],
#  ['저', '짜장면', '먹을', '때', '항상', '탕짜면', '으로', '시키는뎅ㅎ'],
#  ['어',
#   '!!',
#   '어제',
#   '먹었는',
#   '뒈.',
#   '오늘',
#   '도',
#   '맛있',
#   '게',
#   '드시',
#   '넹~',
#   '참고로',
#   '난',
#   '원',
#   '이였',
#   '음.'],
#  ['너',
#   '블님',
#   '코카',
#   '콜라',
#   '를',
#   '무시하',
#   '지',
#   '마세요',
#   '솔직',
#   '펩시',
#   '보단',
#   '코카',
#   '가',
#   '더',
#   '맛있',
#   '습'],
#  ['하핳!',
#   '이거',
#   '보니까',
#   '짜장면',
#   '이',
#   '먹고',
#   '싶네요',
#   '!!',
#   '!',
#   '배거팡',
#   '..',
#   '.',
#   'ㅠㅠ',
#   'ㅠㅠ'],
#  ['탕짜면', '보다', '는', '짬짜면+', '탕수육', '~~', '하지만', '찍먹', '코카', '짱!'],
#  ['언제',
#   '부터',
#   '였을까요..',
#   '코카',
#   '펩시',
#   ',',
#   '부먹',
#   '찍먹',
#   '의',
#   '싸움은',
#   '..',
#   '호드',
#   '얼라',
#   '싸움',
#   '같은',
#   '건가',
#   '..',
#   '?'],
#  ['세상',
#   '이거',
#   '새벽',
#   '에',
#   '보면서',
#   '배고',
#   '파',
#   '죽는',
#   '줄',
#   ',,',
#   ',',
#   '하지만',
#   '이',
#   '다음',
#   '날',
#   '탕짜',
#   '며면',
#   '머금',
#   ',,',
#   '헤헤'],
#  ['너불님', '짜장면', '어디', '껀', '가요', '?', '코카', '를', '주시', '네요', 'ㅎㅎ'],
#  ['부먹', '팹시', '불', 'ㅡㅡ', 'ㅡㅡ', '편'],
#  ['아', '..', '..', '더', '보기', '란에', '있는', '글', '너무', '슬프', '자녀', '..', '.ㅠ'],
#  ['코너', '속의', '코너', '젓가락', '일정하게', '가르기', '!!', '!!'],
#  ['좀',
#   '불편',
#   '하구먼',
#   '코카',
#   '콜라',
#   '보고',
#   '좋았는데',
#   '탕수육',
#   '을',
#   '보고',
#   '크흠',
#   '..',
#   '.'],
#  ['짜장', '+', '탕수육', '+', '짬뽕', '짬짜', '탕'],
#  ['코카', '콜라', '가', '없었으면', '애초에', '펩시', '도', '없었음ㅋ'],
#  ['부먹',
#   ',',
#   '찍먹',
#   '탕수육',
#   '은',
#   '배에',
#   '들어',
#   '가면',
#   '똑같',
#   '은데',
#   '왜',
#   '부먹',
#   '찍먹',
#   '으로',
#   '나뉘는거죠?'],
#  ['맛있', '겠다', '..', '..', '너불님', '이', '드시', '는거', '다', '맛있', '어보임', '..', '.'],
#  ['너불님', '먹방', '너무', '좋아', '요', '~~~~~~~~~~', '!'],
#  ['솔직',
#   '그냥',
#   '어떤',
#   '탄산',
#   '이든',
#   '빠르게',
#   '확따면소리가',
#   '크고',
#   '느리게따면',
#   '쉬이이이익',
#   '소리',
#   '남'],
#  ['부먹', '에다', '가', '코카', '의', '조합', '??', '??'],
#  ['너불님', '꾸여', '워', '..', '맛있', '게', '잘드신다', '..', '!'],
#  ['콜라', '면됬지뭨ㅋ', 'ㅇㅈ', '?ㅇ', 'ㅇㅈ'],
#  ['너불',
#   '짜응은',
#   '어떻게',
#   '해서',
#   '잘생',
#   '겨짐',
#   '??',
#   '난',
#   '..',
#   '..',
#   '..',
#   '..',
#   '..',
#   'ㅠ'],
#  ['너무',
#   '배고',
#   '파요',
#   '짝짝',
#   '짝',
#   '너무',
#   '늦게',
#   '한다',
#   '근데',
#   '너불',
#   '이는',
#   '너무',
#   '좋아',
#   '요',
#   '너무',
#   '맛있',
#   '게',
#   '먹',
#   '는다'],
#  ['배고', '프다앜ㅠ'],
#  ['너불님', '펩시', '파', '아니', '였나요', '??', '??'],
#  ['벽뜯어진거', '마음', '아픔', 'ㅠ'],
#  ['따아아아아아아아아아', '아아아', '!!', '!!', '!!', '!!', '으으으으', '..', '.', 'ㅋㅋ'],
#  ['코콜', '욕하', '지', '마라여ㅕ', '..', 'ㅠ'],
#  ['나는', '악어', '콜라', '가', '더', '맛있', '든데'],
#  ['부먹', '펩시', '찍먹', '코카', '콜라'],
#  ['부먹', '팹시', '파', '..', '불편'],
#  ['소스', '안', '먹는', '데', '소스', '가', '그렇게', '맛있', '나요?'],
#  ['아', '진짜', '너무', '귀엽', '게', '드셔', 'ㅠㅠ', 'ㅠ', 'ㅜㅜ', 'ㅜㅜ', 'ㅜㅠ', 'ㅜㅜ', 'ㅜ'],
#  ['저도',
#   '펩시',
#   '가',
#   '좋음',
#   '왜냐',
#   '하면',
#   '작은',
#   '아빠',
#   '가',
#   '칠성',
#   '화사',
#   '인데',
#   '펩시',
#   '먹으',
#   '레요!'],
#  ['코카', '를', '무시하', '지', '마세요', '!'],
#  ['코카', '콜라', '비하', '..', '불편', '..', '정떨정떨'],
#  ['부먹', '펩시', '..', '?'],
#  ['방금',
#   '떡볶이',
#   '먹었는데',
#   '올라',
#   '온거',
#   '실화',
#   '?',
#   '갑자기',
#   '탕수육',
#   '먹고',
#   '싶네',
#   '..',
#   '..',
#   '.'],
#  ['부먹', '팹시', '불편'],
#  ['너불님', '실망', '..', '.'],
#  ['너하'],
#  ['코카',
#   '는',
#   '뭔가',
#   '톡쏘는',
#   '맛이',
#   '없어',
#   '서',
#   '별로',
#   '인',
#   '..',
#   '찰싹!',
#   '근데',
#   '팹시',
#   '는',
#   '톡쏘는',
#   '맛도',
#   '있음',
#   '!!',
#   '!',
#   '걔다가',
#   '부먹',
#   '..',
#   '그',
#   '것은',
#   '사랑',
#   '입니다',
#   '!!',
#   '!!',
#   '!'],
#  ['맛있', '겠다', '..', '..', '주륵'],
#  ['뜨아아아아아아ㅏㅇ앙', '아ㅏ'],
#  ['나도', '탕짜면', '먹는', '데', '저는', '원'],
#  ['다', '다', '물어', '혼종', '이', '짱이', '야!'],
#  ['부먹', '불편'],
#  ['너불님', '너무', '조아', '여~', '짝짝', '짝'],
#  ['ㅡ저녁', '탕짜면', '먹을', '껄', '..', '.ㅡ', '치킨', '먹었는데', '.', '.', '너불님', '쓰릉해요~'],
#  ['코카', '편', 'ㅡㅡ', '안'],
#  ['난', '코카', '가', '더', '좋은데', '..', '..', '?'],
#  ['코카', '가', '쥬아!!!!!!!!', '!'],
#  ['저기', '코카', '느리게', '따시는것같', '..', '큼'],
#  ['저는', '찍먹', '에다', '가', '코카', '입니다', '너불님', '구독', '취소', '합니다', 'ㅈㅅ', '구라임'],
#  ['아임', '혼종'],
#  ['코카', '부먹', '무엇'],
#  ['저는',
#   '부먹',
#   '파도',
#   '찍먹',
#   '파도',
#   '아닙니다',
#   '담먹',
#   '파+',
#   '쳐먹',
#   '파',
#   '입니다',
#   'ㅋㅋ',
#   '저는',
#   '코카',
#   '는',
#   '좀',
#   '못먹겠더라고요',
#   '탄산',
#   '이',
#   '너무',
#   '쎄서',
#   '..',
#   'ㅠㅠ',
#   '그래서',
#   '펩시',
#   '아니',
#   '면',
#   '사이다',
#   '먹어',
#   '여',
#   '펩시',
#   '쥬아',
#   '사이다',
#   '쥬아'],
#  ['펩시', '따실때', '딱!', '코카', '따실때', '따아아아ㅏ아아아아아', '아아아아아아아', '악'],
#  ['+', '짬뽕', '우주최강'],
#  ['너불님', '이', '부먹', '에', '펩시', '를', '좋아', '하신다', '니', '..'],
#  ['멋사', '불편'],
#  ['펩시', '파라', '큼', '..', '.좀', '그렇', '네요'],
#  ['아',
#   '..',
#   '..',
#   '배고',
#   '파',
#   '..',
#   '..',
#   '아침도',
#   '못',
#   '먹고',
#   '..',
#   '..',
#   '역시',
#   '부먹',
#   '!!',
#   '찡끗',
#   '코카',
#   '말고',
#   '펩시',
#   '면',
#   '좋겠',
#   '지만',
#   '..',
#   '.',
#   'ㅎㅎ'],
#  ['코카', '콜라', '불', 'ㅡㅡ', 'ㅡ편'],
#  ['볼', '한번', '만', '만져보고싶다', '..'],
#  ['나도', 'ㅠ', '먹고', '싶다', '..', 'ㅠㅠ'],
#  ['중국', '집에', '서', '시키면', '콜라', '를', '주는', '구나', '..', '.'],
#  ['코카', '파의', '반란을', '일으키자', '!!'],
#  ['부먹',
#   '불',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   '편',
#   '젓가락',
#   '불',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡ편'],
#  ['끄아아',
#   '아무것도',
#   '안',
#   '먹어',
#   '서',
#   '배고',
#   '픈데',
#   '그',
#   '와중에',
#   '너불님',
#   '잘생',
#   '김',
#   '..',
#   '.',
#   '저',
#   '어제',
#   '토',
#   '번',
#   '해썹요',
#   'ㅠㅠ',
#   'ㅠ'],
#  ['너불님',
#   '은',
#   '좋아',
#   '하지만',
#   '이건',
#   '선동과',
#   '날조입니다!!',
#   '코카',
#   '는',
#   '약하게',
#   '따지',
#   '않는',
#   '이상',
#   '저런',
#   '소리',
#   '가',
#   '날',
#   '수',
#   '없습니다',
#   '고로',
#   '선동과',
#   '날조입니다!!!!!',
#   '하지만',
#   '너불님',
#   '그런',
#   '모습',
#   '도',
#   '귀엽',
#   '습니다',
#   '!!',
#   '좋아',
#   '합니다',
#   '너불님',
#   '!!'],
#  ['코카', '찍먹', '이죠'],
#  ['새벽', '에', 'gta', '방송', '하다가', '배고', '파서', '했던', '방송'],
#  ['우왕', '초', '전', '짜장면', '또', '먹고', '싶다', 'ㅠㅠ', 'ㅠㅠ'],
#  ['탕수육', '은', '부먹', '콜라', '는', '코카', '져', '!!'],
#  ['뭐야', '오늘', '도', '잘생', '겼잖아'],
#  ['저만그럼?', '펩시', '는', '따는', '소리', '안나던데'],
#  ['맜있', '겠다'],
#  ['겁나', '귀여', '미', '너불님', '!', '너무', '조아', '여', '~~', '!!'],
#  ['탕짜면', '..', '?', '동공지진'],
#  ['와', '부먹', '에', '펩시', '면', '윽'],
#  ['탕타탕타당', '탕짜면'],
#  ['아닛', '!!', '??', '탕짜면', '의', '탕수육', '이', '부먹', '??', '?', '!!'],
#  ['너무', '좋', '와요', '!', '~~~~~', '~', '짝짝', '짝짝', 'X'],
#  ['부먹',
#   '불편',
#   '코카',
#   '너무',
#   '조아요',
#   '오',
#   '!!',
#   '!',
#   '너불님',
#   '도',
#   '너무',
#   '조아요오오오',
#   '!!',
#   '!'],
#  ['난', '처먹', '파', '인데'],
#  ['너하'],
#  ['너불님', '활기', '차시고', '귀여', '우시', '당', 'ㅋㅅㅋ'],
#  ['..',
#   '.',
#   '이런',
#   '시간',
#   '에',
#   '탕짜면',
#   '이라니',
#   '..',
#   '..',
#   '코카',
#   '맛있',
#   '지요!',
#   '너불님',
#   '코카',
#   '콜라',
#   '를',
#   '누가',
#   '그렇게',
#   '땁니까..ㅠㅠㅠ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '젓가락',
#   '코카',
#   '가',
#   '내린',
#   '저주'],
#  ['하', 'ㅋㅋ', 'ㅋㄹ', '불편', '펩시', '짱'],
#  ['지금', '짜장면', '하고', '탕수육', '시켰습니당'],
#  ['젓가락', '이', '!!', '?', '!?!?', '!?!', '으아', '아아ㅏ', '아아아아', 'ㅏ'],
#  ['분',
#   '초에',
#   '귀',
#   '터질뻔',
#   '..',
#   '..',
#   '이어폰',
#   '꽂고',
#   '들었는데',
#   '진짜',
#   '터지는',
#   '줄',
#   '..',
#   '.'],
#  ['ㅋㅋ',
#   'ㅋ',
#   '멋사',
#   '님은',
#   '세게',
#   '따서',
#   '코',
#   '캌!!',
#   '소리',
#   '나는',
#   '데',
#   '너불님',
#   '은',
#   '일부러약하게',
#   '따시넼',
#   'ㅋㅋ'],
#  ['너불님', '펩시', '파', '인가', '?', '난', '펩시', '인데'],
#  ['코카', '콜라', '..', '..', '.?'],
#  ['그렇게', '오늘', '도', '너불님', '은', '귀여', '웠다.'],
#  ['탕짜면', '첨', '봤', '..', 'ㄷ', '존맛이겠다아ㅏㅏ'],
#  ['너불님', '왼손이신가요', '오른손이신가요?'],
#  ['탕수육', '맛있', '겠다', '..', '.'],
#  ['너무', '좋아', '여', '짝짝', '짝'],
#  ['나는', '코카', '파다!', 'ㅎㅎ'],
#  ['너불님', '영상', '재미', '있어요'],
#  ['이때',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '텐션',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'GTA',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ하'],
#  ['부먹',
#   ',',
#   '펩시',
#   '파',
#   '만세',
#   '를',
#   '들어',
#   '라',
#   '~~~',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!'],
#  ['와', '진짜', '넘후', '맛있', '겠는데', '..'],
#  ['펩시', '너무', '쪼아', '여', '~~~'],
#  ['안농'],
#  ['너불님', '께서는', '먹어', '도', '살이', '안찌시는것', '같아요'],
#  ['쪼아', '요', '눌럿찌요'],
#  ['코카', '무시하지마', '여', 'ㅡㅡ'],
#  ['맞있', '겠다'],
#  ['너불', '쨩', '카와이', '데스요', '젓가락', '실퍀', 'ㅋㅋ', 'ㅋㅋ'],
#  ['하튜주새용~!'],
#  ['저는',
#   '처먹',
#   '입니다',
#   'ㅏ',
#   '부먹',
#   '이든',
#   '쯱먹이든',
#   '코카',
#   '든',
#   '펩싀든',
#   '맛있',
#   '으면',
#   '되는',
#   '거져',
#   '!'],
#  ['왕', '마시', '케타'],
#  ['너불님', '..', '.', '너무', '좋아', '여', '~~~~~', '~', '짝짝', '짝짝', '짝짝', '짝짝'],
#  ['너불님', '영상', '너무', '좋아', '요', '~~'],
#  ['좋아', '요', '주시면', '굿!'],
#  ['난',
#   '팹시',
#   '찍먹',
#   '판데',
#   '..',
#   '..',
#   '.',
#   '이',
#   '영상',
#   '엔',
#   '하',
#   '나도',
#   '안나',
#   '왘ㅋㅋㅋ',
#   '그',
#   '래도',
#   '너불님',
#   '먹방',
#   '은',
#   '너무',
#   '쪼아',
#   '요',
#   '짝짝',
#   '짝짝',
#   '짝'],
#  ['코카', '라', '조금', '불', 'ㅡㅡ', '편한', '감이', '크흠', '..', '..'],
#  ['탕짜면', '너무', '조아요', '~!', '쯕짝짝짝짝짝짝짝'],
#  ['똑똑', '똑', '누구', '십니', '까?', '탕짜면', '배달왔습니다', '너무', '좋아', '요', '쨕', '짝짝'],
#  ['댓글', '보니', '난', '끔직한', '혼종', '인가보다'],
#  ['ㄷㄷ'],
#  ['와', '찐짜', '맛있', '어', '겠다'],
#  ['탕짜면', '가즈아!'],
#  ['와아아ㅏ아아아아ㅏ아', '!!'],
#  ['너', '블님', '잘생', '김'],
#  ['귀여', '워요.', '.', 'ㅠㅠ', '글쿠', '너무', '맜있', '어', '보여', '요', 'ㅠㅠ', 'ㅠ'],
#  ['아하하핳',
#   '너불님',
#   '잘생',
#   '겼따!',
#   '근데',
#   '아직',
#   '밥',
#   '안',
#   '먹었는데',
#   '배고',
#   '프다',
#   '..',
#   'ㅜ'],
#  ['너불님', '파마', '종류', '머에요'],
#  ['코카', '너무', '좋아', '요', '짝짝', '짝짝', '짝'],
#  ['펩시', '도', '따뜻하', '면', '그렇거든요!흥!'],
#  ['너불님', '의', '얼굴', '은', '열일', '중'],
#  ['부먹', '부울편', '펩시', '불펴언'],
#  ['코카', '를', '..', '..', '코카', '가', '갑', '..', '..', '.'],
#  ['댓글',
#   '들',
#   '펩시',
#   '코가',
#   '얘기',
#   '밖에',
#   '없냐',
#   'ㅋㅋ',
#   'ㅋ',
#   '불편',
#   '편안',
#   '따지고있네',
#   'ㅋㅋ',
#   'ㅋㅋ'],
#  ['맛있', '겠따'],
#  ['헤헤', '헿'],
#  ['본격적으로', '디스하시는데', 'ㅋㅋ', 'ㅋㅋ'],
#  ['와', '대박', 'ㅠㅠ', 'ㅠ', '맛있', '겠다', 'ㅠㅠ'],
#  ['먹고',
#   '싶다',
#   '..',
#   '..',
#   '..',
#   '근데',
#   '탕수육',
#   '이',
#   '부먹',
#   '이라니',
#   '!!',
#   '!!',
#   '!!'],
#  ['그', '래도', '재미', '있으', '니', '좋아', '요', '구독'],
#  ['너불님', '카와이'],
#  ['부먹',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!'],
#  ['코카', '는', '좋은데', '..', '부먹', '이', '네요', 'ㅠㅠ'],
#  ['어?', '나', '방금', '탕수육', '이랑', '짜장면', '먹었는데', '?', '와', '이런', '우연이', '대박이네요'],
#  ['헉',
#   '너불님',
#   '먹방',
#   '!',
#   '탕짜면',
#   '이라',
#   '닛ㅅ',
#   '너불님',
#   '은',
#   '항상',
#   '잘드신다',
#   '는',
#   '..',
#   '너무',
#   '조아',
#   '여',
#   '짝짝'],
#  ['너하너하'],
#  ['맛있', '겠다'],
#  ['너무', '좋아', '요~', '짝짝'],
#  ['꺄하', 'ㅜㅜ', '넘', '잘생', '겼으', 'ㅜㅜ', 'ㅜㅜ'],
#  ['펩시', '불편'],
#  ['멋사', '님'],
#  ['담부찍', '코펩파', '입니다'],
#  ['앗', '이때', '택시비', '만처넌', '나온날이자너?'],
#  ['저건', '섞먹', '아닌가', '..', '.?'],
#  ['너불님', '먹방', '너무', '좋아', '요', '짝짝', '짝짝', '짝'],
#  ['번째', '좋아', '요는', '제가', '!!', 'ㅎ'],
#  ['코.카.좋.아'],
#  ['부럽다'],
#  ['전', '그냥', '처먹', '파라', '..', 'ㅋㅋ', 'ㅋ'],
#  ['요즘', '넙짱', '더', '기여워', '짐'],
#  ['꿀'],
#  ['배고', '파', '..'],
#  ['너무', '기엽자너', '..', '..', '.', 'ㅠㅠ', '맛있', '겠당', '..', '..', '.'],
#  ['너불님', '..', '코카', '를', '..'],
#  ['다들', '탕수육', '부먹', '?', '찍먹', '?'],
#  ['와아아'],
#  ['부먹', '개이득'],
#  ['아', '갑자기', '먹고', '싶다', 'ㅠㅠ'],
#  ['코트는',
#   '치익',
#   ',,',
#   ',',
#   '이고',
#   '펩시',
#   '는',
#   '칙~~~~~익임',
#   '결론',
#   '은',
#   '난',
#   '펩시',
#   '고',
#   '부먹',
#   '이다',
#   '난',
#   '너불님',
#   '이랑',
#   '똑같',
#   '이',
#   '있다',
#   'ㅋㅋ',
#   '개꿀',
#   '펩시',
#   '짱'],
#  ['너무', '져아여~', '~'],
#  ['코카', '불편'],
#  ['맛있', '겠다'],
#  ['너무',
#   '잘드신다',
#   '..',
#   '이',
#   '영상',
#   '은',
#   '새벽',
#   '에',
#   '보지',
#   '않는걸',
#   '추천',
#   '합니다',
#   '..',
#   '배고',
#   '파요.'],
#  ['아닛!', '코카', '가', '!!'],
#  ['네다펩', '장난'],
#  ['빠'],
#  ['너불님', '먹는', '모습', '도', '예쁘', '고', '귀엽', '다', '~~'],
#  ['으아', 'ㅠㅠ', '탕짜면', '맛있', '겠다', 'ㅠㅠ', 'ㅠㅠ', 'ㅠ'],
#  ['코카', '..', '..'],
#  ['배고',
#   '파',
#   '..',
#   '..',
#   '..',
#   '밥도',
#   '먹었는데',
#   '..',
#   '배고',
#   '파!',
#   'ㅠㅠ',
#   'ㅠㅠ',
#   'ㅠ'],
#  ['나무', '젓가락', '실퍀', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ'],
#  ['배고', '프네', '..', '..', '주륵'],
#  ['방금', '밥먹', '고', '왔는데', '또', '배고', '파아', '..', '.'],
#  ['코.카.쥬.아'],
#  ['나는', '콜라', '보다', '사이다'],
#  ['친구', '들이', '부먹', '찍먹', '으로', '싸울때', '싸우는시간동안', '하나', '라도', '더집어먹는사람'],
#  ['와우'],
#  ['펩시', '는', '사랑', '입니다', '!!', '!'],
#  ['나만', '짬뽕', '국물이', '카레로', '보이', '나', '..', '??'],
#  ['나도', '짜장면', '먹고', '싶어', 'ㅜㅜ'],
#  ['코카', '만세'],
#  ['코카', '기쁨'],
#  ['이시'],
#  ['불',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ편'],
#  ['어디서', '살수', '있어요', '?'],
#  ['코카'],
#  ['코카', '비하', '하지', '마여', '..', '..', '..', 'ㅠㅠ'],
#  ['솔직',
#   '자',
#   '장면',
#   '부먹',
#   '아님',
#   '에요?',
#   '소스',
#   '를',
#   '부어',
#   '섞어',
#   '먹니',
#   'ㅎ.ㅎ',
#   '자',
#   '장면',
#   '찍먹',
#   '은',
#   '간',
#   '짜장',
#   '을',
#   '시켜',
#   '면을',
#   '소스',
#   '에',
#   '찍어',
#   '먹',
#   '는다',
#   'ㅋㅋ'],
#  ['먹는',
#   '것도',
#   '복스럽',
#   '구',
#   '..',
#   '.',
#   '귀여',
#   '우신',
#   '..',
#   '.',
#   '너불님',
#   '..',
#   '.',
#   '그래',
#   '요',
#   '역시',
#   '콜라',
#   '는',
#   '펩시',
#   '지',
#   '..',
#   '물론',
#   '내가',
#   '코카',
#   '지만',
#   '너불님',
#   '이',
#   '펩시',
#   '라면',
#   '펩시',
#   '죠',
#   '..',
#   '뭐',
#   '..',
#   '오늘',
#   '도',
#   '..',
#   '귀여',
#   '우시',
#   '고',
#   '..',
#   '잘생',
#   '기시고',
#   '..',
#   '너불님',
#   '다',
#   '하세요',
#   '..',
#   '황인준',
#   '..',
#   '짱',
#   '..'],
#  ['나는',
#   '콜라',
#   '가',
#   '뭐든',
#   '사이다가뭐든',
#   '부먹',
#   '이든',
#   '찍먹',
#   '이둔',
#   '그냥',
#   '먹는',
#   '데',
#   '이런',
#   '거로',
#   '싸우는',
#   '걸',
#   '많이',
#   '보다',
#   '보니',
#   '정말',
#   '불편',
#   '하네'],
#  ['여러분',
#   '여러분',
#   '은',
#   '유명한',
#   '명물음식점을갈때',
#   '원조집을',
#   '가지',
#   '않습니까?',
#   '마트갈때를',
#   '생각',
#   '하십시오',
#   '..',
#   '.',
#   '똑같',
#   '습니다',
#   '..',
#   '.',
#   '콜라',
#   '의',
#   '원조',
#   '!',
#   '코카',
#   '콜라',
#   '를',
#   '찬양',
#   '합시다',
#   '..',
#   '.',
#   '하지만',
#   '코카',
#   '콜라',
#   '는',
#   '펩시',
#   '보다',
#   '비싸',
#   '서',
#   '난',
#   '펩시',
#   '파'],
#  ['너불님',
#   '탄산',
#   '음료',
#   '는',
#   '차가',
#   '울',
#   '수록',
#   '김빠지는',
#   '소리',
#   '가',
#   '적게',
#   '나는',
#   '거에요'],
#  ['저는',
#   '전에',
#   '친구',
#   '가',
#   '나무',
#   '젓가락',
#   '으로',
#   '싫어',
#   '하는',
#   '사람',
#   '을',
#   '얼마',
#   '나',
#   '싫어',
#   '하는',
#   '지',
#   '알려줄테니',
#   '반으로',
#   '쪼개라했지만',
#   '불량품이라',
#   '아여',
#   '부서저',
#   '버렸즙니다',
#   '..',
#   '.',
#   '이로써',
#   '제가',
#   '얼마',
#   '나',
#   '오빠',
#   '를',
#   '싫어',
#   '하는',
#   '지',
#   '알수있었습니다',
#   '..',
#   '..',
#   '.'],
#  ['맛있', '겠자', '너~'],
#  ['솔직',
#   '코카',
#   '좋아',
#   '하는',
#   '사람',
#   '한테',
#   '펩시',
#   '가',
#   '펩시',
#   '좋아',
#   '하는',
#   '사람',
#   '한테',
#   '코카',
#   '가',
#   '가야',
#   '리얼',
#   '개',
#   '꿀잼',
#   '.',
#   '코카',
#   '보고',
#   '이게',
#   '탄산',
#   '음료',
#   '냐',
#   '하시는',
#   '데',
#   '원래',
#   '펩시',
#   '보다',
#   '코카',
#   '가',
#   '더',
#   '탄산',
#   '이',
#   '많은걸로',
#   '알고',
#   '있는',
#   '디',
#   '..',
#   '?'],
#  ['와',
#   '!!',
#   '!',
#   '비주얼',
#   '이',
#   '정말',
#   '키야',
#   '~~~~',
#   '!!',
#   '오늘',
#   '도',
#   '먹방',
#   '보면서',
#   '배고',
#   '파지',
#   '겠네',
#   '요',
#   '!!',
#   '!',
#   '나도',
#   '오늘',
#   '짜장면',
#   '먹었는데',
#   '또',
#   '먹고',
#   '싶잖아',
#   '!!',
#   '너무',
#   '좋아',
#   '요',
#   '짝짝',
#   '짝짝',
#   '짝짝'],
#  ['코카',
#   '는',
#   '과학력이',
#   '대단하여',
#   '김이',
#   '덜빠지게',
#   '캔,병이',
#   '만',
#   '들어',
#   '저',
#   '있습니다',
#   '그것의',
#   '비해는',
#   '펩시',
#   '는',
#   '탄산',
#   '이',
#   '많이',
#   '빠지',
#   '죠',
#   '재밌',
#   '는?',
#   '논리일뿐',
#   '너무',
#   '뭐라고하지말아주세요',
#   'ㅠㅠ',
#   '저는',
#   '코카',
#   '가더',
#   '좋습니다',
#   '그',
#   '래도',
#   '펩시',
#   '가',
#   '싫지는',
#   '안습니다'],
#  ['코카',
#   '년',
#   '팹시',
#   '년',
#   '결론',
#   '코카',
#   '는',
#   '펩시',
#   '보다',
#   '먼져',
#   '나옴',
#   '펩시',
#   '는',
#   '그냥',
#   '베낀거임',
#   '솔직',
#   '펩시',
#   '는',
#   '달아서',
#   '김빠',
#   '진',
#   '콜라',
#   '맛임',
#   '반면',
#   '코카',
#   '는',
#   '톡',
#   '쏘는',
#   '맛이',
#   '강해서',
#   '기분',
#   '이가',
#   'ㄱㅁㄸ',
#   '합니다',
#   '.',
#   '솔직',
#   '코카',
#   '펩시',
#   '하시는',
#   '데',
#   '저는',
#   '그냥',
#   '주는',
#   '거',
#   '먹음',
#   '나는',
#   '끔찍한',
#   '혼종',
#   '이기',
#   '떼문에'],
#  ['코카',
#   '콜라',
#   '와',
#   '펩시',
#   '의',
#   '탄산',
#   '차이',
#   '는',
#   '입니다',
#   '.',
#   '펩시',
#   '는',
#   '달고',
#   '탄산',
#   '이',
#   '있어',
#   '서',
#   '펩시',
#   '를',
#   '선호',
#   '하지만',
#   '저는',
#   '사람',
#   '침',
#   '때문에',
#   '코카',
#   '콜라',
#   '를',
#   '먹기',
#   '듦'],
#  ['맛있', '겠다', '..', '.'],
#  ['하핫',
#   '..',
#   '.',
#   '늦어서',
#   '죄송',
#   '하무니당~',
#   '너불님',
#   '영상',
#   '보다',
#   '늦은건',
#   '안비밀~',
#   '펩시',
#   '파도',
#   '아니',
#   '고',
#   '코카',
#   '파도',
#   '아니',
#   '고',
#   '콜라',
#   '는',
#   '무조건',
#   '좋은',
#   '부먹',
#   '다봄',
#   '..',
#   'ㅎㅎ'],
#  ['와',
#   '요즘',
#   '짜장면',
#   '찍먹',
#   '아닌가',
#   '부먹',
#   '하네',
#   '와',
#   '무슨',
#   '짬뽕',
#   '국물이',
#   '랑',
#   '코카',
#   '콜라',
#   '까지',
#   'ㄹㅇ',
#   '넘하시네',
#   'ㅠㅠ',
#   'ㅠㅠ'],
#  ['내가',
#   '생각',
#   '하기',
#   '에는',
#   '탄산',
#   '은',
#   '코카',
#   '가',
#   '더많은것같은데참고로',
#   '전',
#   '사이다',
#   '좋아',
#   '함'],
#  ['아',
#   '너불님',
#   '보는',
#   '내내',
#   '귀엽',
#   '고',
#   '사랑',
#   '스러',
#   '웠는데',
#   '제',
#   '마음',
#   '을',
#   '훔쳐',
#   '갔어요',
#   '잡아갈건데',
#   '잡아가도될까여?',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ',
#   '죄송',
#   '해요',
#   '아',
#   '콜라',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ',
#   '펩시',
#   '가',
#   '짱이',
#   '다',
#   '아~',
#   '탕짜면',
#   '맛있',
#   '겠어요',
#   '..',
#   '~'],
#  ['난',
#   '그냥',
#   '처먹',
#   '인데',
#   '탕수육',
#   '먹을',
#   '때',
#   '몇개는',
#   '담가놓고',
#   '몇개는',
#   '찍어',
#   '먹고',
#   '그리고',
#   '콜라',
#   '라면',
#   '무슨',
#   '콜라',
#   '더',
#   '다',
#   '좋아',
#   'ㅇㅈ',
#   '?'],
#  ['나는',
#   '찍먹',
#   '이다',
#   '짜장면',
#   '도?',
#   '찍어',
#   '먹어',
#   '도',
#   '짜장면',
#   '맛난닼',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ',
#   '코카',
#   '갓',
#   '!!',
#   '나는',
#   '일편단심',
#   '코카',
#   '다!'],
#  ['짜장면',
#   '반개도',
#   '못',
#   '먹는',
#   '저의',
#   '버킷리스트가',
#   '생겼습니다',
#   '짜',
#   '중또는대',
#   '탕',
#   '하기',
#   '..',
#   '배고',
#   '프다',
#   '..',
#   '.'],
#  ['그',
#   '래도',
#   '전',
#   '찍먹',
#   '에',
#   '코카',
#   '콜라',
#   '파',
#   '입니다',
#   '저는',
#   '펩시',
#   '보다',
#   '코카',
#   '콜라',
#   '가',
#   '더',
#   '탄산',
#   '이',
#   '쎄다고',
#   '느끼는',
#   '데',
#   '저만',
#   '그런',
#   '건가요?',
#   '전',
#   '너불님',
#   '이',
#   '펩시',
#   '를',
#   '좋하',
#   '하시',
#   '고',
#   '부먹',
#   '이여도',
#   '너불',
#   '유튜브',
#   '를',
#   '사랑',
#   '합니다'],
#  ['부먹', '불편', 'ㅡㅡ'],
#  ['멋사', '님이', '이', '영상', '을', '싫어', '합니다'],
#  ['코카',
#   '콜라',
#   '선호하는',
#   '사람',
#   '대상으로',
#   '같은',
#   '컵에',
#   '코카',
#   '콜라',
#   '와',
#   '펩시',
#   '를',
#   '부어',
#   '어떤건지',
#   '모르',
#   '게',
#   '해',
#   '놓는',
#   '다음',
#   '개를',
#   '먹어',
#   '본후',
#   '어떤',
#   '게',
#   '더',
#   '맛있',
#   '냐고',
#   '물어',
#   '봤는데',
#   '모두',
#   '펩시',
#   '가',
#   '존맛이라고',
#   'ㅋㅋ',
#   '하는',
#   '거',
#   '보고',
#   '코카',
#   '콜라',
#   '는',
#   '겉멋인가',
#   '라는',
#   '생각',
#   '이',
#   '듬',
#   'ㅋㅋ'],
#  ['부먹', '이리', '구요', '??', '??', '불편', '코카', '콜라', '라구요', '??', '편안'],
#  ['여기', '서', '짜장면', '찍먹', '하시는', '분', '있다', '면', '찍먹', '짱', '인정', '해준다'],
#  ['너불님', '을아', '무리', '좋아', '해도', '부먹', '이랑', '펩시', '는', '못먹', '겠다', 'ㅠㅠ'],
#  ['늘',
#   '볼때마다',
#   '얼굴',
#   '생기신거',
#   '개에바임',
#   '..',
#   '잘생',
#   '겼어',
#   '..',
#   '너므',
#   '져아여~',
#   '쨕쨕짝ㄱ짝쨕쨕',
#   '오른쪽',
#   '밑에',
#   '늘',
#   '있는',
#   '토비오쨩도',
#   '너므',
#   '져아여~',
#   '짝짝',
#   'ㅉㄱ',
#   '쨕짯',
#   '짝짝'],
#  ['갠취존중~',
#   '찍먹',
#   '이',
#   '라고해서',
#   '부먹',
#   '에',
#   '대한',
#   '말도안되는말좀안했으',
#   '면',
#   '좋겠',
#   '고',
#   '부먹',
#   '이라고',
#   '해서',
#   '찍먹',
#   '에',
#   '대한',
#   '말도',
#   '안',
#   '되는',
#   '말좀',
#   '안했으면좋',
#   '겠다',
#   '..',
#   'ㅠ'],
#  ['여기',
#   '서.',
#   '한마디',
#   '하겠습니다',
#   '코카',
#   '펩시',
#   '맛',
#   '똑같',
#   '음',
#   '차이',
#   '없음',
#   '내',
#   '생각',
#   '부먹',
#   '찍먹',
#   '둘다',
#   '탕수육',
#   '맛',
#   '둘다',
#   '맛잇',
#   '음',
#   '앞에',
#   '탕수육',
#   '잇는',
#   '데',
#   '소스',
#   '부엇다고',
#   '안먹지는안을듯',
#   '내',
#   '생각',
#   '나는',
#   '다먹',
#   '음',
#   '난',
#   '쳐먹',
#   '이다!'],
#  ['난',
#   '진짜',
#   '혼종',
#   '이다',
#   '코카',
#   '콜라',
#   '?',
#   '팹시',
#   '?',
#   '난',
#   '탄산',
#   '이',
#   '싫어',
#   '!',
#   '찍먹',
#   '?',
#   '부먹',
#   '?',
#   '난',
#   '처먹',
#   '이다!',
#   '결론',
#   '둘다',
#   '상관없',
#   '음'],
#  ['코카',
#   '콜라',
#   '따는',
#   '소리',
#   '갔다',
#   '가',
#   '뭐라고',
#   '하는',
#   '건',
#   '좀',
#   '..',
#   '.',
#   '전',
#   '너불님',
#   '의',
#   '안티가',
#   '아닌',
#   '것을',
#   '밝니다'],
#  ['중력',
#   '보다',
#   '소리',
#   '가',
#   '컸다',
#   '..',
#   '.!',
#   '중력님',
#   '꺼',
#   '보고',
#   '보려고햇는데',
#   '소리',
#   '가',
#   '커서',
#   '놀랐다',
#   '..',
#   '!',
#   '뭐지',
#   '..',
#   '?',
#   '뭔가',
#   '이상한거같다',
#   '..',
#   '중력',
#   '..',
#   '.',
#   '보다',
#   '..',
#   '소',
#   '..',
#   '리가',
#   '..',
#   '크다',
#   '..',
#   '?',
#   '좀이상하네',
#   '..',
#   '뭐지',
#   '..',
#   '?'],
#  ['흐음',
#   '..',
#   '.',
#   '일부러',
#   '코카',
#   '캔을',
#   '살살따신것',
#   '같은',
#   '데',
#   '..',
#   '.',
#   '저런',
#   '소리',
#   '는',
#   '펩시',
#   '나',
#   '저렇게',
#   '나지',
#   '!!',
#   '!'],
#  ['한마디',
#   '만',
#   '하',
#   '겠다',
#   '.',
#   '그냥',
#   '다',
#   '좀',
#   '먹어',
#   '라.',
#   '이러다가',
#   '짬뽕',
#   '도',
#   '찍먹',
#   ',',
#   '부먹',
#   '나오',
#   '겠다',
#   '.',
#   '그냥',
#   '주는데로',
#   '먹어',
#   '.',
#   '없는',
#   '것보단',
#   '낫잖아',
#   'ㅠㅠ'],
#  ['사람',
#   '마다',
#   '자기입맛에맛는',
#   '음식',
#   '이',
#   '있는',
#   '데',
#   '부먹',
#   '이여서',
#   '구취하고',
#   '펩시',
#   '좋아',
#   '해서',
#   '구취하고',
#   '이건좀아니잖아',
#   '..'],
#  ['아아',
#   '신데',
#   '이걸',
#   '보니',
#   '맛있',
#   '는거',
#   '먹고',
#   '싶다',
#   '..',
#   '돈이없으므오',
#   '대리만족',
#   '할게요',
#   '진짜',
#   '맛잇게',
#   '드시',
#   '네요',
#   '..',
#   'ㅜ'],
#  ['간식',
#   '은',
#   '소시지',
#   '콜라',
#   '는',
#   '펩시',
#   '지',
#   '탕수육',
#   '은',
#   '부먹',
#   '이지',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!'],
#  ['와',
#   '..',
#   '.',
#   '맛있',
#   '게',
#   '드신다',
#   '..',
#   '..',
#   '부럽',
#   '오늘',
#   '시켜먹어야',
#   '겠다',
#   '!!'],
#  ['너불님',
#   '의',
#   '먹방',
#   '은',
#   '크게',
#   '크게',
#   '먹고',
#   '넘',
#   '잘',
#   '먹어',
#   '서',
#   '소리',
#   '도',
#   '들으면',
#   '미칠것',
#   '같아',
#   '밥먹',
#   '었는데',
#   '배고',
#   '파져',
#   'ㅠㅠ',
#   '그레서',
#   '더',
#   '좋앙',
#   'ㅠㅠ',
#   '배고',
#   '파',
#   '..',
#   '먹고',
#   '싶당'],
#  ['전',
#   '탕수육',
#   '소스',
#   '를',
#   '먹지',
#   '않습니다.',
#   '그냥',
#   '먹습니다.',
#   '전',
#   '탄산',
#   '을',
#   '마시',
#   '지',
#   '않습니다.',
#   '그래서',
#   '사람',
#   '들이',
#   '부먹',
#   '찍먹',
#   '으로',
#   '싸울때',
#   '코카',
#   '펩시',
#   '로',
#   '싸울때',
#   '전',
#   '그냥',
#   '먹고',
#   '있답니다.'],
#  ['나도',
#   '코카',
#   '콜라',
#   '별로',
#   '던데',
#   '..',
#   '왜',
#   '좋아',
#   '하는',
#   '지',
#   '모르',
#   '겠음',
#   '..',
#   '처음',
#   '에',
#   '쫌',
#   '따고',
#   '있다',
#   '가',
#   '먹으면',
#   '김',
#   '다',
#   '빠져',
#   '서',
#   '싫음',
#   '..'],
#  ['바삭할땐',
#   '아',
#   '무리',
#   '부먹',
#   '파여도',
#   '찍먹',
#   '을',
#   '하셔야',
#   '됩니다',
#   '부먹',
#   '파',
#   '행',
#   '님들',
#   '담먹',
#   '이라',
#   '도',
#   'ㅠㅠ',
#   '펩시',
#   '는',
#   '사랑',
#   '이거',
#   '~~'],
#  ['펩시',
#   '가',
#   '코카',
#   '보다',
#   '탄산',
#   '적고',
#   '더',
#   '달아서',
#   '난',
#   '개인적',
#   '의로',
#   '코카',
#   '가낫던데'],
#  ['콜라', '나', '펩시', '나어자피', '위에', '들어', '가면', '똑같', '음', 'ㅋㅋ'],
#  ['부먹', '불편', '코카', '편안'],
#  ['코카', '콜라', '보고', '구리다고', '하는', '이런', '..', '..'],
#  ['저',
#   '원려',
#   '코카',
#   '콜라',
#   '파',
#   '였는데',
#   '펩시',
#   '자주',
#   '먹어',
#   '서',
#   '펩시',
#   '파됬',
#   '어여',
#   'ㅋㅋ',
#   '그',
#   '래도',
#   '난',
#   '찍먹',
#   '이닷!'],
#  ['짜장면',
#   '다',
#   '먹고',
#   '선',
#   '소스',
#   '일부',
#   '터',
#   '안',
#   '먹고',
#   '나중에',
#   '밥비벼',
#   '먹으면',
#   '개',
#   '꿀맛',
#   '~'],
#  ['부먹',
#   '은',
#   '원래',
#   '그렇게',
#   '나와',
#   '서',
#   '그렇',
#   '다',
#   '쳐도',
#   '좀',
#   '불ㅡ',
#   '편이',
#   '었는데',
#   '코카',
#   '는',
#   '따는',
#   '소리',
#   '가',
#   '역시',
#   '넘',
#   '청량하네요',
#   '귀정화하고',
#   '갑니다',
#   '~',
#   'ㅎㅎ'],
#  ['지나가',
#   '는',
#   '탄산',
#   '충인데',
#   '펩시',
#   '는',
#   '사실',
#   '콜라',
#   '향이',
#   '있는',
#   '탄산',
#   '음료',
#   '라구요',
#   '!!',
#   '!'],
#  ['여기',
#   '찍먹',
#   '충들',
#   '너무',
#   '불편',
#   '에',
#   '하네',
#   '너불님',
#   '취향',
#   '도',
#   '좀',
#   '존중해주세요.',
#   '여기',
#   '오다가',
#   '주웠다.',
#   '좋아',
#   '요를',
#   '누르',
#   '며'],
#  ['ㅎ', '펩시', '파', '소리', '질러', '~~~~~~~~~~'],
#  ['나는', '콜라', '면다', '맛있', '다'],
#  ['모든', '탄산', '음료', '개봉', '할때', '천천', '따면', '다', '김빠지는소리나는데,', 'ㅋㅋ', 'ㅋ'],
#  ['아', '..', '.', '끔찍', '하다', '팹시', '파에', '부먹', '이라니', '..', '..', '..'],
#  ['러불찡이', '부먹', '이라', '면', '나도', '오늘', '부터', '..', 'ㅎㅎ'],
#  ['요즘',
#   '업소용',
#   '콜라',
#   '탄산',
#   '이',
#   '너무',
#   '없어',
#   '..',
#   '..',
#   '따로',
#   '사',
#   '먹는',
#   '게',
#   '더좋음'],
#  ['콜라', '는', '코카', '콜라', '만이', '콜랍니다'],
#  ['내가', '좋아', '하는', '탕짜면', '을', '..', '.', '스팸구워먹어야지', '..'],
#  ['너불님',
#   '사람',
#   '마다',
#   '취향',
#   '은',
#   '다릅니다.그렇게',
#   '너불님',
#   '이',
#   '펩시',
#   '를',
#   '좋아',
#   '하신다고',
#   '코카',
#   '콜라',
#   '를',
#   '하찬게',
#   '보지',
#   '않았으면',
#   '좋겠습니',
#   '당.',
#   '이건',
#   '너불님',
#   '에',
#   '대한',
#   '저의',
#   '생각',
#   '이니',
#   '심하',
#   '게',
#   '받아드리지',
#   '않았으면',
#   '좋',
#   '겠네',
#   '요'],
#  ['멋사',
#   '님의',
#   '해',
#   '명이',
#   '필요',
#   '하',
#   '네요',
#   '코카',
#   '따는',
#   '소리',
#   '가',
#   '코캌',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '이라는',
#   '말을',
#   '들었는데',
#   '전혀',
#   '아니',
#   '군요',
#   '..',
#   '.'],
#  ['펩시', '는', '달고', '코콜은', '탄산', '인데', '..', '..', '취양', '존중', '좀'],
#  ['지금', '코카', '보고', '탄산', '없다', '고', '그러신건가요', '??', '불편', '하', '네요'],
#  ['탄산',
#   '은',
#   '코카',
#   '가더',
#   '많은',
#   '디',
#   '그리고',
#   '조금',
#   '따놓고',
#   '따면',
#   '탄산',
#   '다나',
#   '가져',
#   '..',
#   '..'],
#  ['솔찍', '저', '짜장면', '은', '나한테', '한입', '컷', '당할듯'],
#  ['난주는대로머거서',
#   '코카',
#   '펩시',
#   '안',
#   '따지고',
#   '나는주먹이라그딴거무',
#   '시',
#   '한다',
#   '!',
#   '주먹',
#   '은',
#   '주는대로먹는다'],
#  ['아', '..', '짜장면', '먹고', '싶다', '..', 'ㅠ'],
#  ['너무', '좋아', '요', '짝짝', '짝'],
#  ['코카',
#   '나',
#   '펩시',
#   '나',
#   '코막고',
#   '먹으면',
#   '맛',
#   '똑같',
#   '음',
#   'ㅋㅋ',
#   '찍먹',
#   '이든',
#   '부먹',
#   '이든',
#   '배속에',
#   '들어',
#   '가면',
#   '같고',
#   'ㅋㅋ'],
#  ['너불님',
#   'ㅜㅜ',
#   '캠?인가',
#   '계속',
#   '초점',
#   '맞출려고',
#   '하는',
#   '게',
#   '자주',
#   '보여',
#   '서',
#   '보기',
#   '가',
#   '좀',
#   '들엉여유ㅠ'],
#  ['너불님',
#   '근데',
#   '코카',
#   '가',
#   '탄산',
#   '이',
#   '펩시',
#   '보다',
#   '많고',
#   '펩시',
#   '가',
#   '코카',
#   '보다',
#   '당도가',
#   '높아',
#   '요'],
#  ['코카',
#   '라서',
#   '불편',
#   '한',
#   '사람',
#   '편한',
#   '사람',
#   '한테',
#   '물어보겠는데',
#   '코카',
#   '랑',
#   '펩시',
#   '둘다',
#   '섞여있으면',
#   '어쩔거임'],
#  ['구냥', '닥치고', '먹어', '요'],
#  ['코카', '콜라', '여', '영원하라', '펩시', '는', '안돼!안된다고!'],
#  ['제가',
#   '이걸보며',
#   '코카',
#   '를',
#   '먹고',
#   '있죠',
#   '헤',
#   '나는',
#   '펩시',
#   '파',
#   '인데',
#   '..',
#   '.',
#   '코카',
#   '가',
#   '왔네요',
#   '..',
#   '..'],
#  ['너부리', '님', '편의점', '에', '위대한', '닭다리', '먹어달란마리야아아ㅏ'],
#  ['난',
#   '펩시',
#   '랑',
#   '코카',
#   '랑',
#   '뭔',
#   '차이',
#   '가',
#   '있는',
#   '질',
#   '모르',
#   '겄다',
#   '차이',
#   '점좀',
#   '알려주세요ㅠㅅㅠ'],
#  ['찍먹', '파', '인데', '너불님', '부먹', '보고', '부먹', '으로', '먹고', '싶다', '사실', '쳐먹'],
#  ['다', '좋은데', '부먹', '이', '불편', '..', '..', '..'],
#  ['네',
#   '콜라',
#   '따는',
#   '소리',
#   '치이익',
#   '이라고',
#   '하는',
#   '너불님',
#   '은',
#   '지금',
#   '콜라',
#   '을',
#   '마시고있습니다'],
#  ['나도', '부먹', '이랑', '펩시', '충인데'],
#  ['탕짜면', '비싸', '다', '우리', '쪽', '짜장면', '은', '원인데', '탕수육', '이', '비싼건가', '..'],
#  ['그', '와중에', '콜라', '코카', '콜라', '임', 'ㅋㅋ', 'ㅋ'],
#  ['쓰아아아앙', '윾시', '짜장', '이랑', '탕수육', '은', '최고', '야'],
#  ['슈바러마', '코카', '콜라', '욕하', '지', '마라'],
#  ['콜라', '열때', '김빠졌다고', '하시는', '거', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋ'],
#  ['코카', '가', '그', '정도', '면', '펩시', '는', '소리', '도', '없', '..', '..'],
#  ['코카', '콜라', '보다', '펩시', '가', '마싯어~'],
#  ['유독',
#   '너불님',
#   '먹방',
#   '에서',
#   '부',
#   '찍먹',
#   '코카',
#   '펩시',
#   '가',
#   '나뉘는거는',
#   '기분',
#   '탓인가',
#   'ㅋㅋ',
#   'ㅋㅋ'],
#  ['전쟁',
#   '을',
#   '선고한다',
#   '어디서',
#   '위대한',
#   '코카',
#   '를',
#   '건드려',
#   '이',
#   '놈이!!!',
#   '오늘',
#   '부터',
#   '코카',
#   '의',
#   '자존심을',
#   '걸어서',
#   '전쟁한다.'],
#  ['흠',
#   '..',
#   '.',
#   '혹시',
#   '여기',
#   '저와',
#   '같은',
#   '소스안먹,스프라이트',
#   '분들',
#   '있나요',
#   '..',
#   '??',
#   '?'],
#  ['편집', '깜유님', '핑짱하고', '추억쌓인', '짜장면'],
#  ['??', '코카', '가', '더', '탄산', '이', '센걸로아는데..', '잘못안건가', '..'],
#  ['너불님', '!!', '!', '칠성', '사이다', 'vs', '스프라이트'],
#  ['오프닝', '래퍼', '수준', 'ㅋㅋ', 'ㅋㅋ', 'ㅋ'],
#  ['댓글',
#   '에',
#   '왜',
#   '찍먹',
#   '에',
#   '펩시',
#   '파는',
#   '보이',
#   '지',
#   '않을까',
#   '..',
#   '난',
#   '찍먹',
#   '에',
#   '펩',
#   '신데'],
#  ['부먹',
#   '이든',
#   '찍먹',
#   '이든',
#   '펩시',
#   '든',
#   '코카',
#   '든',
#   '똑같',
#   '은',
#   '탕수육',
#   ',콜란데',
#   '걍',
#   '처묵',
#   '합시다',
#   '여러분'],
#  ['펩시', '보다', '코카', '콜라', '가', '더', '탄산', '이', '많은데', '..', '..'],
#  ['이거',
#   '새벽',
#   '시에',
#   '찍었다는건',
#   '안비밀',
#   '남순,만득,',
#   '핑맨',
#   ',',
#   '너불님',
#   '끼리',
#   'Gta',
#   '습격한',
#   '후에',
#   '한',
#   '먹방'],
#  ['..',
#   '.내',
#   '귀ㅣ',
#   '..',
#   '.',
#   '소리',
#   '크게',
#   '해놨는데',
#   '..',
#   '.',
#   '소리',
#   '작은',
#   '중력님',
#   '인줄',
#   '..'],
#  ['펩시', '가', '오려', '탄산', '적은', '데', '개', '소리'],
#  ['부먹',
#   '불편',
#   '코카',
#   '편안',
#   '찍먹',
#   '에',
#   '코카',
#   '파',
#   '부먹',
#   '편안',
#   '코카',
#   '불편',
#   '부먹',
#   '에',
#   '펩시',
#   '파',
#   '부먹',
#   '불편',
#   '코카',
#   '불편',
#   '??',
#   '!',
#   '??',
#   '!'],
#  ['대부분', '부먹', '이면', '펩시', '던데', '전', '부먹', '코카', '입니다', '매우', '편안'],
#  ['탕수육', '은주', '먹이', '죠', '주는대로먹는다'],
#  ['찍먹',
#   '이든',
#   '부먹',
#   '이든',
#   '펩시',
#   '든',
#   '코카',
#   '콜라',
#   '든',
#   '거서건데',
#   '왜들',
#   '편갈하냐',
#   '이해XX'],
#  ['너불님', '이', '먹방', '할때', '입고', '계신옷', '먼지좀', '알수', '있을까요?'],
#  ['너불님', '젓가락', '운은', '미국', '갔어!', '아니', '야', '천국행이겠지~'],
#  ['코카', '와', '펩시', '가', '싸울', '때', '맥콜은', '평화롭지'],
#  ['근데', '배달올때', '소스에담가져나오면', '부먹', '이', '아니', '라', '담먹', '되지않음?', 'ㅎㅎ', 'ㅎ'],
#  ['잠만', '..', '갑자기', '짜장면', '먹고', '싶잖아', '..', '.'],
#  ['음식',
#   '때문에',
#   '논쟁',
#   '이라',
#   '..',
#   '.',
#   '그냥먹으면안되나요?',
#   '서로취향존중하면서지',
#   '냅시다',
#   '저는',
#   '콜라',
#   '든',
#   '탕수육',
#   '이든',
#   '있는',
#   '대로',
#   '먹습니다',
#   '소스',
#   '따로',
#   '면',
#   '찍먹',
#   '인거고',
#   '부어져서나오면',
#   '부먹',
#   '합니다'],
#  ['원',
#   '탕짜면',
#   '..',
#   '.',
#   'ㄹㅇ',
#   '혜자',
#   '아닌가',
#   '..',
#   '모든',
#   '중국집',
#   '이',
#   '저랬으면',
#   '..',
#   '.'],
#  ['인사는',
#   '좋은데',
#   '넘',
#   '빨리',
#   '말하',
#   '고',
#   '소란',
#   '스러워요',
#   '..',
#   '.',
#   '악플은',
#   '아니',
#   '에요',
#   '..',
#   '이해',
#   '해주세',
#   '요'],
#  ['너불님', '..', '.', '펩시', '파', '라고', '하셨', '자나', '여', '..', '.', '!!'],
#  ['난', '콜라', '는', '펩시', '든', '코카', '든', '걍', '먹음', '둘이', '맛', '똑같', '던데'],
#  ['펩시',
#   '는',
#   '펩시',
#   '이이',
#   '이이',
#   '..',
#   '.',
#   '이러고',
#   '코카',
#   '는',
#   '코홐!',
#   '카핰!',
#   '하는',
#   '게',
#   '정상아님?'],
#  ['캬~침',
#   '꼴깍',
#   '넘어가',
#   '는',
#   '소리',
#   '들려',
#   '요',
#   '~~~',
#   '!',
#   '너무',
#   '좋아',
#   '요',
#   '~~~'],
#  ['저는',
#   '부먹',
#   '에',
#   '코카',
#   '입니다',
#   '.',
#   '후후',
#   '이',
#   '영상',
#   '마음',
#   '에',
#   '드는군요.',
#   '내',
#   '마음',
#   '속에',
#   '저장'],
#  ['gta', '끝나고', '먹으시던게', '올라왔네용~'],
#  ['맛있', '겠다', '!침흐른다', '..', '.'],
#  ['콜라', '는', '펩시', '죠', '누간', '요즘', '코카', '먹습니', '까?'],
#  ['코카', '콜라', '욕하', '지', '마세', '여'],
#  ['시작', '이', '요란스러워서', '맘에든다', '이미지랑', '찰떡', '쓰.'],
#  ['저는',
#   '악어',
#   '님과',
#   '같은',
#   '혼종',
#   '파',
#   '입니다',
#   ',',
#   '그리고',
#   '찍먹',
#   '인데',
#   '우리',
#   '가족',
#   '은',
#   '다',
#   '부먹',
#   '이야',
#   '..',
#   '.'],
#  ['코카',
#   '콜라',
#   '구리다고해서',
#   '구독',
#   '취소',
#   '했다',
#   '.',
#   '콜라',
#   '는',
#   '코카',
#   '콜라',
#   '지',
#   '..'],
#  ['너불님', '도', '코카', '충은', '펩시', '보면', '뭐라한다는데', '너불님', '도', '같음', 'ㄱㄱ', 'ㄱ'],
#  ['근데',
#   '부먹',
#   '은',
#   '거의',
#   '펩시',
#   '고',
#   '찍먹',
#   '은',
#   '거의',
#   '코카',
#   '다',
#   '난',
#   '혼종',
#   '이라는',
#   '건',
#   '안비밀'],
#  ['오늘', '점심', '이거', '먹어', '는디'],
#  ['코카', '콜라', '무슨', '맛', '으로', '먹지', '?'],
#  ['우리', '동네엔', '저렇게', '파는', '데', '없는', '데', '부럽', '네요', 'ㅠ', '으어', '맛있', '겠다'],
#  ['펩시',
#   '와',
#   '코카',
#   '를',
#   '가리지',
#   '않는',
#   '혼종',
#   '이지만',
#   '펩시',
#   '가',
#   '가격',
#   '이',
#   '더',
#   '싸서',
#   '펩시',
#   '만',
#   '사ㅁ',
#   '..',
#   '..'],
#  ['저도', '펩시', '파', '입니다'],
#  ['부먹', '이', '맛있', '는데', '코카', '는짜릿', '하고', '펩시', '는', '맛있', '어'],
#  ['저는', '둘다', '파'],
#  ['아으', '펩시', '충', '펩시', '는', '콜라', '아니', '야', '!!', '!'],
#  ['너불님', '탄산', '은', '코카', '가', '더', '강한데', '..', '.'],
#  ['난', '노먹판데', '..', '.헿', '탕수육', '소스', '가', '맛이', '없어', '서라죠'],
#  ['부먹', '펩시', '짱'],
#  ['펩시',
#   '에',
#   '부먹',
#   '?',
#   '좋아',
#   '요',
#   '번',
#   '누릅니다.',
#   '물론',
#   '댓글',
#   '달기',
#   '전에',
#   '한번',
#   '눌러',
#   '서',
#   '누적',
#   '번이',
#   '죠'],
#  ['코카', '편', '안'],
#  ['싫어',
#   '요',
#   '부먹',
#   '싫어',
#   '하는',
#   '사람',
#   '이나',
#   '코카',
#   '콜라',
#   '좋아',
#   '하는',
#   '사람',
#   '이닼',
#   'ㅋㅋ'],
#  ['특수채널용은', '머임?', 'ㅋㅋ', 'ㅋ'],
#  ['코카', '딸때', '치이이이이이~', '김빠지는', '소리', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋ'],
#  ['펩시', '여부할', '하라', '!!', '!!', '!'],
#  ['저는', '찍먹', '부먹', '둘다', '하고', '코카', '먹어', '요', '..', '.ㅋ'],
#  ['너불님', '박수개잘친다'],
#  ['코카', '콜라', '가', '좀더', '좋지않나?'],
#  ['젓가락', '뒷부분', '잡고', '때면', '등분되요'],
#  ['갑자기', '짜장면', '먹고', '싶다'],
#  ['찍먹',
#   '이고',
#   '부먹',
#   '이고',
#   '다',
#   '필요',
#   '없쒀',
#   '!!',
#   '!',
#   '난',
#   '처먹',
#   '이다',
#   '!!',
#   '자고로',
#   '음식',
#   '은',
#   '처먹',
#   '어야',
#   '제맛ㅎ'],
#  ['너불님', '항상', '한입', '먹을', '때마다', '안경', '쓰윽'],
#  ['코카', '가더', '마싯', '지', '펩시', '줫밥'],
#  ['저는',
#   '탕수육',
#   '을',
#   '찍먹',
#   '도',
#   '부먹',
#   '도',
#   '아닌',
#   '담먹',
#   '입니다',
#   '저는',
#   '탕수육',
#   '을',
#   '소스',
#   '에',
#   '담궈먹어요',
#   'ㅋㅋ'],
#  ['짬국', '입먹네', '..', '..', '.불', 'ㅡㅡ', 'ㅡ편'],
#  ['너불님', '꽈투룹', '닳으셨엉'],
#  ['맞다맞다', '코카', '보단', '펩시', '지!'],
#  ['난', '부먹', '파', '거러다가', '언', '니들', '한테', '욕을', '아주', '맛있', '게', '크윽'],
#  ['나는', '코카', '가', '탄산', '이', '더', '쎄던데'],
#  ['중화요리', '평소', '에', '많이', '먹어', '주세요', 'ㅎㅎ'],
#  ['저',
#   '..',
#   '.',
#   '코카',
#   '..',
#   '.',
#   '좋아',
#   '하는',
#   '데요',
#   '..',
#   '.',
#   '울먹',
#   '이런',
#   '시청자',
#   '는',
#   '싫어',
#   '하시',
#   '나요',
#   '?',
#   '울먹'],
#  ['콜라', '는', '코카', '지'],
#  ['펩시', '충?', '코카', '충?', '따', '꺼져', '!', '콜라', '는!', '옐로우', '콜라', '지!'],
#  ['아', '너무', '기엽ㅂ자나'],
#  ['코카', '콜라', 'ㅠ', '욕하', '지', '마요', '펩시', '는', '노맛', '동의', '어', '보겸'],
#  ['너불', '이', '부먹', '코카', '네용'],
#  ['찍먹', '부먹', '신경', '안', '쓰는', '끔찍한', '혼종', '이', '짱', '!', '그렇', '지만', '부펩스다'],
#  ['저는', '코카', '에', '찍먹', '이', '에요'],
#  ['소리', '좋은데', '..', '.', '그', '래도', '저느', '스프라이트', '가', '제일', '좋아', '요!'],
#  ['계급표', '혼종', '찍먹', '부먹', '코카', '펩시', '콜라', '극혐'],
#  ['너불님', '부먹', '이네', '저도', '부먹', '이예요'],
#  ['부먹', '에', '펩시', '라니', '저랑', '천생연분이네요'],
#  ['펩시', '가', '좋지'],
#  ['와',
#   '부먹',
#   '눅눅',
#   '한거',
#   '봐',
#   '불',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   '편',
#   '코카',
#   '편',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   'ㅡㅡ',
#   '안'],
#  ['코카', '싫어', '하는', '사람', '처음', '봄'],
# ...
#   '와',
#   '펩시',
#   '둘',
#   '다',
#   '좋아',
#   '하는',
#   '혼종',
#   '이져',
#   '..'],
#  ['완전', '맜있', '겠다'],
#  ['존나', '나대면서', '먹네', '조용', '쳐먹', '지'],
#  ['코카', '콜라', '짱', '~~~~~', '~', '!!', '!!', '!!'],
#  ['먹방', '너무', '조아', '여~'],
#  ['너불님', '사랑해', '욤'],
#  ['자신이', '잘', '못따쓰면서', '이상', '한', '말하', '네'],
#  ['너불님', '너무', '쫑아요!~!!', '짝짝', '짝짝'],
#  ['부먹', '불편'],
#  ['너불님', '멏살이에요?'],
#  ['분이', '이렇게', '빨리', '지나가', '다니', '..', '!'],
#  ['보니까', '짬뽕', '먹고', '싶어', '진다', '..'],
#  ['나', '블님', '너무', '귀여', '워여'],
#  ['부먹', '은', '부워서', '먹는', '거고', '찍먹', '은', '찍어', '서', '먹는', '거임?'],
#  ['저는', '코카', '파임다'],
#  ['코카', '만세'],
#  ['쳐먹', '파를', '찬양', '하라', '~!'],
#  ['코카', '파여', '일어나라', '!!', '!', 'ㅋㅋ', 'ㅋ'],
#  ['싫어', '요', '누규냐?'],
#  ['젓가락', '불편'],
#  ['코카', '콜라', '극혐', '~'],
#  ['부먹', '불', 'ㅡㅡ', 'ㅡ편', 'ㅋㅋ', 'ㅋ'],
#  ['너불님', '너무', '좋아', '요o'],
#  ['이거',
#   '보고',
#   '언니',
#   '랑',
#   '짜장면',
#   '시켜',
#   '먹기',
#   '로',
#   '했어요',
#   '너무',
#   '좋아',
#   '여',
#   '~~',
#   '짝짝',
#   '짝짝'],
#  ['너불님',
#   '과',
#   '같은',
#   '부먹',
#   '에',
#   '펩시',
#   '여서',
#   '행복',
#   '하고',
#   '제가',
#   '탕수육',
#   '엄청',
#   '좋아',
#   '하는',
#   '데',
#   '맛있',
#   '것다',
#   '..',
#   '..'],
#  ['부먹', '불편', '코카', '편안'],
#  ['역시', '너불님', '너무', '조아', '여~', '짝짝', '짝짝'],
#  ['잠깐', '너불님', '이', '코카', '를', '?!'],
#  ['아ㅏ',
#   '콜라',
#   '카',
#   '코카',
#   '자너?',
#   '불',
#   'ㅡㅡ',
#   '편할',
#   '뿐',
#   '오늘',
#   '펩시',
#   '랑',
#   '코카',
#   '랑',
#   '같이먹으니까',
#   '확연',
#   '펩시',
#   '가',
#   '맛있',
#   '더라구영ㅇ',
#   '먼가',
#   '코카',
#   '는',
#   '밍밍해여..'],
#  ['너굴님',
#   '너무',
#   '사랑',
#   '스러',
#   '운데',
#   '여기',
#   '서',
#   '어떻게',
#   '더',
#   '방송',
#   '을',
#   '더',
#   '챙겨볼지를모르겠네요',
#   'ㅎㅎ'],
#  ['완전', '맛있', '어', '보여', '요', 'ㅜㅜ'],
#  ['부먹', '불', 'ㅡㅡ', '울', 'ㅡㅡ', '편'],
#  ['코카', '가', '뭐', '어때서여', '!!', '!!', '!'],
#  ['너불님',
#   '코카',
#   '는',
#   '탄산',
#   '이',
#   '없지만',
#   '맛',
#   '잇고',
#   '펩시',
#   '는',
#   '탄산',
#   '은',
#   '많은데',
#   '맛이',
#   '별로',
#   '에여',
#   '그니까',
#   '너불님',
#   '은',
#   '탄산',
#   '파',
#   '라는',
#   '말씀',
#   '제의견',
#   '이라',
#   '그럽니다',
#   '욕하',
#   '고',
#   '싶어',
#   '도',
#   '참아',
#   '주세',
#   '여'],
#  ['너불님', '보다', '탕짜면', '에', '눈이간다.'],
#  ['싫어', '요', '개', '너무', '좋아', '요'],
#  ['너불님', '은', '나랑', '입맛이', '안맛아'],
#  ['부먹', '편', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', '안'],
#  ['찍먹', '펩시', '손', '~~'],
#  ['어디', '집이에요', '탕짜면'],
#  ['빨', '먹을', '원한다'],
#  ['부먹', '너무', '조아요', '짝짝', '짝짝', '짝짝'],
#  ['펩.시.공.조.아'],
#  ['너무', '좋아', '영', '~~~~~~~~', '짝짝', '짝짝', '짝짝'],
#  ['배달하시는분들', '너무', '추우시', '겠다'],
#  ['코카', '찍먹', '너무', '조아요', '짝짝', '짝짝'],
#  ['헐', '배고', '파', '..'],
#  ['난', '찍먹', '에', '펩시', '다', '!!'],
#  ['배고', '프단', '말이야', '~!~!~!~!~!', '~!'],
#  ['끔찍한', '혼종', '들', '모여라!'],
#  ['부먹', '불', 'ㅡㅡ', 'ㅡㅡ', '편'],
#  ['코카', '불편'],
#  ['노란딱지', '..', '..', 'ㅠ'],
#  ['그거', '어디서', '팔아', '염?'],
#  ['패', '원짜리'],
#  ['코카', '가', '원조지', '!!'],
#  ['그냥', '뱃속에', '들어', '가면', '다', '똑같', '다'],
#  ['구독', '취소', '할거얍'],
#  ['개', '귀엽', '다', 'ㅋㅋ', 'ㅋ', '진짜'],
#  ['이', '영상', '을', '멋사', '님이', '싫어', '하', '십니다'],
#  ['쳐묵파는', '편안', '하다', '..'],
#  ['부먹', '불편', '코카', '편안'],
#  ['부먹', '찍먹', '보단', '걍', '쳐먹'],
#  ['부먹', '너무', '좋아', '요', '~~'],
#  ['부먹', '불편', '코카', '편안'],
#  ['혼종', '모이세요.'],
#  ['난', '걍', '쳐먹', '이라', '상관', '업다', '..'],
#  ['시작', '할때', '깜놀', 'ㅋ'],
#  ['코카', '콜라', '비하하는거?'],
#  ['코카', '편', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ안'],
#  ['너불님',
#   '많이',
#   '배고',
#   '프셨나',
#   '봐요',
#   '..',
#   '이렇게',
#   '말수',
#   '많이',
#   '적어',
#   '든거',
#   '처음',
#   '봐요',
#   '..',
#   '밥',
#   '제때제때',
#   '챙겨',
#   '드시',
#   '세요',
#   'ㅠㅠ'],
#  ['너불님', '이', '너무', '좋아', '여'],
#  ['난', '혼종', '인데', '..', '.'],
#  ['엇', '코카', '콜라', '?!'],
#  ['너불님', '은', '손도', '빛나', '요.'],
#  ['보고', '시켰', '더'],
#  ['너불님', '정수리가', '..', '.'],
#  ['난', '코카', '파', '인데', '..', '..', '..', '..', 'ㅠㅠ'],
#  ['!', '부먹', '파', '!', '펩시'],
#  ['지나가',
#   '던',
#   '부먹',
#   '이항',
#   '펩시',
#   '파',
#   '인데',
#   '좋아',
#   '요',
#   '누르',
#   '고',
#   '갑니',
#   '당',
#   '구독',
#   '은',
#   '당연'],
#  ['귀여', '웤', 'ㅋㅋ', 'ㅋ'],
#  ['펩시', '짱'],
#  ['먹방이제일인기많아', 'ㅋㅋ', '너불님', '사랑해', '여'],
#  ['부먹', '너무', '좋아', '요', '!!'],
#  ['나두', '한입만', '..', '!'],
#  ['탕짜면', '너무', '좋아', '요~', '짝짝', '짝'],
#  ['나는', '소스', '없이', '먹는', '데'],
#  ['어어?이쏴람이',
#   '주작을?!',
#   '펩시',
#   '는',
#   '가라',
#   '코카',
#   '가',
#   '갑이',
#   '다',
#   '!!',
#   '라고',
#   '끔찍한',
#   '혼종',
#   '이',
#   '말',
#   '합니다'],
#  ['코카', '를', '무시', '한좌로', '젓가락', '이부', '서졌다'],
#  ['귀', '아파'],
#  ['혼종', '파', '손ㅋ'],
#  ['꺄', '먹방', '넘흐', '좋아', '요'],
#  ['맛있', '겠네', '요', '..', '.침주륵', '탕짜면', '이라니이', '..', '.'],
#  ['나도', '먹고', '싶당', '..', '..'],
#  ['불만이', '많노'],
#  ['마리오', '..', '.?'],
#  ['아유', '복스럽', '게', '잘', '먹으', '신다'],
#  ['형은',
#   '다',
#   '괜찮',
#   '은거',
#   '같은',
#   '데',
#   '부먹',
#   '인거랑',
#   '펩시',
#   '가',
#   '제일',
#   '문제',
#   '야',
#   '..',
#   '..',
#   '.'],
#  ['코카', '불', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ편'],
#  ['부먹', '!', '부먹', '!'],
#  ['ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋ', '개웃', '곀', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ'],
#  ['크', '..', '..', '흠', '부먹', '크', '..', '..', '..', '.흠'],
#  ['마시게따,,,,'],
#  ['나는', '혼종', '이다', '한마디로', '반', '나두어서', '한쪽은', '부먹', '한쪽은', '찍먹', '함'],
#  ['부먹', '파', '!!', '!'],
#  ['너무', '맛있', '어', '보여', '요', '짝짝', '짝짝'],
#  ['불', 'ㅡㅡ', 'ㅡ편'],
#  ['나무', '젓가락', '쪼개는거', '실패했을때', '겁나', '웃었', '넼', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋ'],
#  ['코카', '편안'],
#  ['펩시', '가', '더낫지'],
#  ['코카', '무엇', '?', '불편', '!', 'ㅡㅡ'],
#  ['아', '..', '.', '맛있', '겠다', '..'],
#  ['귀엽', '당'],
#  ['코카', '불편'],
#  ['난', '탕수육', '은', '오로지', '간장에', '찍어', '먹는', '뎀', '..'],
#  ['엌', 'ㅋㅋ', 'ㅋㅋ', '귀여', '웤', 'ㅋㅋ'],
#  ['코카', '편', 'ㅡㅡ', 'ㅡ안'],
#  ['코카', '가', '뭐임', '??', 'ㅋ'],
#  ['안녕하', '십니', '까?', '이온', '음료', '파', '입니다'],
#  ['부먹', '불편'],
#  ['아', '미친', 'ㅠㅠ', 'ㅠㅠ', 'ㅠ', '배고', '파', 'ㅠㅠ', 'ㅠㅠ', 'ㅠ'],
#  ['너불님', '좋아', '하지만', '제가', '코카', '파에', '부먹', '파인뎅.', '크흠', '..'],
#  ['펩시',
#   '좋아',
#   '하는',
#   '사람',
#   '은',
#   'ㅈ을쓰고',
#   '코카',
#   '콜라',
#   '좋아',
#   '하는',
#   '사람',
#   '은',
#   'ㅊ을',
#   '쓰세요'],
#  ['맛있', '겟다'],
#  ['맛있', '겠따'],
#  ['맛있', '겠다'],
#  ['너불님', '이', '부먹', '이었', '다니', '..', '..', '.!', '하지만', '괜찮', '아.'],
#  ['나는', '담가먹고,', '탄산', '을', '안', '마시', '지', '..', '.'],
#  ['배고', '프다'],
#  ['코카', '손', '!!', '!'],
#  ['난', '솔직', '코카', '든', '펩시', '든', '알빠아니고', '그냥', '먹는', '데'],
#  ['불', 'ㅡㅡ', 'ㅡ편'],
#  ['너불님', '의', '너무', '좋아', '요를', '반복해서', '듣기', '위해', '적는', '댓글', '이다'],
#  ['정수리가', '많이', '비었는데', '탈모인가요?'],
#  ['오늘', '구독', '했는데', '추천', '채널에', '달자', '님이', '..', '.'],
#  ['너불님', '수전증', '썰??'],
#  ['그저', '먹는', '영상', '인데', '왜이렇게', '사랑', '스럽지?'],
#  ['멋X', '저는', '천성', '부먹', '이', '에요'],
#  ['맜있', '겠다'],
#  ['코카', '콜라', '비하', '발언'],
#  ['맛있', '겠당'],
#  ['훗', '나는', '쳐먹', '이다', '!!', '관종', '임'],
#  ['찍먹', '이든', '부먹', '이든', '팹펩?시든', '코카', '든', '맛만', '있으면', '됨'],
#  ['마씨께따'],
#  ['마씨께따'],
#  ['나는', '코카', '긴', '하지만', '팹시', '든', '코카', '든', '뭐든', '있음', '먹음'],
#  ['부먹', '에다', '펩시', '?', '역적이다!!!!!!'],
#  ['~', '악어', '님은', '??', '??', '자', '좋습니다', '여러분', '들', '한번', '먹어', '보겠습니다'],
#  ['부먹', '펩시', '불', 'ㅡㅡ', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ편'],
#  ['부.먹.을.찬.양.', '하.', '라'],
#  ['노란딱지', '영상', '..'],
#  ['귀', '뚤은거임?'],
#  ['귀걸이', '이뻐', '여', '!!', '!'],
#  ['난', '펩시', '별', '론데', '..', '.'],
#  ['저한테', '왜그러시져', '??'],
#  ['근데', '솔찍', '다', '맛있', '음'],
#  ['코카', '콜라', '편', 'ㅡㅡ', '안'],
#  ['부먹', '너무', '좋아', '요', '~~', '짝짝', '짝'],
#  ['부먹', '불편'],
#  ['부먹', '불', 'ㅡㅡ', 'ㅡㅡ', 'ㅡ편'],
#  ['어디서', '산거에요?'],
#  ['코카', '편안'],
#  ['부먹', '불편'],
#  ['저도', '펩시', '파!'],
#  ['콜라',
#   '소리',
#   '펩시',
#   '펩',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!!',
#   '!시!',
#   '이이',
#   '이이',
#   '이!'],
#  ['윾시', '팹시', '가'],
#  ['아니', '다'],
#  ['에휴', '그래서', '내가', '구독', '을', '안누른다'],
#  ['부먹', '불편'],
#  ['담먹', '짱'],
#  ['배고', '프다', '..', '.'],
#  ['대.리.만.족'],
#  ['펩시', 'ㄴㄴ', '갓카', '콜라', '가', '짱이', '에요'],
#  ['혼종', '인'],
#  ['코카', '따위는', '펩시', '한테안돼죠~~'],
#  ['저건', '..', '부먹', '이', '아닌', '..', '담먹', '담근', '후', '먹', '는다', '이다', '..'],
#  ['부먹', '펩시', '가', '짱이다!!!!!'],
#  ['안녕하세요', '쳐먹', '입니다', '.'],
#  ['븅신같다'],
#  ['광',
#   '숙이',
#   '엄청',
#   '컸네',
#   '요',
#   '..',
#   '..',
#   '이제',
#   '겨울',
#   '이랑',
#   '겨울',
#   '이',
#   '아버님',
#   '보다',
#   '도',
#   '더',
#   '클듯...'],
#  ['광',
#   '숙이',
#   '가',
#   '저렇게',
#   '음식',
#   '을',
#   '들고',
#   '카펫',
#   '위에',
#   '서',
#   '먹으면',
#   '서',
#   '흘리',
#   '고',
#   '하면',
#   '안그',
#   '래도',
#   '진드기와',
#   '먼지가',
#   '많을',
#   '카펫',
#   '이',
#   '더',
#   '더러워지고',
#   '그',
#   '위로',
#   '광',
#   '숙이',
#   '가',
#   '다니면',
#   '털이',
#   '나',
#   '이런',
#   '데',
#   '진드기',
#   '옮을수도있어요',
#   '물론',
#   '너불님',
#   '의',
#   '피부',
#   '나',
#   '기관지에도',
#   '안좋',
#   '구요',
#   '카펫은치우시는게',
#   '좋아',
#   '보여',
#   '욥'],
#  ['뭔가', '처음', '봤을', '때보다', '엄', '~~', '첨', '불어난거', '같은', '느낌', '?'],
#  ['여기', '가', '너구리', '랑', '라쿤', '이', '먹방', '하는', '유튜브', '채널인가요'],
#  ['댓글',
#   '에',
#   '간혹',
#   '나도',
#   '라쿤',
#   '키울까라는',
#   '분들',
#   '이',
#   '보여',
#   '서',
#   '걱정',
#   '되',
#   '네요',
#   '한',
#   '생명을',
#   '키운다는건',
#   '굉장',
#   '큰',
#   '책임감이',
#   '필요',
#   '한',
#   '일',
#   '입니다',
#   '너불님',
#   '이',
#   '라쿤',
#   '을',
#   '키우',
#   '네?',
#   '귀엽',
#   '네?',
#   '하고',
#   '쉽게',
#   '결정해서',
#   '키울일이',
#   '아니',
#   '라는',
#   '거죠',
#   '..',
#   '늪지대',
#   '의',
#   '시청자',
#   '연령층이',
#   '낮은만큼',
#   '반려',
#   '동물',
#   '을',
#   '키운다는것에',
#   '쉽게',
#   '생각',
#   '할',
#   '분들',
#   '이',
#   '많을',
#   '수',
#   '있기',
#   '때문에',
#   '너불님',
#   '도',
#   '광',
#   '숙이',
#   '를',
#   '컨텐츠',
#   '의',
#   '일종으로써',
#   '유튜브',
#   '에',
#   '노출시키시려면',
#   '좀',
#   '더',
#   '주의가',
#   '필요',
#   '해보',
#   '입니다',
#   '적어',
#   '도',
#   '영상',
#   '의',
#   '마지막에',
#   '반려',
#   '동물',
#   '을',
#   '키운다는건',
#   '큰',
#   '책임',
#   '이',
#   '필요',
#   '하다',
#   '는',
#   '문구',
#   '한줄이라도',
#   '남겨주셨으면',
#   '좋겠어요'],
#  ['ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㄱㅋㄱ', '그걸', '왜', '먹어', '봐요', 'ㅋㅋ', 'ㄱㅋ'],
#  ['동물', '의숲', '브금', '인거', '저만', '들리는건가요', '..', '.'],
#  ['끝쪽에',
#   '분가량의',
#   '정적뭔뎈',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '뭐',
#   '있는',
#   '줄',
#   '알고',
#   '기다려는데',
#   '아무것도',
#   '없엌',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ'],
#  ['시작',
#   '할',
#   '때',
#   '하는',
#   '브이',
#   '는',
#   '시그니처인가요!?',
#   'ㅋㅋ',
#   'ㅌㅋ',
#   'ㅌ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '꾸요',
#   '웡',
#   '!!'],
#  ['여기',
#   '부터',
#   '그냥',
#   '다',
#   '검은',
#   '색이',
#   '네여',
#   'ㅋㅋ',
#   '분동안',
#   '뭐',
#   '있는',
#   '줄',
#   '알고',
#   '계속',
#   '봤는데',
#   'ㅋㅋ'],
#  ['광',
#   '숙이',
#   '진짜',
#   '쑥쑥',
#   '크',
#   '네요',
#   '..',
#   '!',
#   '볼',
#   '때마다',
#   '크고',
#   '있는',
#   '것',
#   '같아요',
#   'ㅋㅋ',
#   'ㅋ',
#   '짱',
#   '귀여',
#   '워',
#   '그리고',
#   '같이',
#   '너불님',
#   '도',
#   '너무',
#   '너무',
#   '귀여',
#   '우심',
#   'ㅎㅎ',
#   '..',
#   '광',
#   '숙이',
#   '바라보는',
#   '눈빛이',
#   '사랑',
#   '스럽다는',
#   '눈빛이여서',
#   '너무',
#   '쪼아',
#   '욧',
#   'ㅠㅠ',
#   'ㅠ',
#   '항상',
#   '영상',
#   '재미',
#   '있게',
#   '잘',
#   '보고',
#   '가요',
#   '너불님',
#   '!',
#   '오늘',
#   '도',
#   '재밌',
#   '는',
#   '영상',
#   '고마워용',
#   'D'],
#  ['라쿤', '간식', '맛', '보는', '너구리'],
#  ['~', '??', '??', '공백의', '시간', '~'],
#  ['이빨봐', '한번', '물리면', '절단각인데?'],
#  ['ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '표정',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋ광',
#   '숙이',
#   '똑똑',
#   '하넼',
#   'ㅋㅋ',
#   'ㅋㅋ'],
#  ['광', '숙이', '가', '광', '숙이', '인지', '너불님', '인지', '좀', '더', '크면', '못알아보', '겠네'],
#  ['광', '숙이', '가', '너불님', '보다', '더', '어께가', '넓은듯'],
#  ['ㅇㅇ', '너불님', '보다', '큰것같음', '줜나', '큼', '..', '.'],
#  ['광', '숙이', '저거', '털이', '에요?', '살이에요?'],
#  ['제가',
#   '생각',
#   '하는',
#   '츄르',
#   '가',
#   '아니',
#   '라',
#   '고기',
#   '같은',
#   '츄르',
#   '도',
#   '있군요',
#   '전',
#   '짜서',
#   '주는',
#   '것만',
#   '있는',
#   '줄',
#   '알았',
#   '네용'],
#  ['포나', '곧', '시작하는데', '포나', '영상', '많이', '올려주세요', '너불님', '~'],
#  ['귤', '껍데기에', '농약', '때문에', '광', '숙이', '걱정', '됩니다', 'ㅜㅜ'],
#  ['광수가아아~',
#   '너불님',
#   '찡긋',
#   '너무',
#   '귀엽',
#   '잖아',
#   '리',
#   '..',
#   '.',
#   '리타',
#   '어?',
#   '츄르',
#   '+',
#   '닭가슴살',
#   '환상',
#   '의',
#   '조합',
#   '너불님',
#   '은',
#   '내가',
#   '안아줄게!',
#   '??????????',
#   '??',
#   '귤도',
#   '맛있',
#   '게',
#   '먹는',
#   '구만'],
#  ['안돼',
#   '넙쨩',
#   '..',
#   '!',
#   '고양이',
#   '전용',
#   '츄르',
#   '말고',
#   '사람',
#   '이',
#   '먹는',
#   '거',
#   '먹어',
#   '..',
#   'ㅠ',
#   '불쌍해',
#   '보인단말이얌',
#   '..',
#   'ㅠ'],
#  ['광', '숙이', '카메라', '각도', '왜', '안맞추냐고', '하니까', '봐주는것봐', 'ㅠㅠ', 'ㅠ', '귀요미'],
#  ['너굴~!맨', '!!'],
#  ['너불님', '언제', '나', '귀엽', '고', '멋져여~', '그리고', '광', '숙이', '도', '귀여', '워여~'],
#  ['침대',
#   '및',
#   '카',
#   '페트',
#   '?',
#   '광',
#   '숙이',
#   '털이',
#   '랑',
#   '색이',
#   '비슷비슷하네요~',
#   '설',
#   '..',
#   '마',
#   '..',
#   '과',
#   '..',
#   '광',
#   '숙이',
#   '털로',
#   '만',
#   '든거',
#   '아니',
#   '죠?'],
#  ['사랑해', '..', '..', '진짜', '물려도', '좋으니까', '안고', '싶다', 'ㅜㅠ'],
#  ['졸귀'],
#  ['광', '숙이', '많이', '컸어', '짜식', '..'],
#  ['근데', '라쿤', '은', '잡식성인가요?'],
#  ['광',
#   '숙이',
#   '랑',
#   '캠방',
#   '느무',
#   '좋아',
#   '여',
#   'ㅠㅠ',
#   'ㅠ',
#   '저',
#   '라쿤',
#   '키울까',
#   '고민중이거든여',
#   'ㅋㅋ'],
#  ['진심', '인트로', '보면', '볼수록', '너불님', '귀엽', '당!'],
#  ['광', '숙이', '랑', '같이', '해서', '동물', '의', '숲', '브금', '이', '나오', '나?'],
#  ['동물', '확대', '로', '신고하겠습니다'],
#  ['라쿤', '이', '귤도', '까먹', '네', 'ㅋㅋ', 'ㅋ', '똑똑', '하다'],
#  ['리타', '어', '아님', '??', '?', 'ㅋㅋ'],
#  ['너불', '이', '츄르', '잘먹', '네', '기특해라'],
#  ['털이',
#   'ㅠㅠ',
#   '어떻게',
#   'ㅠㅠ',
#   '안고',
#   '싶어',
#   'ㅠㅠ',
#   '날',
#   '물어',
#   '도',
#   '되니까',
#   '안고자고',
#   '싶어',
#   'ㅠㅠ'],
#  ['광',
#   '숙이',
#   '꿀',
#   '까먹',
#   '으면서',
#   '혓바닥',
#   '낼름하고',
#   '카메라쪽보는것도',
#   '귀엽',
#   '고',
#   '너불님',
#   '이',
#   '쓰담',
#   '할때',
#   '이리',
#   '있는',
#   '것도',
#   '귀엽',
#   '고',
#   '아몬드',
#   '안',
#   '뺏길려고',
#   '먹으면',
#   '서',
#   '하나',
#   '집고',
#   '있는',
#   '건',
#   '왜',
#   '이리사랑스러운지',
#   '..',
#   '.',
#   'ㅜㅠ',
#   '정말',
#   '광',
#   '숙이',
#   '사랑',
#   '받으',
#   '면서',
#   '살아라.',
#   '행복',
#   '하고',
#   '건강',
#   '해다오'],
#  ['오랜만에',
#   '방송',
#   '보러',
#   '왔는데',
#   '광',
#   '숙이',
#   '엄청',
#   '컸네',
#   '요',
#   '!!',
#   '!',
#   '귀여',
#   '워요',
#   'ㅠㅠ'],
#  ['열심', '먹네'],
#  ['광', '숙이', '..', '점점', '돼지', '가', '되간다', '..'],
#  ['아',
#   '광',
#   '숙이',
#   '진심',
#   '개',
#   '기여워',
#   'ㅜㅜ',
#   'ㅜㅜ',
#   'ㅠㅠ',
#   'ㅠㅠ',
#   'ㅠㅠ',
#   'ㅠㅠ',
#   '미쳣디',
#   '혹시',
#   '보통',
#   '라쿤',
#   '들은',
#   '식사량이',
#   '어느',
#   '정도',
#   '인지',
#   '알고',
#   '계신',
#   '분',
#   '있나요',
#   '??'],
#  ['하트주면사랑해요'],
#  ['광', '숙이', '털이', '길어진거', '맞죠?', '덩치', '가', '커진거', '아니', '죠?'],
#  ['너불님', '광', '숙이', '몸집이', '엄청', '커졌', '는데', '저거', '사실이에요?', '털이', '에요'],
#  ['광', '숙이', '최후', '의', '간식', '너불님'],
#  ['분명',
#   '..',
#   '.',
#   '라쿤',
#   '이',
#   '츄르',
#   '를',
#   '먹는',
#   '동',
#   '영상',
#   '인데',
#   '왜',
#   '너불님',
#   '이',
#   '츄르',
#   '를',
#   '먹는',
#   '거죠?'],
#  ['저', '반지퍼', '셔츠', '..', '다시', '봐도', '너무', '이쁜거', '같다', '..', '.', 'ㅎㅎ'],
#  ['귤', '껍질', '에', '농약', '없나요', '??', '?', '??'],
#  ['역시', '너불님', '은', '광', '숙이', '화가', '진행', '되는', '게', '맞는', '듯'],
#  ['너',
#   '블님',
#   '광',
#   '숙이',
#   '이름',
#   '왜',
#   '이렀게',
#   '지었나요',
#   '광',
#   '숙이',
#   '귀여',
#   '워요',
#   '광',
#   '숙이',
#   '씻기는',
#   '방법',
#   '올려주세요'],
#  ['뭐야', '이녀석', '개', '귀엽', '잖아', '??'],
#  ['광', '숙이', '중력님', '보다', '더', '클듯'],
#  ['귤', '유기농이겠죠?'],
#  ['라쿤', '은', '굴을', '까먹', '을수', '있엇다', '..', '..', '..'],
#  ['광', '숙이', '갑자기', '거대해져서', '놀람', '..'],
#  ['와', '..', '.', '좋아', '요', '번째', '..', '.', 'ㄷㄷ'],
#  ['엄청', '컷당', '귤먹을때', '광', '숙이', '마!귤', '먹는', '거', '처음', '보나'],
#  ['광', '숙이', '뙈찌ㅎㅎㅎㅎ'],
#  ['오', '광', '숙이', '많이', '컷다'],
#  ['왜', '더', '토실토실해', '보이지?'],
#  ['츄르', '를', '모르', '는', '인'],
#  ['초오', '리타', '어', '..'],
#  ['아', '미친', '존나', '잘생', '기셨어'],
#  ['츄르', '가', '머에여', '..', '..', '..', '..', '.'],
#  ['섭넬',
#   '광',
#   '숙이',
#   '개',
#   '귀여',
#   '워',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '참고로',
#   '광',
#   '숙이',
#   '진짜',
#   '많이',
#   '컷다',
#   'ㄷㄷ'],
#  ['라쿤', '확대', '범', ',,'],
#  ['광', '숙이', '바보', '광', '숙이', '바라', '기'],
#  ['등이네요!', '빠놀이', '싫어', '하시', '면', '죄송', '해요', 'ㅠㅠ'],
#  ['너.불.조.아'],
#  ['광', '숙이', '산책시켜주세요'],
#  ['저희',
#   '집',
#   '고양이',
#   '들은',
#   '츄르',
#   '먹으면',
#   '설사하고',
#   '아파',
#   '서',
#   'ㅠㅠ',
#   'ㅠ',
#   '병원',
#   '에서',
#   '는',
#   '간식',
#   '같은',
#   '거',
#   '먹이지말고',
#   '사료',
#   '만',
#   '먹으라고해서',
#   '저희',
#   '집은',
#   '간식',
#   '이',
#   '아예',
#   '없는',
#   '데',
#   '다른',
#   '냥이',
#   '들이',
#   '간식',
#   '먹을',
#   '때마다',
#   '마음',
#   '아프',
#   '네요',
#   'ㅠㅠ'],
#  ['꽝쑥이'],
#  ['옷', '예쁘네요!!!!!!', '!', '광', '숙이', '귀여', '워', '!!', '!'],
#  ['광', '숙이', '엄마하고싶다'],
#  ['라쿤', '+', '돼지', '라지', '광', '숙이', '는', '라지', '사이', '즈'],
#  ['저희', '고양이', '도', '츄르', '보면', '환장하', '져', 'ㅋㅋ'],
#  ['돼지', '..', '너부리', '아니', '광', '숙이', '..'],
#  ['웃을때', '입동굴', '진짜', 'ㅠ'],
#  ['오우야', '이빨', '한번', '살벌하네'],
#  ['라쿤', '은', '비만', '많다고', '하던데', '너불님', '주의하셔야겠어요', 'ㄷㄷ', '..'],
#  ['라쿤',
#   '이',
#   '고양이',
#   '랑',
#   'DNA',
#   '가',
#   '비슷하',
#   '다라',
#   '..',
#   '그래서',
#   '둘다',
#   '도도하고',
#   '귀엽',
#   '군요',
#   '라쿤',
#   '개',
#   '좋아',
#   '..'],
#  ['패딩', '모자에', '있는', '털이', '라쿤', '털이', '신분', '..'],
#  ['너불님', '츄르', '맛있', '어요', '??', '?', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ', 'ㅋㅋ'],
#  ['너불님', '옷', '악어', '님', '옷인줄'],
#  ['광', '숙이', '귀여', '움', '이랑', '몸집이', '배가', '됐넹ㅎ'],
#  ['라멘', '~~~~~', '~~', '!!', '!!', '!'],
#  ['저',
#   '카펫',
#   '에서',
#   '저러고',
#   '먹는',
#   '거',
#   '보니',
#   '어우',
#   '..',
#   '.소오름끼친다',
#   '안그',
#   '래도',
#   '울집',
#   '강아지',
#   '도',
#   '침대',
#   '밑에',
#   '서',
#   '맨날',
#   '뭐',
#   '물고가서',
#   '먹고',
#   '하는',
#   '데',
#   '밑에',
#   '흘린거',
#   '치우느라',
#   '핵고생',
#   '..',
#   '.',
#   '애',
#   '키우',
#   '듯이',
#   '동물',
#   '도',
#   '위생',
#   '잘',
#   '관리',
#   '하면',
#   '서',
#   '키워',
#   '줘야',
#   '하는',
#   '데',
#   '카펫',
#   '은',
#   '치우기',
#   '너무',
#   '불편',
#   '할듯',
#   '.'],
#  ['너구리',
#   '는',
#   '개과인데',
#   '..',
#   '.',
#   '라쿤',
#   '은',
#   '너구리',
#   '과거든여?',
#   '근데',
#   '고양이',
#   '와',
#   'd',
#   'na',
#   '가',
#   '거의비슷하다고여?',
#   '예',
#   '!!',
#   '!!'],
#  ['몸에', '달라붙으면', '옷', '찢어', '질듯'],
#  ['ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   'ㅋㅋ',
#   '고양이',
#   '간식',
#   '맛있',
#   '어',
#   '보여',
#   '서',
#   '저도',
#   '조금먹어본적있는데',
#   '생긴것보다',
#   '맛읎더라구요',
#   '..',
#   '.',
#   'ㅋㅋ',
#   'ㅋ'],
#  ['광', '숙이', '살찐거', '봐', '귀여', '워ㅓ', '만져보고', '싶다', 'ㅠㅠ', 'ㅠㅠ'],
#  ['아웃트로는', '너굴맨이', '처리했으니', '안심하라구!'],
#  ['껍질', '꼭', '씻으셔야겠네', '귤', '껍질', '에도', '농약', '많은', '뎅'],
#  ...]

# %%
from soynlp.tokenizer import RegexTokenizer

tokenizer = RegexTokenizer()
h=[]

for comments in final_total:
    h.append(' '.join(tokenizer.tokenize(comments)))
    
final_total = h
del h

# %%
from soynlp.word import WordExtractor

word_extractor = WordExtractor(min_frequency=10,
    min_cohesion_forward=0.05, 
    min_right_branching_entropy=0.0
)

word_extractor.train(final_total) # list of str or like
words = word_extractor.extract()
# Out:
# training was done. used memory 2.769 Gbse memory 3.079 Gb
# all cohesion probabilities was computed. # words = 85654
# all branching entropies was computed # words = 201833
# all accessor variety was computed # words = 201833

# %%
scores = {word:score.cohesion_forward for word, score in words.items()}

# %%
scores2 = {word:max(score.cohesion_forward,score.cohesion_backward) for word, score in words.items()}

# %%
scores = scores2

# %%
final_total = final_total[100000:100100]

# %%
from soynlp.tokenizer import LTokenizer, MaxScoreTokenizer

tokenizer= LTokenizer(scores = scores)
tokenizer2 = MaxScoreTokenizer(scores=scores)
tmp = []; tmp2 = []
r_tmp = []; r_tmp2 = []

for i in final_total:
    tmp.append(tokenizer.tokenize(i))
    
tmp = sum(tmp, [])

for i in tmp:
    tmp2.append(tokenizer2.tokenize(i))
    
tmp2 = sum(tmp2, [])

# %%
tmp
# Out:
# ['악',
#  '미쳤다',
#  '요즘',
#  '언니',
#  '진챠',
#  '너무',
#  '너무너무',
#  '좋아',
#  '서',
#  '하루',
#  '다섯',
#  '시간씩',
#  '언니',
#  '영상',
#  '보고있어요',
#  '엉엉',
#  '진짜',
#  '방금',
#  '도',
#  '보는데',
#  '또',
#  '영상',
#  '올라와서',
#  '진짜',
#  '행보',
#  '케요',
#  '라이',
#  '프진진',
#  '언니',
#  '예전',
#  '영상',
#  '보다가',
#  '오늘',
#  '올라',
#  '온',
#  '영상',
#  '보니까',
#  '피부',
#  '가',
#  '너무',
#  '좋아',
#  '신거',
#  '같아요',
#  '이제',
#  '아침',
#  '저녁',
#  '으로',
#  '쌀쌀',
#  '하니까',
#  '언니',
#  '가',
#  '좋아',
#  '하시는',
#  '잠옷',
#  '추천',
#  '영상',
#  '을',
#  '보고싶어요',
#  'ㅠㅠ',
#  'ㅠ',
#  '일본에서',
#  '구독하구잇어요어늬너무이뻐요',
#  'ㅠ',
#  '그냥',
#  '다해요',
#  'ㅠㅠ',
#  'ㅠㅠㅠ',
#  '사랑해요',
#  'ㅠ',
#  '아',
#  'ㅜㅜ',
#  'ㅜ',
#  '미모',
#  '대방출',
#  '너무',
#  '예쁜',
#  '거',
#  '아닙니까',
#  '들숨',
#  '에',
#  '재력',
#  '을',
#  '날숨에',
#  '건강',
#  '을',
#  '..',
#  '보라색',
#  '아이',
#  '섀도',
#  '넘',
#  '잘어울려',
#  '여',
#  '그리',
#  '규',
#  '파운데이션',
#  '도',
#  '코부분은',
#  '놔두',
#  '고',
#  '볼이',
#  '랑',
#  '외곽은',
#  '컨실러',
#  '로',
#  '살짝',
#  '덮으니까',
#  '중앙',
#  '이',
#  '밝아',
#  '보이고',
#  '잘어울리',
#  '는거가태요',
#  '오늘',
#  '영상',
#  '잘봤어',
#  '여',
#  'ㅎ',
#  'ㅡ',
#  'ㅎ',
#  '언니',
#  '아이라인',
#  '가끔',
#  '그리',
#  '실',
#  '때',
#  '꼬리',
#  '짧게',
#  '위로',
#  '빼면',
#  '더',
#  '자연스러',
#  '울거가타여',
#  '저도',
#  '아라',
#  '안그',
#  '리고',
#  '속눈썹',
#  '집착',
#  '스탈이라',
#  '아이라인',
#  '왜',
#  '안그',
#  '리냐는',
#  '댓글',
#  '이',
#  '이해가',
#  '안되',
#  '네여',
#  '너무',
#  '예뻐요',
#  '완젼',
#  '예뻐요',
#  '존',
#  '예',
#  '와',
#  '진짜',
#  '톤',
#  '파괴자',
#  '..',
#  '.',
#  '최고',
#  '되세요',
#  'ㅠㅜㅜ',
#  '분위기',
#  '대박',
#  '적',
#  '와',
#  '진짜',
#  '너무',
#  '예쁘',
#  '고',
#  '너무',
#  '사랑',
#  '스러워여',
#  '썸네일',
#  '숨멎',
#  '나중에',
#  '진진님',
#  '이',
#  '자주',
#  '쓰시는',
#  '립들',
#  '소개해주세요',
#  '언니',
#  '오늘도',
#  '이뻐요',
#  'ㅠ',
#  '진진님',
#  '미모',
#  '약간',
#  '미친',
#  '듯',
#  '..',
#  '넘무',
#  '너무',
#  '이뿌',
#  '다',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '사랑해요',
#  '너무',
#  '최고',
#  '사랑해요',
#  '정말',
#  '흑',
#  '흑',
#  '흑',
#  '숙구구',
#  'ㅜㅝ',
#  '긴영상',
#  '사랑합니다',
#  '..',
#  '.',
#  '저런',
#  '메이크업',
#  '잘어울려',
#  '주셔서',
#  '감사',
#  '해요',
#  '..',
#  '.',
#  '진짜',
#  '사랑해요',
#  '그냥',
#  '사랑해요',
#  '이유는',
#  '업서요',
#  '..',
#  '..',
#  '와',
#  '아이라인',
#  '안그',
#  '린게',
#  '더',
#  '나은',
#  '사람',
#  '첨',
#  '봐요',
#  '..',
#  '.',
#  '보통',
#  '아이라인',
#  '안그',
#  '리면',
#  '큰일',
#  '나는',
#  '데',
#  'ㅜㅜ',
#  '오려',
#  '안그',
#  '린게',
#  '짱예',
#  '..',
#  '글구',
#  '쿨한',
#  '셰도우',
#  '색도',
#  '넘',
#  '잘어울려',
#  '여',
#  '언니',
#  '사랑해요',
#  'ㅠㅠ',
#  '사랑해요',
#  '진진',
#  'ㅠㅠ',
#  'ㅠㅠㅠㅠㅠㅠ',
#  'ㄴ',
#  '너무',
#  '이쁜',
#  '진진언니',
#  '오늘도',
#  '매력',
#  '진진',
#  '..',
#  '.',
#  '천사',
#  '인데',
#  '점점',
#  '눈이',
#  '악마',
#  '로',
#  '변해',
#  '가는',
#  '메이크업',
#  '이네요',
#  '이렇게',
#  '이쁘기있냐고요',
#  '빠',
#  '퍼플',
#  '세상',
#  '찰떡',
#  '아닌가요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '정말',
#  '너무',
#  '너무',
#  '예뻐요',
#  'ㅠㅠ',
#  'ㅠ',
#  '제',
#  '롤모델',
#  'ㅠㅠ',
#  '와',
#  '진짜',
#  '썸네일',
#  '보고',
#  '깜짝놀',
#  '라서',
#  '들어',
#  '왔어요',
#  '진짜',
#  '제가',
#  '이때까지',
#  '본',
#  '언니',
#  '영상',
#  '중에',
#  '단연',
#  '최고',
#  '로',
#  '젤',
#  '예뻐요',
#  'ㅠㅠ',
#  'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '진진님',
#  '저도',
#  '일본',
#  '갔다',
#  '사봐',
#  '서',
#  '쟁여',
#  '놓고',
#  '쓰는',
#  '템인데',
#  '이름',
#  '은',
#  '페어',
#  '아크네예요',
#  '일본에서',
#  '만',
#  '파는거',
#  '같아',
#  '서',
#  '일본',
#  '갔을때',
#  '한번',
#  '사보',
#  '세요',
#  '여드름',
#  '난',
#  '곳에',
#  '콕찍어바르면',
#  '전',
#  '일',
#  '내에',
#  '난거',
#  '같아요',
#  '짱좋아요',
#  '언니',
#  '영상',
#  '보면',
#  '트러블',
#  '신경',
#  '많이',
#  '쓰시는',
#  '거',
#  '같아',
#  '서',
#  '아무도',
#  '안물어봤',
#  '지만',
#  '추천',
#  '해용',
#  '와',
#  '대박',
#  '..',
#  '.',
#  '진짜',
#  '보석',
#  '들어',
#  '있는',
#  '조개',
#  '껍데기',
#  '안에',
#  '사는',
#  '바다',
#  '속에서',
#  '도',
#  '얼짱',
#  '으로',
#  '유명한',
#  '인어공주',
#  '같아',
#  '진짜',
#  '너무',
#  '예쁘',
#  '셔',
#  '진짜',
#  '매일매일',
#  '이',
#  '리즈',
#  '라는',
#  '말이',
#  '찰떡이',
#  '야',
#  '어쩜',
#  '안녕하세요',
#  '한국대중음악박물관',
#  '입니다',
#  '방탄소년단',
#  '뉴이스트세븐틴아이유트와이스',
#  '싸인',
#  '의상도',
#  '전시',
#  '가',
#  '되고있어',
#  '요',
#  '갤럭시',
#  '노트',
#  '이벤트',
#  '중입니다',
#  '.',
#  '한국대중음악박물관',
#  '홈페이지',
#  '에서',
#  '확인',
#  '가능하고',
#  '누구',
#  '나',
#  '참여',
#  '가능합니다',
#  '한국대중음악박물관',
#  '검색',
#  '분만',
#  '투자해서',
#  '갤럭시',
#  '노트',
#  '응모해',
#  '보세요',
#  '라이',
#  '너',
#  '한번',
#  '안그리면진짜',
#  '편함',
#  'ㅋㅋ',
#  '눈끝도막긁을수있고',
#  '저도',
#  '언니처럼',
#  '라이',
#  '너그리건안그리건차이가안나서',
#  '필요',
#  '성을못느낌으로',
#  '안그',
#  '리는데',
#  '주위에서',
#  '그리',
#  '라는애들',
#  '꼭있음',
#  '..',
#  '저런',
#  '색깔',
#  '도',
#  '어울리는',
#  '진진님',
#  '..',
#  '대단하',
#  '시다',
#  '..',
#  '매력',
#  '뿜뿜실화냐',
#  '..',
#  '흑',
#  '..',
#  '너무',
#  '멋잇어',
#  'ㅠㅠ',
#  'ㅠ',
#  '비실',
#  '크',
#  '페탈와이는',
#  '호',
#  '피부',
#  '톤에',
#  '하나도',
#  '화사하',
#  '지',
#  '않게',
#  '딱',
#  '맞게',
#  '올라',
#  '가요',
#  '어두운',
#  '거',
#  '선호하',
#  '셨으면',
#  '진짜',
#  '밝을듯',
#  '..',
#  '.',
#  '헐랭',
#  '저랑',
#  '완전',
#  '똑같',
#  '아요',
#  '저더',
#  '한쪽',
#  '눈',
#  '찝자마자',
#  '바로',
#  '마스카라',
#  '바르고',
#  '그래',
#  '요',
#  'ㅋㅋ',
#  'ㅋㅋㅋㅋ',
#  '눈이',
#  '긴',
#  '편이',
#  '여서',
#  '속눈썹',
#  '에',
#  '집착',
#  '엄',
#  'ㅊ',
#  '청',
#  '함',
#  '파데',
#  '바르고',
#  '난',
#  '뒤의',
#  '진진님',
#  '얼굴',
#  '을',
#  '보고',
#  '뱀파이어',
#  '가',
#  '연상',
#  '됐읍니다',
#  '오늘',
#  '영상',
#  '뱀파이어',
#  '메이크업',
#  '이라고',
#  '생각',
#  '해두고',
#  '찾아',
#  '올거에오',
#  '언니',
#  '제발',
#  '이거',
#  '진진',
#  '의',
#  '화장',
#  '놀이',
#  '시리즈',
#  '로',
#  '가시',
#  '죠',
#  '언니',
#  '하고싶은거',
#  '다해',
#  '주세요',
#  '헐',
#  '귀걸이',
#  '대박',
#  '예뻐요',
#  '..',
#  '..',
#  '무의식',
#  '중에',
#  '반말하',
#  '는',
#  '것',
#  '좀',
#  '줄여주',
#  '심',
#  '좋을것같아요',
#  '아',
#  '언니',
#  '이영상',
#  '진짜',
#  '오',
#  'ㅑ',
#  '케',
#  '기여워요',
#  'ㅠㅠ',
#  'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  'ㅠㅜㅜㅜ',
#  '진진',
#  '이렇게',
#  '완전',
#  '색다른',
#  '메이크업조아요',
#  'ㅠㅠ',
#  'ㅠ',
#  '진진',
#  '얼굴',
#  '도화지야뭐야',
#  '소화',
#  '력',
#  '대박',
#  '적인부분',
#  '앞에',
#  '하얀',
#  '색을',
#  '바르',
#  '라는데',
#  '이건',
#  '하기',
#  '싫으네요',
#  '단호',
#  'ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '너무',
#  '귀여',
#  '워',
#  'ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '언니',
#  '귀엽',
#  '고',
#  '이쁘고',
#  '영롱하고',
#  '혼자',
#  '다',
#  '해',
#  '엉엉',
#  '메탈',
#  '릭한',
#  '메이크업',
#  '젤',
#  '잘',
#  '어울리',
#  '잖아요',
#  'ㅠ',
#  'ㅠ',
#  '시상',
#  '에나',
#  '저',
#  '색깔이',
#  '어찌',
#  '저리',
#  '잘어울',
#  '린대유',
#  '갑자기',
#  '궁금',
#  '해졌는데',
#  '키',
#  '물어봐도',
#  '돼요',
#  '와',
#  '인어공주',
#  '다',
#  '언니',
#  '눈썹문신',
#  '어디서',
#  '하셨는지',
#  '궁금',
#  '해요',
#  '..',
#  '진진',
#  '의',
#  '영수',
#  '증',
#  '..',
#  '..',
#  '제발',
#  '..',
#  '..',
#  '아라',
#  '아아랄',
#  'ㄹ',
#  '각',
#  'ㄱㄹ',
#  'ㄱ',
#  '너무',
#  '예뻐',
#  '진짜',
#  '너무',
#  '너무',
#  '최고',
#  '야',
#  '진진언니',
#  '가',
#  '짱이',
#  '야',
#  'ㅠㅠ',
#  'ㅠㅠㅠㅠㅠㅠ',
#  '언니',
#  '입술',
#  '관리',
#  '어떻게',
#  '하시는',
#  '지',
#  '궁금',
#  '해용',
#  '진진님',
#  '사랑해요',
#  'ㅠㅠ',
#  'ㅠ',
#  '언니',
#  '진짜',
#  '너무',
#  '예뻐요',
#  'ㅠㅜㅜ',
#  '완전',
#  '와기고양이',
#  '느낌',
#  '아아',
#  '악',
#  'ㅜㅜ',
#  'ㅜ',
#  '사랑해요',
#  '와',
#  '우대박',
#  '언니',
#  '이세',
#  '상',
#  '사람',
#  '아니죠',
#  '아니',
#  '사람',
#  '아니죠',
#  '요정이',
#  '죠',
#  'ㅠㅠ',
#  '분',
#  '순삭',
#  '언니',
#  '왤케',
#  '기여워',
#  '여',
#  '좋아요',
#  '으애',
#  'ㅠㅠ',
#  '진진',
#  '선물이다',
#  '잘',
#  '볼께요',
#  '새랭햅내대',
#  '진진',
#  '오늘',
#  '은',
#  '약간',
#  '인어공주',
#  '같아요',
#  '아코',
#  '예쁘',
#  '다',
#  'ㅠ',
#  'ㅠ',
#  '열일하',
#  '는',
#  '선풍기',
#  '웜톤',
#  '도',
#  '쿨톤',
#  '도',
#  '왜케',
#  'ㄷ',
#  'ㅏ',
#  '잘어울리',
#  '셔요',
#  'ㅠㅠ',
#  'ㅠㅠㅠㅠㅠㅠ',
#  '언니',
#  '눈썹',
#  '문신',
#  '하신거에요',
#  '진진님',
#  '해주',
#  '시면',
#  '진짜',
#  '좋을것같아',
#  '여',
#  '..',
#  '와',
#  '언니',
#  '메이크업',
#  '완전',
#  '찰떡',
#  '센',
#  '화장',
#  '도',
#  '잘어울리',
#  '고',
#  'ㅜㅜ',
#  '최고',
#  '되신다',
#  '헥',
#  '오랜만에',
#  '아이라인',
#  '그리',
#  '셨네욤',
#  '무슨',
#  '미국',
#  '년대',
#  '하이',
#  '틴',
#  '스타',
#  '같다',
#  '..',
#  '.',
#  '너무',
#  '예뻐요',
#  'ㅠㅠ',
#  '와',
#  '보라색',
#  '진짜',
#  '잘어울려요',
#  'ㅠㅜㅜㅠ',
#  '언니',
#  '존예',
#  '피부',
#  '커버',
#  '진짜',
#  '잘',
#  '된다',
#  '..',
#  '진짜',
#  '이번',
#  '메이크업',
#  '너무',
#  '이뻐요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '진진',
#  '뭔들',
#  '병원',
#  '원장님',
#  '이랑',
#  '인연',
#  '무엇입니까',
#  '친화력',
#  '쩔어',
#  'ㅠ',
#  '저',
#  '포니',
#  '이펙',
#  '트',
#  '립',
#  '틴트',
#  '엄청',
#  '좋은',
#  '데',
#  '향이',
#  '진짜',
#  '넘',
#  '별루',
#  '예욥',
#  '이번에',
#  '아이라인',
#  '그렸',
#  '네욧',
#  '아라',
#  '그려',
#  '도',
#  '여신',
#  '미친',
#  '미친',
#  '대미',
#  '친',
#  '언니',
#  '만',
#  '하루종일',
#  '봤어요',
#  'ㅠㅠ',
#  '최애',
#  '언니',
#  '아이라인',
#  '예쁘세요',
#  'ㅠㅠ',
#  'ㅠ',
#  '너무',
#  '이뻐',
#  'ㅠㅠ',
#  '언니',
#  '인스타그램',
#  '하세',
#  '여',
#  '진진',
#  '임',
#  '밑트임',
#  '하신건가요',
#  '천사',
#  '같아요',
#  '여신',
#  '..',
#  '그냥',
#  '옙허',
#  '..',
#  '그냥',
#  '언니',
#  '입술',
#  '도',
#  '뚫어',
#  '주세용',
#  '으윽',
#  '기다렸어요',
#  'ㅠㅠ',
#  '항상',
#  '봐도',
#  '세상',
#  '이쁜',
#  '언니',
#  '얌',
#  '진짜',
#  '너무',
#  '예뻐요',
#  '예뻐',
#  '용',
#  'ㅎ',
#  '오오오',
#  '왕아아',
#  '언니',
#  '태닝',
#  '왜',
#  '해요',
#  '궁금',
#  '해서요']

# %%
for i in final_total:
    r_tmp.append(tokenizer2.tokenize(i))
    
r_tmp = sum(r_tmp, [])

for i in r_tmp:
    r_tmp2.append(tokenizer.tokenize(i))
    
r_tmp2 = sum(r_tmp2, [])

# %%
former = final_total
tmp = []

while 1:
    for i in former:
        tmp.append(tokenizer.tokenize(i))
    
    tmp = sum(tmp, [])
    
    if len(former) == len(tmp):
        break
    
    former = tmp; tmp = []

# %%
tmp
# Out:
# ['악',
#  '미쳤다',
#  '요즘',
#  '언니',
#  '진챠',
#  '너무',
#  '너무',
#  '너무',
#  '좋아',
#  '서',
#  '하루',
#  '다섯',
#  '시간',
#  '씩',
#  '언니',
#  '영상',
#  '보고있어요',
#  '엉엉',
#  '진짜',
#  '방금',
#  '도',
#  '보는데',
#  '또',
#  '영상',
#  '올라와서',
#  '진짜',
#  '행보',
#  '케요',
#  '라이',
#  '프진진',
#  '언니',
#  '예전',
#  '영상',
#  '보다가',
#  '오늘',
#  '올라',
#  '온',
#  '영상',
#  '보니까',
#  '피부',
#  '가',
#  '너무',
#  '좋아',
#  '신거',
#  '같아요',
#  '이제',
#  '아침',
#  '저녁',
#  '으로',
#  '쌀쌀',
#  '하니까',
#  '언니',
#  '가',
#  '좋아',
#  '하시는',
#  '잠옷',
#  '추천',
#  '영상',
#  '을',
#  '보고싶어요',
#  'ㅠㅠ',
#  'ㅠ',
#  '일본에서',
#  '구독',
#  '하구',
#  '잇어요',
#  '어늬너무이뻐요',
#  'ㅠ',
#  '그냥',
#  '다해',
#  '요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠ',
#  '사랑해요',
#  'ㅠ',
#  '아',
#  'ㅜㅜ',
#  'ㅜ',
#  '미모',
#  '대방출',
#  '너무',
#  '예쁜',
#  '거',
#  '아닙니까',
#  '들숨',
#  '에',
#  '재력',
#  '을',
#  '날숨에',
#  '건강',
#  '을',
#  '..',
#  '보라색',
#  '아이',
#  '섀도',
#  '넘',
#  '잘어울려',
#  '여',
#  '그리',
#  '규',
#  '파운데이션',
#  '도',
#  '코부분은',
#  '놔두',
#  '고',
#  '볼이',
#  '랑',
#  '외곽은',
#  '컨실러',
#  '로',
#  '살짝',
#  '덮으니까',
#  '중앙',
#  '이',
#  '밝아',
#  '보이고',
#  '잘어울리',
#  '는거',
#  '가태',
#  '요',
#  '오늘',
#  '영상',
#  '잘봤어',
#  '여',
#  'ㅎ',
#  'ㅡ',
#  'ㅎ',
#  '언니',
#  '아이라인',
#  '가끔',
#  '그리',
#  '실',
#  '때',
#  '꼬리',
#  '짧게',
#  '위로',
#  '빼면',
#  '더',
#  '자연스러',
#  '울거',
#  '가타',
#  '여',
#  '저도',
#  '아라',
#  '안그',
#  '리고',
#  '속눈썹',
#  '집착',
#  '스탈',
#  '이라',
#  '아이라인',
#  '왜',
#  '안그',
#  '리냐는',
#  '댓글',
#  '이',
#  '이해가',
#  '안되',
#  '네여',
#  '너무',
#  '예뻐요',
#  '완젼',
#  '예뻐요',
#  '존',
#  '예',
#  '와',
#  '진짜',
#  '톤',
#  '파괴자',
#  '..',
#  '.',
#  '최고',
#  '되세요',
#  'ㅠㅜㅜ',
#  '분위기',
#  '대박',
#  '적',
#  '와',
#  '진짜',
#  '너무',
#  '예쁘',
#  '고',
#  '너무',
#  '사랑',
#  '스러',
#  '워여',
#  '썸네일',
#  '숨멎',
#  '나중에',
#  '진진님',
#  '이',
#  '자주',
#  '쓰시는',
#  '립들',
#  '소개해주세요',
#  '언니',
#  '오늘도',
#  '이뻐요',
#  'ㅠ',
#  '진진님',
#  '미모',
#  '약간',
#  '미친',
#  '듯',
#  '..',
#  '넘무',
#  '너무',
#  '이뿌',
#  '다',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '사랑해요',
#  '너무',
#  '최고',
#  '사랑해요',
#  '정말',
#  '흑',
#  '흑',
#  '흑',
#  '숙구구',
#  'ㅜㅝ',
#  '긴영상',
#  '사랑합니다',
#  '..',
#  '.',
#  '저런',
#  '메이크업',
#  '잘어울려',
#  '주셔서',
#  '감사',
#  '해요',
#  '..',
#  '.',
#  '진짜',
#  '사랑해요',
#  '그냥',
#  '사랑해요',
#  '이유는',
#  '업서요',
#  '..',
#  '..',
#  '와',
#  '아이라인',
#  '안그',
#  '린게',
#  '더',
#  '나은',
#  '사람',
#  '첨',
#  '봐요',
#  '..',
#  '.',
#  '보통',
#  '아이라인',
#  '안그',
#  '리면',
#  '큰일',
#  '나는',
#  '데',
#  'ㅜㅜ',
#  '오려',
#  '안그',
#  '린게',
#  '짱예',
#  '..',
#  '글구',
#  '쿨한',
#  '셰도우',
#  '색도',
#  '넘',
#  '잘어울려',
#  '여',
#  '언니',
#  '사랑해요',
#  'ㅠㅠ',
#  '사랑해요',
#  '진진',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㄴ',
#  '너무',
#  '이쁜',
#  '진진언니',
#  '오늘도',
#  '매력',
#  '진진',
#  '..',
#  '.',
#  '천사',
#  '인데',
#  '점점',
#  '눈이',
#  '악마',
#  '로',
#  '변해',
#  '가는',
#  '메이크업',
#  '이네',
#  '요',
#  '이렇게',
#  '이쁘',
#  '기있냐고요',
#  '빠',
#  '퍼플',
#  '세상',
#  '찰떡',
#  '아닌가요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '정말',
#  '너무',
#  '너무',
#  '예뻐요',
#  'ㅠㅠ',
#  'ㅠ',
#  '제',
#  '롤모델',
#  'ㅠㅠ',
#  '와',
#  '진짜',
#  '썸네일',
#  '보고',
#  '깜짝놀',
#  '라서',
#  '들어',
#  '왔어요',
#  '진짜',
#  '제가',
#  '이때까지',
#  '본',
#  '언니',
#  '영상',
#  '중에',
#  '단연',
#  '최고',
#  '로',
#  '젤',
#  '예뻐요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '진진님',
#  '저도',
#  '일본',
#  '갔다',
#  '사봐',
#  '서',
#  '쟁여',
#  '놓고',
#  '쓰는',
#  '템인데',
#  '이름',
#  '은',
#  '페어',
#  '아크',
#  '네예요',
#  '일본에서',
#  '만',
#  '파는거',
#  '같아',
#  '서',
#  '일본',
#  '갔을때',
#  '한번',
#  '사보',
#  '세요',
#  '여드름',
#  '난',
#  '곳에',
#  '콕찍어바르면',
#  '전',
#  '일',
#  '내에',
#  '난거',
#  '같아요',
#  '짱좋아요',
#  '언니',
#  '영상',
#  '보면',
#  '트러블',
#  '신경',
#  '많이',
#  '쓰시는',
#  '거',
#  '같아',
#  '서',
#  '아무도',
#  '안물어봤',
#  '지만',
#  '추천',
#  '해용',
#  '와',
#  '대박',
#  '..',
#  '.',
#  '진짜',
#  '보석',
#  '들어',
#  '있는',
#  '조개',
#  '껍데기',
#  '안에',
#  '사는',
#  '바다',
#  '속에서',
#  '도',
#  '얼짱',
#  '으로',
#  '유명한',
#  '인어공주',
#  '같아',
#  '진짜',
#  '너무',
#  '예쁘',
#  '셔',
#  '진짜',
#  '매일매일',
#  '이',
#  '리즈',
#  '라는',
#  '말이',
#  '찰떡이',
#  '야',
#  '어쩜',
#  '안녕하세요',
#  '한국대중음악박물관',
#  '입니다',
#  '방탄소년단',
#  '뉴이',
#  '스트',
#  '세븐틴',
#  '아이',
#  '유트',
#  '와이',
#  '스',
#  '싸인',
#  '의상',
#  '도',
#  '전시',
#  '가',
#  '되고있어',
#  '요',
#  '갤럭시',
#  '노트',
#  '이벤트',
#  '중입니다',
#  '.',
#  '한국대중음악박물관',
#  '홈페이지',
#  '에서',
#  '확인',
#  '가능하',
#  '고',
#  '누구',
#  '나',
#  '참여',
#  '가능합니다',
#  '한국대중음악박물관',
#  '검색',
#  '분만',
#  '투자해',
#  '서',
#  '갤럭시',
#  '노트',
#  '응모해',
#  '보세요',
#  '라이',
#  '너',
#  '한번',
#  '안그',
#  '리면진짜',
#  '편함',
#  'ㅋㅋ',
#  '눈끝도막긁을수있고',
#  '저도',
#  '언니',
#  '처럼',
#  '라이',
#  '너그',
#  '리건안그리건차이가안나서',
#  '필요',
#  '성을',
#  '못느',
#  '낌으로',
#  '안그',
#  '리는데',
#  '주위에서',
#  '그리',
#  '라는',
#  '애들',
#  '꼭있음',
#  '..',
#  '저런',
#  '색깔',
#  '도',
#  '어울리는',
#  '진진님',
#  '..',
#  '대단하',
#  '시다',
#  '..',
#  '매력',
#  '뿜뿜',
#  '실화냐',
#  '..',
#  '흑',
#  '..',
#  '너무',
#  '멋잇어',
#  'ㅠㅠ',
#  'ㅠ',
#  '비실',
#  '크',
#  '페탈와이는',
#  '호',
#  '피부',
#  '톤에',
#  '하나도',
#  '화사하',
#  '지',
#  '않게',
#  '딱',
#  '맞게',
#  '올라',
#  '가요',
#  '어두운',
#  '거',
#  '선호하',
#  '셨으면',
#  '진짜',
#  '밝을듯',
#  '..',
#  '.',
#  '헐랭',
#  '저랑',
#  '완전',
#  '똑같',
#  '아요',
#  '저더',
#  '한쪽',
#  '눈',
#  '찝자마자',
#  '바로',
#  '마스카라',
#  '바르고',
#  '그래',
#  '요',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '눈이',
#  '긴',
#  '편이',
#  '여서',
#  '속눈썹',
#  '에',
#  '집착',
#  '엄',
#  'ㅊ',
#  '청',
#  '함',
#  '파데',
#  '바르고',
#  '난',
#  '뒤의',
#  '진진님',
#  '얼굴',
#  '을',
#  '보고',
#  '뱀파이어',
#  '가',
#  '연상',
#  '됐읍니다',
#  '오늘',
#  '영상',
#  '뱀파이어',
#  '메이크업',
#  '이라고',
#  '생각',
#  '해두',
#  '고',
#  '찾아',
#  '올거',
#  '에오',
#  '언니',
#  '제발',
#  '이거',
#  '진진',
#  '의',
#  '화장',
#  '놀이',
#  '시리즈',
#  '로',
#  '가시',
#  '죠',
#  '언니',
#  '하고싶은거',
#  '다해',
#  '주세요',
#  '헐',
#  '귀걸이',
#  '대박',
#  '예뻐요',
#  '..',
#  '..',
#  '무의식',
#  '중에',
#  '반말하',
#  '는',
#  '것',
#  '좀',
#  '줄여주',
#  '심',
#  '좋을것같아요',
#  '아',
#  '언니',
#  '이영상',
#  '진짜',
#  '오',
#  'ㅑ',
#  '케',
#  '기여워요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠ',
#  'ㅠㅜㅜㅜ',
#  '진진',
#  '이렇게',
#  '완전',
#  '색다른',
#  '메이크업',
#  '조아요',
#  'ㅠㅠ',
#  'ㅠ',
#  '진진',
#  '얼굴',
#  '도화지야뭐야',
#  '소화',
#  '력',
#  '대박',
#  '적인',
#  '부분',
#  '앞에',
#  '하얀',
#  '색을',
#  '바르',
#  '라는',
#  '데',
#  '이건',
#  '하기',
#  '싫으',
#  '네요',
#  '단호',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  '너무',
#  '귀여',
#  '워',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋㅋ',
#  'ㅋ',
#  '언니',
#  '귀엽',
#  '고',
#  '이쁘고',
#  '영롱하고',
#  '혼자',
#  '다',
#  '해',
#  '엉엉',
#  '메탈',
#  '릭한',
#  '메이크업',
#  '젤',
#  '잘',
#  '어울리',
#  '잖아',
#  '요',
#  'ㅠ',
#  'ㅠ',
#  '시상',
#  '에나',
#  '저',
#  '색깔이',
#  '어찌',
#  '저리',
#  '잘어울',
#  '린대유',
#  '갑자기',
#  '궁금',
#  '해졌는데',
#  '키',
#  '물어봐도',
#  '돼요',
#  '와',
#  '인어공주',
#  '다',
#  '언니',
#  '눈썹문신',
#  '어디서',
#  '하셨는지',
#  '궁금',
#  '해요',
#  '..',
#  '진진',
#  '의',
#  '영수',
#  '증',
#  '..',
#  '..',
#  '제발',
#  '..',
#  '..',
#  '아라',
#  '아아',
#  '랄',
#  'ㄹ',
#  '각',
#  'ㄱㄹ',
#  'ㄱ',
#  '너무',
#  '예뻐',
#  '진짜',
#  '너무',
#  '너무',
#  '최고',
#  '야',
#  '진진언니',
#  '가',
#  '짱이',
#  '야',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '언니',
#  '입술',
#  '관리',
#  '어떻게',
#  '하시는',
#  '지',
#  '궁금',
#  '해용',
#  '진진님',
#  '사랑해요',
#  'ㅠㅠ',
#  'ㅠ',
#  '언니',
#  '진짜',
#  '너무',
#  '예뻐요',
#  'ㅠㅜㅜ',
#  '완전',
#  '와기고양이',
#  '느낌',
#  '아아',
#  '악',
#  'ㅜㅜ',
#  'ㅜ',
#  '사랑해요',
#  '와',
#  '우대박',
#  '언니',
#  '이세',
#  '상',
#  '사람',
#  '아니',
#  '죠',
#  '아니',
#  '사람',
#  '아니',
#  '죠',
#  '요정이',
#  '죠',
#  'ㅠㅠ',
#  '분',
#  '순삭',
#  '언니',
#  '왤케',
#  '기여워',
#  '여',
#  '좋아요',
#  '으애',
#  'ㅠㅠ',
#  '진진',
#  '선물',
#  '이다',
#  '잘',
#  '볼께요',
#  '새랭햅내대',
#  '진진',
#  '오늘',
#  '은',
#  '약간',
#  '인어공주',
#  '같아요',
#  '아코',
#  '예쁘',
#  '다',
#  'ㅠ',
#  'ㅠ',
#  '열일하',
#  '는',
#  '선풍기',
#  '웜톤',
#  '도',
#  '쿨톤',
#  '도',
#  '왜케',
#  'ㄷ',
#  'ㅏ',
#  '잘어울리',
#  '셔요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '언니',
#  '눈썹',
#  '문신',
#  '하신거에요',
#  '진진님',
#  '해주',
#  '시면',
#  '진짜',
#  '좋을것같아',
#  '여',
#  '..',
#  '와',
#  '언니',
#  '메이크업',
#  '완전',
#  '찰떡',
#  '센',
#  '화장',
#  '도',
#  '잘어울리',
#  '고',
#  'ㅜㅜ',
#  '최고',
#  '되신다',
#  '헥',
#  '오랜만에',
#  '아이라인',
#  '그리',
#  '셨네욤',
#  '무슨',
#  '미국',
#  '년대',
#  '하이',
#  '틴',
#  '스타',
#  '같다',
#  '..',
#  '.',
#  '너무',
#  '예뻐요',
#  'ㅠㅠ',
#  '와',
#  '보라색',
#  '진짜',
#  '잘어울려요',
#  'ㅠㅜㅜㅠ',
#  '언니',
#  '존예',
#  '피부',
#  '커버',
#  '진짜',
#  '잘',
#  '된다',
#  '..',
#  '진짜',
#  '이번',
#  '메이크업',
#  '너무',
#  '이뻐요',
#  'ㅠㅠ',
#  'ㅠㅠ',
#  '진진',
#  '뭔들',
#  '병원',
#  '원장님',
#  '이랑',
#  '인연',
#  '무엇입니까',
#  '친화력',
#  '쩔어',
#  'ㅠ',
#  '저',
#  '포니',
#  '이펙',
#  '트',
#  '립',
#  '틴트',
#  '엄청',
#  '좋은',
#  '데',
#  '향이',
#  '진짜',
#  '넘',
#  '별루',
#  '예욥',
#  '이번에',
#  '아이라인',
#  '그렸',
#  '네욧',
#  '아라',
#  '그려',
#  '도',
#  '여신',
#  '미친',
#  '미친',
#  '대미',
#  '친',
#  '언니',
#  '만',
#  '하루종일',
#  '봤어요',
#  'ㅠㅠ',
#  '최애',
#  '언니',
#  '아이라인',
#  '예쁘세요',
#  'ㅠㅠ',
#  'ㅠ',
#  '너무',
#  '이뻐',
#  'ㅠㅠ',
#  '언니',
#  '인스타그램',
#  '하세',
#  '여',
#  '진진',
#  '임',
#  '밑트임',
#  '하신건가요',
#  '천사',
#  '같아요',
#  '여신',
#  '..',
#  '그냥',
#  '옙허',
#  '..',
#  '그냥',
#  '언니',
#  '입술',
#  '도',
#  '뚫어',
#  '주세',
#  '용',
#  '으윽',
#  '기다렸어요',
#  'ㅠㅠ',
#  '항상',
#  '봐도',
#  '세상',
#  '이쁜',
#  '언니',
#  '얌',
#  '진짜',
#  '너무',
#  '예뻐요',
#  '예뻐',
#  '용',
#  'ㅎ',
#  '오오오',
#  '왕아아',
#  '언니',
#  ...]

# %%
with open('straight.pickle', 'wb') as f:
    pickle.dump(tmp2, f, pickle.HIGHEST_PROTOCOL)
    
with open('reversed.pickle', 'wb') as f:
    pickle.dump(r_tmp2, f, pickle.HIGHEST_PROTOCOL)

# %%
print(len(tmp), len(tmp2))
print(len(r_tmp), len(r_tmp2))
# Out:
# 46717 58668
# 58830 58831

# %%
# import math

# def word_score(score):
#     return (score.cohesion_forward * math.exp(score.right_branching_entropy))

# print('단어   (빈도수, cohesion, branching entropy)\n')
# for word, score in sorted(words.items(), key=lambda x:word_score(x[1]), reverse=True)[:30]:
#     print('%s     (%d, %.3f, %.3f)' % (
#             word, 
#             score.leftside_frequency, 
#             score.cohesion_forward,
#             score.right_branching_entropy
#             )
#          )
# Out:
# 단어   (빈도수, cohesion, branching entropy)
#
# ..     (73, 0.901, 4.314)
# ...     (42, 0.720, 3.936)
# 광숙이     (547, 0.930, 3.573)
# 너불님     (942, 0.737, 3.709)
# ㅋㅋ     (421, 0.966, 3.205)
# ㅠㅠ     (175, 0.897, 3.197)
# !!     (15, 0.714, 3.392)
# 진짜     (161, 0.778, 3.146)
# ㅋㅋㅋ     (315, 0.850, 3.051)
# ??     (36, 0.720, 3.065)
# 영상     (176, 0.907, 2.750)
# ㅋㅋㅋㅋ     (214, 0.789, 2.873)
# ....     (18, 0.606, 3.030)
# 많이     (125, 0.727, 2.699)
# 근데     (67, 0.870, 2.516)
# 라쿤     (299, 0.920, 2.439)
# ㅎㅎ     (64, 0.842, 2.479)
# ㅠㅠㅠ     (73, 0.612, 2.793)
# 코카     (446, 0.880, 2.374)
# 버거     (59, 0.738, 2.526)
# 역시     (47, 0.959, 2.245)
# ㅋㅋㅋㅋㅋ     (146, 0.761, 2.378)
# 펩시     (285, 0.973, 2.099)
# 콜라     (89, 0.947, 2.104)
# ???     (21, 0.648, 2.465)
# ㅜㅜ     (44, 0.815, 2.230)
# 햄버거     (169, 0.948, 2.026)
# ㅠㅠㅠㅠ     (46, 0.618, 2.399)
# 봤는데     (17, 0.753, 2.161)
# 독감     (108, 0.982, 1.844)

# %% [markdown]
# # Konlpy

# %%
from konlpy.tag import Hannanum, Kkma, Komoran, Mecab, Twitter

use = final_total
han = []; kk = []; ko = []; me = []; twi = []

hannanum = Hannanum(); kkma = Kkma(); twitter = Twitter()

for i in use:
    han.append(hannanum.morphs(i))
    kk.append(kkma.morphs(i))
    #ko.append(komoran.morphs(i))
    #me.append(mecab.morphs(i))
    twi.append(twitter.morphs(i))
# Out:
# C:\Users\myeon\AppData\Local\Continuum\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
han
# Out:
# [['악',
#   '미치',
#   '었다',
#   '요즘',
#   '언니',
#   '진챠',
#   '너무너무너무',
#   '좋',
#   '아',
#   '하루',
#   '다섯시간',
#   '씩',
#   '언니',
#   '영상',
#   '보',
#   '고',
#   '있',
#   '어',
#   '요',
#   '엉엉',
#   '진짜',
#   '방금',
#   '도',
#   '보',
#   'ㄴ데',
#   '또',
#   '영상',
#   '오르',
#   '아',
#   '오',
#   '아',
#   '진짜',
#   '행보케요',
#   '라이프진진'],
#  ['언니',
#   '예전',
#   '영상',
#   '보',
#   '다가',
#   '오늘',
#   '오르',
#   '아',
#   '오',
#   'ㄴ',
#   '영상',
#   '보',
#   '니까',
#   '피부',
#   '가',
#   '너무',
#   '좋아신거',
#   '같',
#   '아',
#   '요',
#   '이제',
#   '아침',
#   '저녁',
#   '으로',
#   '쌀쌀',
#   '하',
#   '니까',
#   '언니',
#   '가',
#   '좋',
#   '아',
#   '하',
#   '시는',
#   '잠옷',
#   '추천',
#   '영상',
#   '을',
#   '보',
#   '고',
#   '싶',
#   '어',
#   '요',
#   'ㅠㅠㅠ'],
#  ['일본에서구독하구잇어요어늬너무이뻐요',
#   'ㅠ',
#   '그냥다해요',
#   'ㅠㅠㅠㅠㅠ',
#   '사랑',
#   '하',
#   '어',
#   '요',
#   'ㅠ',
#   '아',
#   'ㅜㅜㅜ'],
#  ['미모', '대방출', '너무', '예쁘', 'ㄴ', '것', '아니', 'ㅂ니까'],
#  ['들숨', '에', '재력', '을', '날숨', '에', '건강', '을', '..'],
#  ['보라색',
#   '아이섀',
#   '도',
#   '널',
#   'ㅁ',
#   '잘어울려',
#   '이',
#   '어',
#   '그리규',
#   '파운데이션',
#   '도',
#   '코부분',
#   '은',
#   '놔두',
#   '고',
#   '볼',
#   '이랑',
#   '외곽',
#   '은',
#   '컨실러',
#   '로',
#   '살짝',
#   '덮',
#   '으니까',
#   '중앙',
#   '이',
#   '밝',
#   '아',
#   '보이',
#   '고',
#   '잘어울리는거가태요',
#   '오늘',
#   '영상',
#   '잘봤어',
#   '이',
#   '어',
#   'ㅎ',
#   'ㅡ',
#   'ㅎ'],
#  ['언니',
#   '아이라',
#   '이',
#   'ㄴ',
#   '가끔',
#   '그리',
#   '시ㄹ',
#   '때',
#   '꼬리',
#   '짧',
#   '게',
#   '위',
#   '로',
#   '빼',
#   '면',
#   '더',
#   '자연스러울거가타',
#   '이',
#   '어',
#   '저',
#   '도',
#   '아',
#   '이',
#   '라',
#   '안그리',
#   '이',
#   '고',
#   '속눈썹',
#   '집착스탈이라',
#   '아이라',
#   '이',
#   'ㄴ',
#   '왜',
#   '안그리냐',
#   '는',
#   '댓글',
#   '이',
#   '이해',
#   '가',
#   '안되네',
#   '이',
#   '어'],
#  ['너무', '예쁘', '어요'],
#  ['완젼', '예쁘', '어요'],
#  ['졸', 'ㄴ', '예'],
#  ['오', '아', '진짜', '톤', '파괴', '이', '자', '...', '최고', '되', '세', '요', 'ㅠㅜㅜ'],
#  ['분위기', '대박적'],
#  ['오', '아', '진짜', '너무', '예쁘', '고', '너무', '사랑스러워', '이', '어'],
#  ['썰', 'ㅁ', '네', '이', 'ㄹ', '숨멎'],
#  ['나중', '에', '진진님', '이', '자주쓰시', '는', '립', '들', '소개', '하', '어', '주', '세요'],
#  ['언니', '오늘', '도', '이쁘', '어', '요', 'ㅠ'],
#  ['진진님', '미모', '약간', '미치', 'ㄴ', '듯', '..'],
#  ['넘무너무', '이뿌다', 'ㅠㅠㅠㅠ'],
#  ['사랑', '하', '어요'],
#  ['너무', '최고', '사랑', '하', '어', '요', '정말', '흑', '흑', '흑', '숙구구', 'ㅜㅝ'],
#  ['긴영상',
#   '사랑',
#   '하',
#   'ㅂ니다',
#   '...',
#   '저런',
#   '메이크업',
#   '잘어울려주',
#   '이',
#   '시어서',
#   '감사',
#   '하',
#   '어',
#   '요',
#   '...'],
#  ['진짜', '사랑', '하', '어', '요', '그냥'],
#  ['사랑', '하', '어', '요', '이유', '는', '업서요', '....'],
#  ['오',
#   '아',
#   '아이라',
#   '이',
#   'ㄴ',
#   '안그린',
#   '게',
#   '더',
#   '나',
#   '은',
#   '사람',
#   '첨',
#   '보',
#   '아',
#   '요',
#   '...',
#   '보통',
#   '아이라',
#   '이',
#   'ㄴ',
#   '안그리',
#   '이',
#   '면',
#   '큰일',
#   '나',
#   'ㄴ데',
#   'ㅜㅜ',
#   '오리',
#   '어',
#   '안그린게',
#   '짱예',
#   '..',
#   '글구',
#   '쿨한',
#   '셰도우',
#   '색',
#   '도',
#   '널',
#   'ㅁ',
#   '잘어울려',
#   '이',
#   '어'],
#  ['언니', '사랑', '하', '어', '요', 'ㅠㅠ'],
#  ['사랑', '하', '어', '요', '진진'],
#  ['ㅠㅠㅠㅠㅠ', 'ㅠㅠㅠ', 'ㄴ', '너무', '이쁘', 'ㄴ', '진진언니'],
#  ['오늘', '도', '매력진진', '...'],
#  ['천사',
#   '이',
#   'ㄴ데',
#   '점점',
#   '눈',
#   '이',
#   '악마',
#   '로',
#   '변하',
#   '어',
#   '가',
#   '는',
#   '메이크업',
#   '이',
#   '네요'],
#  [],
#  ['이렇게이쁘기있냐', '이', '고요'],
#  [],
#  ['빠'],
#  ['퍼플', '세상', '찰떡', '아니', 'ㄴ가', '요', 'ㅠㅠㅠㅠ'],
#  ['정말', '너무너무', '예쁘', '어', '요', 'ㅠㅠㅠ', '저', '의', '롤모델', 'ㅠㅠ'],
#  ['오',
#   '아',
#   '진짜',
#   '썸네일보',
#   '이',
#   '고',
#   '깜짝놀라서',
#   '들',
#   '어',
#   '오',
#   '아아',
#   '요',
#   '진짜',
#   '저',
#   '가',
#   '이때',
#   '까지',
#   '보',
#   'ㄴ',
#   '언니',
#   '영상중',
#   '에',
#   '단연',
#   '최고',
#   '로',
#   '젤',
#   '예쁘',
#   '어',
#   '요',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠㅠ'],
#  ['진진님',
#   '저',
#   '도',
#   '일본갔다',
#   '사',
#   '아',
#   '보',
#   '아',
#   '쟁여놓고',
#   '쓰는템',
#   '이',
#   'ㄴ데',
#   '이름',
#   '은',
#   '페어아크',
#   '네',
#   '이',
#   '예요',
#   '일본',
#   '에서만',
#   '파는거',
#   '같',
#   '아',
#   '일본갔을때',
#   '한번',
#   '사',
#   '아',
#   '보',
#   '세',
#   '요',
#   '여드름',
#   '나',
#   'ㄴ',
#   '곳',
#   '에',
#   '콕찍어바르',
#   '이',
#   '면',
#   '전',
#   '일',
#   '내',
#   '에',
#   '난거같아요',
#   '짱좋아요',
#   '언니',
#   '영상',
#   '보',
#   '면',
#   '트러블',
#   '신경',
#   '많',
#   '이',
#   '쓰',
#   '시는',
#   '것',
#   '같',
#   '아',
#   '아무',
#   '도',
#   '안물어봤지만',
#   '추천해용'],
#  ['오',
#   '아',
#   '대박',
#   '...',
#   '진짜',
#   '보석',
#   '들',
#   '어',
#   '있',
#   '는',
#   '조개',
#   '껍데기',
#   '안',
#   '에',
#   '사',
#   '는',
#   '바',
#   '이',
#   '다',
#   '속',
#   '에서도',
#   '얼짱',
#   '으로',
#   '유명',
#   '하',
#   'ㄴ',
#   '인어공주',
#   '같',
#   '아',
#   '진짜',
#   '너무',
#   '예쁘',
#   '시어',
#   '진짜',
#   '매일매일',
#   '이',
#   '리즈라',
#   '는',
#   '말',
#   '이',
#   '찰떡이야',
#   '어쩌',
#   'ㅁ'],
#  ['안녕',
#   '하',
#   '세',
#   '요',
#   '한국대중음악박물관',
#   '일',
#   'ㅂ니다',
#   '방탄소년단뉴이스트세븐틴아이유트와이스',
#   '싸인의상',
#   '도',
#   '전시',
#   '가',
#   '되',
#   '고',
#   '있',
#   '어',
#   '요',
#   '갤럭시노트',
#   '이벤트중',
#   '이',
#   'ㅂ니다',
#   '.',
#   '한국대중음악박물관',
#   '홈페이지',
#   '에서',
#   '확인가능',
#   '하고',
#   '누구',
#   '나',
#   '참여가능',
#   '하',
#   'ㅂ니다',
#   '한국대중음악박물관',
#   '검색',
#   '분만투자해서',
#   '갤럭시노트',
#   '응모해보',
#   '이',
#   '세요'],
#  ['라이너',
#   '한번안그리면진짜',
#   '편하',
#   'ㅁ',
#   'ㅋㅋ',
#   '눈끝도막긁을수있고',
#   '저도언니',
#   '처럼',
#   '라이너그리건안그리건차이가안나서',
#   '필요성을못느낌',
#   '으로',
#   '안그리는데',
#   '주위',
#   '에서',
#   '그리라는애들',
#   '꼭있음',
#   '..'],
#  ['저런',
#   '색깔',
#   '도',
#   '어울리',
#   '는',
#   '진진님',
#   '..',
#   '대단하시',
#   '이',
#   '다',
#   '..',
#   '매력뿜뿜실화냐',
#   '..',
#   '흑',
#   '..',
#   '너무',
#   '멋잇어',
#   'ㅠㅠㅠ'],
#  ['비',
#   '실크',
#   '페탈와',
#   '이',
#   '는',
#   '호',
#   '피부톤',
#   '에',
#   '하',
#   '어',
#   '나',
#   '아',
#   '화사',
#   '하',
#   '지',
#   '않',
#   '게',
#   '딱',
#   '맞',
#   '게',
#   '오르',
#   '아',
#   '가',
#   '아',
#   '요',
#   '어두운거',
#   '선호',
#   '하',
#   '셨으면',
#   '진짜',
#   '밝',
#   '을',
#   '듯',
#   '...'],
#  ['헐랭',
#   '저',
#   '랑',
#   '완전',
#   '똑같',
#   '아',
#   '요',
#   '저',
#   '이',
#   '더어',
#   '한쪽눈',
#   '찝자마',
#   '이',
#   '자',
#   '바로',
#   '마스카라',
#   '바르',
#   '고',
#   '그렇',
#   '어',
#   '요',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋ',
#   '눈',
#   '이',
#   '길',
#   'ㄴ',
#   '편이',
#   '이',
#   '어서',
#   '속눈썹',
#   '에',
#   '집착',
#   '얼',
#   'ㅁ',
#   'ㅊ',
#   '청',
#   '함'],
#  ['파',
#   '이',
#   '데',
#   '바르',
#   '고',
#   '나',
#   'ㄴ',
#   '뒤',
#   '의',
#   '진진님',
#   '얼굴',
#   '을',
#   '보',
#   '고',
#   '뱀파이어',
#   '가',
#   '연상됐읍니다',
#   '오늘',
#   '영상',
#   '뱀파',
#   '이',
#   '어',
#   '메이크업',
#   '이',
#   '라',
#   '고',
#   '생각',
#   '하',
#   '어',
#   '두',
#   '고',
#   '찾아올거',
#   '에이',
#   '오'],
#  ['언니',
#   '제발',
#   '이거',
#   '진진',
#   '의',
#   '화장놀',
#   '이',
#   '시리즈',
#   '로',
#   '가',
#   '시죠',
#   '언니',
#   '하고싶은거',
#   '다하',
#   '어',
#   '주',
#   '세요'],
#  ['헐', 'ㄹ', '귀걸이', '대박', '예쁘', '어', '요', '....'],
#  ['무의식중',
#   '에',
#   '반말',
#   '하',
#   '는',
#   '것',
#   '좀',
#   '줄이',
#   '어',
#   '주',
#   '시ㅁ',
#   '좋',
#   '을',
#   '것',
#   '같',
#   '아요'],
#  ['아',
#   '언니',
#   '이영상',
#   '진짜',
#   '오',
#   'ㅑ',
#   '크',
#   '어',
#   '기여워요',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠ'],
#  ['ㅠㅜㅜㅜ',
#   '진진',
#   '이렇',
#   '게',
#   '완전',
#   '색다른메이크업조아요',
#   'ㅠㅠㅠ',
#   '진진얼굴',
#   '도화지야뭐야',
#   '소화력',
#   '대박적인부분'],
#  ['앞',
#   '에',
#   '하얀색',
#   '을',
#   '바르',
#   '라는데',
#   '이',
#   '이',
#   '건',
#   '하기싫으',
#   '이',
#   '네',
#   '요',
#   '단호',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋ',
#   '너무',
#   '귀엽',
#   '어',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋㅋㅋㅋㅋ',
#   'ㅋ',
#   '언니',
#   '귀엽',
#   '고',
#   '이쁘',
#   '고',
#   '영롱',
#   '하고',
#   '혼자',
#   '다',
#   '하',
#   '어',
#   '엉엉'],
#  ['메탈릭한', '메이크업', '젤', '잘', '어울리', '잖아', '요', 'ㅠ', 'ㅠ'],
#  ['시상', '에나', '저', '색깔', '이', '어찌', '저리', '잘어울린대유'],
#  ['갑자기', '궁금해지', '었는데', '크', '어', '묻', '어', '보', '아', '되', '어요'],
#  ['오', '아', '인어공주', '이', '다'],
#  ['언니', '눈썹문신', '어디', '서', '하', '셨는지', '궁금', '하', '어', '요', '..'],
#  ['진진', '의', '영수증', '....', '제발', '....'],
#  ['아라아아랄',
#   'ㄹ',
#   '각',
#   'ㄱㄹㄱ',
#   '너무예뻐',
#   '진짜',
#   '너무너무',
#   '최고',
#   '이',
#   '야',
#   '진진언니',
#   '가',
#   '짱이야',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠㅠㅠ'],
#  ['언니', '입술', '관리', '어떻', '게', '하', '시는', '지', '궁금해용'],
#  ['진진님', '사랑', '하', '어', '요', 'ㅠㅠㅠ'],
#  ['언니',
#   '진짜',
#   '너무',
#   '예쁘',
#   '어',
#   '요',
#   'ㅠㅜㅜ',
#   '완전',
#   '와기고양',
#   '이',
#   '느끼',
#   'ㅁ',
#   '아아악',
#   'ㅜㅜㅜ',
#   '사랑',
#   '하',
#   '어요'],
#  ['오', '아', '우대박'],
#  ['언니', '이세상', '사람아니죠', '아니', '사람아니죠', '요정', '이', '죠', 'ㅠㅠ'],
#  ['분', '순삭', '언니', '왤케', '기여워', '이', '어'],
#  ['좋', '아요'],
#  ['으애', 'ㅠㅠ', '진진선물', '이', '다', '잘', '보', 'ㄹ께', '요', '새랭햅내대'],
#  ['진진', '오늘', '은', '약간', '인어공주', '같', '아', '요', '아코', '예쁘', '다', 'ㅠ', 'ㅠ'],
#  ['열일하', '는', '선풍기'],
#  ['웜톤',
#   '도',
#   '쿨톤',
#   '도',
#   '왜케',
#   'ㄷ',
#   'ㅏ',
#   '잘어울리',
#   '이',
#   '시어',
#   '요',
#   'ㅠㅠㅠㅠㅠ',
#   'ㅠㅠㅠ'],
#  ['언니', '눈썹', '문신하신거', '이', '에요'],
#  ['진진님', '하', '어', '주', '시면', '진짜', '좋을것같아', '이', '어', '..'],
#  ['오', '아', '언니', '메이크업', '완전', '찰떡'],
#  ['세', 'ㄴ', '화장', '도', '잘어울리', '이', '고', 'ㅜㅜ', '최고', '되', '시ㄴ다'],
#  ['헥', '오랜만', '에', '아이라', '이', 'ㄴ', '그리셨네욤'],
#  ['무슨', '미국', '년대', '하이틴', '스타', '같', '다', '...', '너무', '예쁘', '어', '요', 'ㅠㅠ'],
#  ['오', '아', '보라색진짜', '잘어울려요'],
#  ['ㅠㅜㅜㅠ', '언니', '존예'],
#  ['피부', '커버', '진짜', '잘', '되', 'ㄴ다', '..'],
#  ['진짜', '이번', '메이크업', '너무', '이쁘', '어', '요', 'ㅠㅠㅠㅠ'],
#  ['진진', '뭔들'],
#  ['병원', '원장님', '이랑', '인연', '무엇', '이', 'ㅂ니까', '친화력', '쩔어', 'ㅠ'],
#  ['저',
#   '포니',
#   '이펙트',
#   '립',
#   '틴트',
#   '엄청',
#   '좋',
#   '은',
#   '데',
#   '향',
#   '이',
#   '진짜',
#   '널',
#   'ㅁ',
#   '별루예욥'],
#  ['이번', '에', '아이라', '이', 'ㄴ', '그렸네욧', '아', '이', '라', '그리', '어도', '여신'],
#  ['미친미친', '대미친'],
#  ['언니', '만', '하루종일', '보', '아아', '요', 'ㅠㅠ'],
#  ['최애', '언니'],
#  ['아이라인'],
#  ['예쁘', '세', '요', 'ㅠㅠㅠ'],
#  ['너무', '이쁘', '어', 'ㅠㅠ'],
#  ['언니', '인스타그램', '하세여'],
#  ['진진', '이', 'ㅁ', '밑트', '이', 'ㅁ', '하', '시ㄴ', '것', '이', 'ㄴ가', '요'],
#  ['천사', '같', '아', '요', '열', '시ㄴ', '..'],
#  ['그냥옙허', '..', '그냥'],
#  ['언니', '입술', '도', '뚫어주세용'],
#  ['으윽', '기다리', '었어', '요', 'ㅠㅠ'],
#  ['항상', '보', '아', '세상', '이쁘', 'ㄴ', '언니얌'],
#  ['진짜', '너무예뻐요'],
#  ['예뻐용', 'ㅎ', '오오오'],
#  ['왕아', '아'],
#  ['언니', '태닝', '왜', '하', '어', '요', '궁금해서요']]

# %%
kk
# Out:
# [['악',
#   '미치',
#   '었',
#   '다',
#   '요즘',
#   '언니',
#   '진',
#   '챠',
#   '너무',
#   '너무너무',
#   '좋',
#   '아서',
#   '하루',
#   '다섯',
#   '시간',
#   '씩',
#   '언니',
#   '영상',
#   '보',
#   '고',
#   '있',
#   '어요',
#   '엉엉',
#   '진짜',
#   '방금',
#   '도',
#   '보',
#   '는데',
#   '또',
#   '영상',
#   '올라오',
#   '아서',
#   '진짜',
#   '행보',
#   '하',
#   '게요',
#   '라이프',
#   '진진'],
#  ['언니',
#   '예전',
#   '영상',
#   '보',
#   '다가',
#   '오늘',
#   '올라오',
#   'ㄴ',
#   '영상',
#   '보',
#   '니까',
#   '피부',
#   '가',
#   '너무',
#   '좋',
#   '아',
#   '시',
#   'ㄴ',
#   '거',
#   '같',
#   '아요',
#   '이제',
#   '아침',
#   '저녁',
#   '으로',
#   '쌀쌀',
#   '하',
#   '니까',
#   '언니',
#   '가',
#   '좋아하',
#   '시',
#   '는',
#   '잠옷',
#   '추천',
#   '영상',
#   '을',
#   '보',
#   '고',
#   '싶',
#   '어요',
#   'ㅠㅠㅠ'],
#  ['일본',
#   '에서',
#   '구독',
#   '하',
#   '구',
#   '잇',
#   '어요',
#   '어',
#   '어',
#   '늬',
#   '너무',
#   '이쁘',
#   '어요',
#   'ㅠ',
#   '그냥',
#   '다하',
#   '어요',
#   'ㅠㅠㅠㅠㅠ',
#   '사랑',
#   '하',
#   '어요',
#   'ㅠ',
#   '아',
#   'ㅜㅜㅜ'],
#  ['미모', '대', '방출', '너무', '예쁘', 'ㄴ', '거', '아니', 'ㅂ니까'],
#  ['들숨', '에', '재력', '을', '날숨', '에', '건강', '을', '..'],
#  ['보라색',
#   '아이섀도',
#   '넘',
#   '잘',
#   '어울리',
#   '어',
#   '여',
#   '그리',
#   '규',
#   '파운데이션',
#   '도',
#   '코',
#   '부분',
#   '은',
#   '놔두',
#   '고',
#   '볼',
#   '이랑',
#   '외곽',
#   '은',
#   '커',
#   'ㄴ',
#   '실러',
#   '로',
#   '살짝',
#   '덮',
#   '으니까',
#   '중앙',
#   '이',
#   '밝',
#   '아',
#   '보이',
#   '고',
#   '잘',
#   '어울리',
#   '는',
#   '거가',
#   '태',
#   '요',
#   '오늘',
#   '영상',
#   '잘',
#   '보',
#   '았',
#   '어',
#   '여',
#   'ㅎ',
#   'ㅡ',
#   'ㅎ'],
#  ['언니',
#   '아이',
#   '라인',
#   '가끔',
#   '그리',
#   '시',
#   'ㄹ',
#   '때',
#   '꼬리',
#   '짧',
#   '게',
#   '위로',
#   '빼',
#   '면',
#   '더',
#   '자연',
#   '스럽',
#   'ㄹ',
#   '거가',
#   '타',
#   '아',
#   '여',
#   '저',
#   '어도',
#   '아',
#   '라',
#   '안',
#   '그리',
#   '고',
#   '속눈썹',
#   '집착',
#   '스탈',
#   '이',
#   '라',
#   '아이',
#   '라인',
#   '왜',
#   '안',
#   '그리',
#   '냐',
#   '느',
#   'ㄴ',
#   '댓',
#   '글',
#   '이',
#   '이해',
#   '가',
#   '안되',
#   '네',
#   '여'],
#  ['너무', '예쁘', '어요'],
#  ['와', 'ㄴ', '졀', 'ㄴ', '예쁘', '어요'],
#  ['졸', 'ㄴ', '예'],
#  ['오', '아', '진짜', '톤', '파괴자', '...', '최고', '되', '세요', 'ㅠㅜㅜ'],
#  ['분위기', '대박', '적'],
#  ['오', '아', '진짜', '너무', '예쁘', '고', '너무', '사랑', '스럽', '어', '열'],
#  ['써', 'ㅁ', '네', '일', '숨', '멎'],
#  ['나중',
#   '에',
#   '진',
#   '진',
#   '님',
#   '이',
#   '자주',
#   '쓰',
#   '시',
#   '는',
#   '립',
#   '들',
#   '소개',
#   '하',
#   '어',
#   '주',
#   '세요'],
#  ['언니', '오늘', '도', '이쁘', '어요', 'ㅠ'],
#  ['진진', '니', 'ㅁ', '미모', '약간', '미치', 'ㄴ', '듯', '..'],
#  ['넘', '무', '너무', '이뿌', '다', 'ㅠㅠㅠㅠ'],
#  ['사랑', '하', '어요'],
#  ['너무', '최고', '사랑', '하', '어요', '정말', '흑', '흑', '흑', '숙', '구', '구', 'ㅜ', 'ㅝ'],
#  ['길',
#   'ㄴ',
#   '영상',
#   '사랑',
#   '하',
#   'ㅂ니다',
#   '...',
#   '저러',
#   'ㄴ',
#   '메이크업',
#   '잘',
#   '어울리',
#   '어',
#   '주',
#   '시',
#   '어서',
#   '감사',
#   '해',
#   '요',
#   '...'],
#  ['진짜', '사랑', '하', '어요', '그냥'],
#  ['사랑', '하', '어요', '이유', '는', '업', '서', '요', '....'],
#  ['오',
#   '아',
#   '아이',
#   '라인',
#   '안',
#   '그리',
#   'ㄴ',
#   '것',
#   '이',
#   '더',
#   '낫',
#   '은',
#   '사람',
#   '첨',
#   '보',
#   '아요',
#   '...',
#   '보통',
#   '아이',
#   '라인',
#   '안',
#   '그리',
#   '면',
#   '큰일',
#   '나',
#   '는데',
#   'ㅜㅜ',
#   '오리',
#   '어',
#   '안',
#   '그리',
#   'ㄴ',
#   '것',
#   '이',
#   '짱',
#   '예',
#   '..',
#   '글',
#   '구',
#   '쿨하',
#   'ㄴ',
#   '셰',
#   '도',
#   '우',
#   '색도',
#   '넘',
#   '잘',
#   '어울리',
#   '어',
#   '열'],
#  ['언니', '사랑', '하', '어요', 'ㅠㅠ'],
#  ['사랑', '하', '어요', '진진'],
#  ['ㅠㅠㅠㅠㅠㅠㅠㅠ', 'ㄴ', '너무', '이쁘', 'ㄴ', '진진', '언니'],
#  ['오늘', '도', '매력', '진진', '...'],
#  ['천사',
#   '이',
#   'ㄴ데',
#   '점점',
#   '눈',
#   '이',
#   '악마',
#   '로',
#   '변하',
#   '어',
#   '갈',
#   '는',
#   '메이크업',
#   '이',
#   '네요'],
#  [],
#  ['이렇게', '이쁘', '기', '있', '냐', '고요'],
#  [],
#  ['빨'],
#  ['푸', '어', '플', '세상', '찰떡', '아니', 'ㄴ가요', 'ㅠㅠㅠㅠ'],
#  ['정말', '너무너무', '예쁘', '어요', 'ㅠㅠㅠ', '제', '롤', '모델', 'ㅠㅠ'],
#  ['오',
#   '아',
#   '진짜',
#   '써',
#   'ㅁ',
#   '네',
#   '일',
#   '보고',
#   '깜짝',
#   '놀라',
#   '서',
#   '들어오',
#   '았',
#   '어요',
#   '진짜',
#   '저',
#   '가',
#   '이때',
#   '까지',
#   '보',
#   'ㄴ',
#   '언니',
#   '영상',
#   '중',
#   '에',
#   '단연',
#   '최고',
#   '로',
#   '젤',
#   '예쁘',
#   '어요',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['진진',
#   '니',
#   'ㅁ',
#   '저',
#   '어도',
#   '일본',
#   '가',
#   '었',
#   '다',
#   '사',
#   '아',
#   '보',
#   '아서',
#   '쟁이',
#   '어',
#   '놓',
#   '고',
#   '쓰',
#   '는',
#   '템',
#   '이',
#   'ㄴ데',
#   '이름',
#   '은',
#   '페어',
#   '아크',
#   '네',
#   '예',
#   '요',
#   '일본',
#   '에서',
#   '만',
#   '팔',
#   '는',
#   '거',
#   '같',
#   '아서',
#   '일본',
#   '가',
#   '었',
#   '을',
#   '때',
#   '한번',
#   '사',
#   '보세',
#   '요',
#   '여드름',
#   '낳',
#   'ㄴ',
#   '곳',
#   '에',
#   '콕',
#   '찍',
#   '어',
#   '바르',
#   '면',
#   '전',
#   '일',
#   '내',
#   '에',
#   '낳',
#   'ㄴ',
#   '거',
#   '같',
#   '아요',
#   '짱',
#   '좋',
#   '아요',
#   '언니',
#   '영상',
#   '보',
#   '면',
#   '트러블',
#   '신경',
#   '많이',
#   '쓰',
#   '시',
#   '는',
#   '거',
#   '같',
#   '아서',
#   '아무',
#   '도',
#   '안',
#   '물어보',
#   '았',
#   '지만',
#   '추천',
#   '해용'],
#  ['오',
#   '아',
#   '대박',
#   '...',
#   '진짜',
#   '보석',
#   '듣',
#   '어',
#   '있',
#   '는',
#   '조개',
#   '껍데기',
#   '안',
#   '에',
#   '살',
#   '는',
#   '바다',
#   '속',
#   '에서',
#   '도',
#   '얼',
#   '짱',
#   '으로',
#   '유명',
#   '하',
#   'ㄴ',
#   '인어',
#   '공주',
#   '같',
#   '아',
#   '진짜',
#   '너무',
#   '예쁘',
#   '시',
#   '어',
#   '진짜',
#   '매일',
#   '매일',
#   '이',
#   '리즈라',
#   '는',
#   '말',
#   '이',
#   '찰떡',
#   '이야',
#   '어쩜'],
#  ['안녕',
#   '하세',
#   '요',
#   '한국',
#   '대중음악',
#   '박물관',
#   '이',
#   'ㅂ니다',
#   '방탄',
#   '소년단',
#   '뉴',
#   '이스트',
#   '세',
#   '블',
#   'ㄴ',
#   '티',
#   'ㄴ',
#   '아이',
#   '유',
#   '트와이스',
#   '싸인',
#   '의',
#   '상도',
#   '전시',
#   '가',
#   '되',
#   '고',
#   '있',
#   '어요',
#   '개',
#   'ㄹ',
#   '럭',
#   '시',
#   '노트',
#   '이벤트',
#   '중',
#   '이',
#   'ㅂ니다',
#   '.',
#   '한국',
#   '대중음악',
#   '박물관',
#   '홈페이지',
#   '에서',
#   '확인',
#   '가능',
#   '하',
#   '고',
#   '누구',
#   '나',
#   '참여',
#   '가능',
#   '하',
#   'ㅂ니다',
#   '한국',
#   '대중음악',
#   '박물관',
#   '검색',
#   '분만',
#   '투자',
#   '하',
#   '어서',
#   '개',
#   'ㄹ',
#   '럭',
#   '시',
#   '노트',
#   '응모',
#   '하',
#   '어',
#   '보',
#   '세요'],
#  ['라이너',
#   '한번',
#   '안',
#   '그리',
#   '면',
#   '진짜',
#   '편하',
#   'ㅁ',
#   'ㅋㅋ',
#   '눈',
#   '끝',
#   '도',
#   '막',
#   '긁',
#   '을',
#   '수',
#   '있',
#   '고',
#   '저',
#   '어도',
#   '언니',
#   '처럼',
#   '라이너',
#   '그리',
#   '건',
#   '안',
#   '그리',
#   '건',
#   '차이',
#   '가',
#   '안',
#   '나',
#   '서',
#   '필요성',
#   '을',
#   '못',
#   '느낌',
#   '으로',
#   '안',
#   '그리',
#   '는데',
#   '주위',
#   '에서',
#   '그리',
#   '라는',
#   '애',
#   '들',
#   '꼭',
#   '있음',
#   '..'],
#  ['저런',
#   '색깔',
#   '도',
#   '어울리',
#   '는',
#   '진',
#   '진',
#   '님',
#   '..',
#   '대단',
#   '하',
#   '시',
#   '다',
#   '..',
#   '매력',
#   '뿜뿜',
#   '실화',
#   '이',
#   '냐',
#   '..',
#   '흑',
#   '..',
#   '너무',
#   '멋',
#   '잇',
#   '어',
#   'ㅠㅠㅠ'],
#  ['비',
#   '실크',
#   '페탈와이',
#   '는',
#   '호',
#   '피부',
#   '톤',
#   '에',
#   '하나',
#   '도',
#   '화사',
#   '하',
#   '지',
#   '않',
#   '게',
#   '딱',
#   '맞',
#   '게',
#   '오르',
#   '아',
#   '가요',
#   '어둡',
#   'ㄴ',
#   '거',
#   '선호',
#   '하',
#   '시',
#   '었',
#   '으면',
#   '진짜',
#   '밝',
#   '을',
#   '듯',
#   '...'],
#  ['헐',
#   'ㄹ',
#   '랭',
#   '저',
#   '랑',
#   '완전',
#   '똑같',
#   '아요',
#   '저',
#   '더',
#   '한쪽',
#   '눈',
#   '찝',
#   '자마자',
#   '바로',
#   '마스카라',
#   '바르',
#   '고',
#   '그리하',
#   '여요',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '눈',
#   '이',
#   '길',
#   'ㄴ',
#   '편이',
#   '여',
#   '서',
#   '속눈썹',
#   '에',
#   '집착',
#   '어',
#   'ㅁ',
#   'ㅊ',
#   '청',
#   '함'],
#  ['파',
#   '데',
#   '바르',
#   '고',
#   '낳',
#   'ㄴ',
#   '뒤',
#   '의',
#   '진진',
#   '니',
#   'ㅁ',
#   '얼굴',
#   '을',
#   '보',
#   '고',
#   '뱀파이어',
#   '가',
#   '연상',
#   '되',
#   '었',
#   '읍니다',
#   '오늘',
#   '영상',
#   '뱀파이어',
#   '메이크업',
#   '이',
#   '라고',
#   '생각',
#   '하',
#   '어',
#   '두',
#   '고',
#   '찾아오',
#   'ㄹ',
#   '거',
#   '에',
#   '오'],
#  ['언니',
#   '제발',
#   '이거',
#   '질',
#   'ㄴ',
#   '진의',
#   '화장',
#   '놀이',
#   '시리즈',
#   '로',
#   '가',
#   '시',
#   '죠',
#   '언니',
#   '하',
#   '고',
#   '싶',
#   '은',
#   '거',
#   '다하',
#   '어',
#   '주',
#   '세요'],
#  ['헐', 'ㄹ', '귀걸이', '대박', '예쁘', '어요', '....'],
#  ['무의식',
#   '중',
#   '에',
#   '반말',
#   '하',
#   '는',
#   '것',
#   '좀',
#   '줄이',
#   '어',
#   '주심',
#   '좋',
#   '을',
#   '것',
#   '같',
#   '아요'],
#  ['아',
#   '아',
#   '언니',
#   '이',
#   '영상',
#   '진짜',
#   '오',
#   'ㅑ',
#   '하',
#   '게',
#   '기여워',
#   '요',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['ㅠㅜㅜㅜ',
#   '진진',
#   '이렇게',
#   '완전',
#   '색다르',
#   'ㄴ',
#   '메이크업',
#   '조아',
#   '요',
#   'ㅠㅠㅠ',
#   '진',
#   '지',
#   'ㄴ',
#   '얼굴',
#   '도화지',
#   '야',
#   '뭐',
#   '야',
#   '소화력',
#   '대박',
#   '적인',
#   '부분'],
#  ['앞',
#   '에',
#   '하얀색',
#   '을',
#   '바르',
#   '라는',
#   '데',
#   '이',
#   '건',
#   '하기싫으네',
#   '요',
#   '단호',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '너무',
#   '귀엽',
#   '어',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '언니',
#   '귀엽',
#   '고',
#   '이쁘',
#   '고',
#   '영롱',
#   '하',
#   '고',
#   '혼자',
#   '다',
#   '하',
#   '어',
#   '엉엉'],
#  ['메탈', '릭', '하', 'ㄴ', '메이크업', '젤', '잘', '어울리', '잖아요', 'ㅠ', 'ㅠ'],
#  ['시상', '에', '나', '저', '색깔', '이', '어찌', '저리', '잘', '어울리', 'ㄴ', '대유'],
#  ['갑자기', '궁금', '해지', '었', '는데', '키', '물어보', '아도', '되', '어요'],
#  ['오', '아', '인어', '공주', '이', '다'],
#  ['언니', '눈썹', '문신', '어디', '서', '하', '시', '었', '는지', '궁금하', '어요', '..'],
#  ['질', 'ㄴ', '진의', '영수증', '....', '제', '발', '....'],
#  ['아',
#   '라',
#   '아',
#   '아',
#   '랄',
#   'ㄹ',
#   '각',
#   'ㄱ',
#   'ㄹ',
#   'ㄱ',
#   '너무',
#   '예쁘',
#   '어',
#   '진짜',
#   '너무너무',
#   '최고',
#   '야',
#   '진진',
#   '언니',
#   '가',
#   '짱',
#   '이',
#   '야',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['언니', '입술', '관리', '어떻', '게', '하', '시', '는', '지', '궁금하', '어요'],
#  ['진진', '니', 'ㅁ', '사랑', '하', '어요', 'ㅠㅠㅠ'],
#  ['언니',
#   '진짜',
#   '너무',
#   '예쁘',
#   '어요',
#   'ㅠㅜㅜ',
#   '완전',
#   '오',
#   '아',
#   '기고',
#   '양이',
#   '느낌',
#   '아',
#   '아',
#   '악',
#   'ㅜㅜㅜ',
#   '사랑',
#   '하',
#   '어요'],
#  ['오', '아', '우대', '박'],
#  ['언니',
#   '이',
#   '세상',
#   '사람',
#   '아니',
#   '죠',
#   '알',
#   '니',
#   '사람',
#   '아니',
#   '죠',
#   '요정',
#   '이',
#   '죠',
#   'ㅠㅠ'],
#  ['분', '순삭', '언니', '왤', '하', '게', '기여워', '여'],
#  ['좋', '아요'],
#  ['으', '애', 'ㅠㅠ', '진진', '선물', '이', '다', '잘', '보', 'ㄹ게요', '새', '랭햅', '내', '대'],
#  ['진진',
#   '오늘',
#   '은',
#   '약간',
#   '인어',
#   '공주',
#   '같',
#   '아요',
#   '아',
#   '아',
#   '코',
#   '예쁘',
#   '다',
#   'ㅠ',
#   'ㅠ'],
#  ['열일', '하', '는', '선풍기'],
#  ['웜톤',
#   '도',
#   '쿠',
#   'ㄹ',
#   '톤',
#   '도',
#   '왜케',
#   'ㄷ',
#   'ㅏ',
#   '잘',
#   '어울리',
#   '시',
#   '어요',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['언니', '눈썹', '문신', '하', '시', 'ㄴ', '거', '에', '요'],
#  ['진진',
#   '니',
#   'ㅁ',
#   '하',
#   '어',
#   '주',
#   '시',
#   '면',
#   '진짜',
#   '좋',
#   '을',
#   '것',
#   '같',
#   '아',
#   '여',
#   '..'],
#  ['오', '아', '언니', '메이크업', '완전', '찰떡'],
#  ['세', 'ㄴ', '화장', '도', '잘', '어울리', '고', 'ㅜㅜ', '최고', '되', '시', 'ㄴ다'],
#  ['헥', '오랜만', '에', '아이', '라인', '그리', '시', '었', '네요'],
#  ['무슨', '미국', '년대', '하이틴', '스타', '같', '다', '...', '너무', '예쁘', '어요', 'ㅠㅠ'],
#  ['오', '아', '보라색', '진짜', '잘', '어울리', '어요'],
#  ['ㅠㅜㅜㅠ', '언니', '졸', 'ㄴ', '예'],
#  ['피부', '커버', '진짜', '잘', '되', 'ㄴ다', '..'],
#  ['진짜', '이번', '메이크업', '너무', '이쁘', '어요', 'ㅠㅠㅠㅠ'],
#  ['진진', '뭔', '듣'],
#  ['병원',
#   '원',
#   '장님',
#   '이랑',
#   '인연',
#   '무엇',
#   '이',
#   'ㅂ니까',
#   '치',
#   'ㄴ',
#   '화력',
#   '쩔',
#   '어',
#   'ㅠ'],
#  ['저',
#   '포니',
#   '이펙트',
#   '립',
#   '틴트',
#   '엄청',
#   '좋',
#   '은데',
#   '향',
#   '이',
#   '진짜',
#   '넘',
#   '별루',
#   '예',
#   '욥'],
#  ['이번', '에', '아이', '라인', '그리', '었', '네', '욧', '아', '라', '그리', '어도', '여신'],
#  ['미치', 'ㄴ', '미치', 'ㄴ', '대미', '친'],
#  ['언니', '만', '하루', '종일', '보', '았', '어요', 'ㅠㅠ'],
#  ['최', '애', '언니'],
#  ['아이', '라인'],
#  ['예쁘', '세요', 'ㅠㅠㅠ'],
#  ['너무', '이쁘', '어', 'ㅠㅠ'],
#  ['언니', '인', '스타', '그램', '하세', '열'],
#  ['진', '진임', '밑', '트임', '하', '시', 'ㄴ', '것', '이', 'ㄴ가요'],
#  ['천사', '같', '아요', '여신', '..'],
#  ['그냥', '옙허', '..', '그냥'],
#  ['언니', '입술', '도', '뚫', '어', '주세', '용'],
#  ['으', '윽', '기다리', '었', '어요', 'ㅠㅠ'],
#  ['항상', '보', '아도', '세상', '이쁘', 'ㄴ', '언니', '얌'],
#  ['진짜', '너무', '예쁘', '어요'],
#  ['예쁘', '어', '용', 'ㅎ', '오오', '오'],
#  ['왕', '아아'],
#  ['언니', '태', '닝', '왜', '해', '요', '궁금하', '어서요']]

# %%
twi
# Out:
# [['악',
#   '미쳤다',
#   '요즘',
#   '언니',
#   '진챠',
#   '너무',
#   '너무',
#   '너무',
#   '좋아서',
#   '하루',
#   '다섯',
#   '시간',
#   '씩',
#   '언니',
#   '영상',
#   '보고있어요',
#   '엉엉',
#   '진짜',
#   '방금',
#   '도',
#   '보는데',
#   '또',
#   '영상',
#   '올라와서',
#   '진짜',
#   '행',
#   '보케',
#   '요',
#   '라이프',
#   '진진'],
#  ['언니',
#   '예전',
#   '영상',
#   '보다가',
#   '오늘',
#   '올라온',
#   '영상',
#   '보',
#   '니까',
#   '피부',
#   '가',
#   '너무',
#   '좋',
#   '아신거',
#   '같아요',
#   '이제',
#   '아침',
#   '저녁',
#   '으로',
#   '쌀쌀',
#   '하니까',
#   '언니',
#   '가',
#   '좋아하시는',
#   '잠옷',
#   '추천',
#   '영상',
#   '을',
#   '보고싶어요',
#   'ㅠㅠㅠ'],
#  ['일본',
#   '에서',
#   '구독',
#   '하구',
#   '잇어요',
#   '어늬',
#   '너무',
#   '이뻐요',
#   'ㅠ',
#   '그냥',
#   '다해',
#   '요',
#   'ㅠㅠㅠㅠㅠ',
#   '사랑',
#   '해요',
#   'ㅠ',
#   '아',
#   'ㅜㅜㅜ'],
#  ['미모', '대', '방출', '너무', '예쁜', '거', '아닙니까'],
#  ['들숨', '에', '재력', '을', '날숨', '에', '건강', '을', '..'],
#  ['보라색',
#   '아이',
#   '섀도',
#   '넘',
#   '잘',
#   '어울려여',
#   '그리',
#   '규',
#   '파운데이션',
#   '도',
#   '코',
#   '부분',
#   '은',
#   '놔두고',
#   '볼',
#   '이랑',
#   '외곽',
#   '은',
#   '컨실러',
#   '로',
#   '살짝',
#   '덮으니까',
#   '중앙',
#   '이',
#   '밝아',
#   '보이',
#   '고',
#   '잘',
#   '어울리는거가',
#   '태',
#   '요',
#   '오늘',
#   '영상',
#   '잘',
#   '봤어여',
#   'ㅎ',
#   'ㅡ',
#   'ㅎ'],
#  ['언니',
#   '아이라인',
#   '가끔',
#   '그리실',
#   '때',
#   '꼬리',
#   '짧게',
#   '위로',
#   '빼면',
#   '더',
#   '자연스러울거',
#   '가타',
#   '여',
#   '저',
#   '도',
#   '아라',
#   '안그리',
#   '고',
#   '속눈썹',
#   '집착',
#   '스탈',
#   '이라',
#   '아이라인',
#   '왜',
#   '안',
#   '그리냐는',
#   '댓글',
#   '이',
#   '이해',
#   '가',
#   '안되',
#   '네',
#   '여'],
#  ['너무', '예뻐요'],
#  ['완젼', '예뻐요'],
#  ['존', '예'],
#  ['와', '진짜', '톤', '파괴', '자', '...', '최고', '되세요', 'ㅠㅜㅜ'],
#  ['분위기', '대박', '적'],
#  ['와', '진짜', '너무', '예쁘고', '너무', '사랑스러워여'],
#  ['썸네일', '숨', '멎'],
#  ['나중', '에', '진진', '님', '이', '자주', '쓰시', '는', '립', '들', '소개', '해주세요'],
#  ['언니', '오늘', '도', '이뻐요', 'ㅠ'],
#  ['진진', '님', '미모', '약간', '미친듯', '..'],
#  ['넘', '무', '너무', '이뿌다', 'ㅠㅠㅠㅠ'],
#  ['사랑', '해요'],
#  ['너무', '최고', '사랑', '해요', '정말', '흑', '흑', '흑', '숙', '구구', 'ㅜㅝ'],
#  ['긴', '영상', '사랑', '합니다', '...', '저런', '메이크업', '잘', '어울려주셔서', '감사해요', '...'],
#  ['진짜', '사랑', '해요', '그냥'],
#  ['사랑', '해요', '이유', '는', '업서요', '....'],
#  ['와',
#   '아이라인',
#   '안',
#   '그린게',
#   '더',
#   '나은',
#   '사람',
#   '첨',
#   '봐요',
#   '...',
#   '보통',
#   '아이라인',
#   '안그리',
#   '면',
#   '큰일',
#   '나는데',
#   'ㅜㅜ',
#   '오려',
#   '안',
#   '그린게',
#   '짱',
#   '예',
#   '..',
#   '글구',
#   '쿨한',
#   '셰',
#   '도우',
#   '색도',
#   '넘',
#   '잘',
#   '어울려여'],
#  ['언니', '사랑', '해요', 'ㅠㅠ'],
#  ['사랑', '해요', '진진'],
#  ['ㅠㅠㅠㅠㅠㅠㅠㅠ', 'ㄴ', '너무', '이쁜', '진진', '언니'],
#  ['오늘', '도', '매력', '진진', '...'],
#  ['천사', '인데', '점점', '눈', '이', '악마', '로', '변해가는', '메이크업', '이네', '요'],
#  [],
#  ['이렇게', '이쁘기', '있냐고요'],
#  [],
#  ['빠'],
#  ['퍼플', '세상', '찰떡', '아닌가요', 'ㅠㅠㅠㅠ'],
#  ['정말', '너무', '너무', '예뻐요', 'ㅠㅠㅠ', '제', '롤모델', 'ㅠㅠ'],
#  ['와',
#   '진짜',
#   '썸네일',
#   '보고',
#   '깜짝',
#   '놀라서',
#   '들어왔어요',
#   '진짜',
#   '제',
#   '가',
#   '이',
#   '때',
#   '까지',
#   '본',
#   '언니',
#   '영상',
#   '중',
#   '에',
#   '단연',
#   '최고',
#   '로',
#   '젤',
#   '예뻐요',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['진진',
#   '님',
#   '저',
#   '도',
#   '일본',
#   '갔다',
#   '사봐서',
#   '쟁여놓',
#   '고',
#   '쓰는',
#   '템',
#   '인데',
#   '이름',
#   '은',
#   '페어',
#   '아크네',
#   '예요',
#   '일본',
#   '에서만',
#   '파는거',
#   '같아서',
#   '일본',
#   '갔을',
#   '때',
#   '한번',
#   '사보세요',
#   '여드름',
#   '난',
#   '곳',
#   '에',
#   '콕',
#   '찍어',
#   '바르면',
#   '전',
#   '일',
#   '내',
#   '에',
#   '난거',
#   '같아요',
#   '짱',
#   '좋아요',
#   '언니',
#   '영상',
#   '보면',
#   '트러블',
#   '신경',
#   '많이',
#   '쓰시',
#   '는',
#   '거',
#   '같아서',
#   '아무',
#   '도',
#   '안',
#   '물어봤지만',
#   '추천',
#   '해용'],
#  ['와',
#   '대박',
#   '...',
#   '진짜',
#   '보석',
#   '들어있는',
#   '조개',
#   '껍데기',
#   '안',
#   '에',
#   '사는',
#   '바다',
#   '속',
#   '에서도',
#   '얼짱',
#   '으로',
#   '유명한',
#   '인어공주',
#   '같아',
#   '진짜',
#   '너무',
#   '예쁘셔',
#   '진짜',
#   '매',
#   '일',
#   '매일',
#   '이',
#   '리즈',
#   '라는',
#   '말',
#   '이',
#   '찰떡',
#   '이야',
#   '어쩜'],
#  ['안녕하세요',
#   '한국',
#   '대중음악',
#   '박물관',
#   '입니다',
#   '방탄소년단',
#   '뉴이스트',
#   '세븐',
#   '틴',
#   '아이유',
#   '트와이스',
#   '싸인',
#   '의상',
#   '도',
#   '전시',
#   '가',
#   '되고있어요',
#   '갤럭시',
#   '노트',
#   '이벤트',
#   '중',
#   '입니다',
#   '.',
#   '한국',
#   '대중음악',
#   '박물관',
#   '홈페이지',
#   '에서',
#   '확인가능',
#   '하고',
#   '누구',
#   '나',
#   '참여',
#   '가능합니다',
#   '한국',
#   '대중음악',
#   '박물관',
#   '검색',
#   '분만',
#   '투자',
#   '해서',
#   '갤럭시',
#   '노트',
#   '응모',
#   '해보세요'],
#  ['라이너',
#   '한번',
#   '안그리',
#   '면',
#   '진짜',
#   '편함',
#   'ㅋㅋ',
#   '눈끝',
#   '도막',
#   '긁을수있고',
#   '저',
#   '도',
#   '언니',
#   '처럼',
#   '라이너',
#   '그리건',
#   '안그리',
#   '건',
#   '차이가안나서',
#   '필요성',
#   '을',
#   '못',
#   '느낌으로',
#   '안',
#   '그리는데',
#   '주위',
#   '에서',
#   '그리라는',
#   '애',
#   '들',
#   '꼭',
#   '있음',
#   '..'],
#  ['저런',
#   '색깔',
#   '도',
#   '어울리는',
#   '진진',
#   '님',
#   '..',
#   '대단하시다',
#   '..',
#   '매력',
#   '뿜뿜',
#   '실화',
#   '냐',
#   '..',
#   '흑',
#   '..',
#   '너무',
#   '멋',
#   '잇어',
#   'ㅠㅠㅠ'],
#  ['비',
#   '실크',
#   '페탈와이',
#   '는',
#   '호',
#   '피부',
#   '톤',
#   '에',
#   '하나',
#   '도',
#   '화사하지',
#   '않게',
#   '딱',
#   '맞게',
#   '올라가요',
#   '어',
#   '두',
#   '운거',
#   '선호',
#   '하셨으면',
#   '진짜',
#   '밝을듯',
#   '...'],
#  ['헐랭',
#   '저',
#   '랑',
#   '완전',
#   '똑같아요',
#   '저',
#   '더',
#   '한쪽',
#   '눈',
#   '찝자마자',
#   '바로',
#   '마스카라',
#   '바르고',
#   '그래요',
#   'ㅋㅋㅋㅋㅋㅋ',
#   '눈',
#   '이',
#   '긴',
#   '편이',
#   '여서',
#   '속눈썹',
#   '에',
#   '집착',
#   '엄',
#   'ㅊ',
#   '청',
#   '함'],
#  ['파데',
#   '바르고',
#   '난',
#   '뒤',
#   '의',
#   '진진',
#   '님',
#   '얼굴',
#   '을',
#   '보고',
#   '뱀파이어',
#   '가',
#   '연상',
#   '됐',
#   '읍니',
#   '다',
#   '오늘',
#   '영상',
#   '뱀파이어',
#   '메이크업',
#   '이라고',
#   '생각',
#   '해',
#   '두고',
#   '찾아올거에',
#   '오'],
#  ['언니',
#   '제발',
#   '이',
#   '거',
#   '진진',
#   '의',
#   '화장',
#   '놀이',
#   '시리즈',
#   '로',
#   '가시',
#   '죠',
#   '언니',
#   '하고',
#   '싶은거',
#   '다해',
#   '주세요'],
#  ['헐', '귀걸이', '대박', '예뻐요', '....'],
#  ['무의식', '중', '에', '반말', '하는', '것', '좀', '줄여', '주심', '좋을것', '같아요'],
#  ['아',
#   '언니',
#   '이',
#   '영상',
#   '진짜',
#   '오',
#   'ㅑ',
#   '케',
#   '기여',
#   '워',
#   '요',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['ㅠㅜㅜㅜ',
#   '진진',
#   '이렇게',
#   '완전',
#   '색다른',
#   '메이크업',
#   '조아요',
#   'ㅠㅠㅠ',
#   '진진',
#   '얼굴',
#   '도화지',
#   '야',
#   '뭐',
#   '야',
#   '소화',
#   '력',
#   '대박',
#   '적',
#   '인',
#   '부분'],
#  ['앞',
#   '에',
#   '하얀색',
#   '을',
#   '바르라는데',
#   '이건',
#   '하기',
#   '싫으네요',
#   '단호',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '너무',
#   '귀여워',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '언니',
#   '귀엽고',
#   '이쁘고',
#   '영롱하고',
#   '혼자',
#   '다',
#   '해',
#   '엉엉'],
#  ['메탈릭', '한', '메이크업', '젤', '잘', '어울리잖아요', 'ㅠ', 'ㅠ'],
#  ['시상', '에나', '저', '색깔', '이', '어찌', '저리', '잘', '어울린', '대유'],
#  ['갑자기', '궁금해졌는데', '키', '물어봐도', '돼요'],
#  ['와', '인어공주', '다'],
#  ['언니', '눈썹', '문신', '어디서', '하셨는지', '궁금해요', '..'],
#  ['진진', '의', '영수증', '....', '제발', '....'],
#  ['아',
#   '라',
#   '아아',
#   '랄',
#   'ㄹ',
#   '각',
#   'ㄱㄹㄱ',
#   '너무',
#   '예뻐',
#   '진짜',
#   '너무',
#   '너무',
#   '최고',
#   '야',
#   '진진',
#   '언니',
#   '가',
#   '짱',
#   '이야',
#   'ㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['언니', '입술', '관리', '어떻게', '하시는', '지', '궁금해용'],
#  ['진진', '님', '사랑', '해요', 'ㅠㅠㅠ'],
#  ['언니',
#   '진짜',
#   '너무',
#   '예뻐요',
#   'ㅠㅜㅜ',
#   '완전',
#   '와기',
#   '고양이',
#   '느낌',
#   '아아',
#   '악',
#   'ㅜㅜㅜ',
#   '사랑',
#   '해요'],
#  ['와', '우대', '박'],
#  ['언니', '이세', '상', '사람', '아니죠', '아니', '사람', '아니죠', '요', '정이', '죠', 'ㅠㅠ'],
#  ['분', '순삭', '언니', '왤케', '기여', '워', '여'],
#  ['좋아요'],
#  ['으', '애', 'ㅠㅠ', '진진', '선물', '이다', '잘', '볼께요', '새', '랭햅', '내', '대'],
#  ['진진', '오늘', '은', '약간', '인어공주', '같아요', '아코', '예쁘다', 'ㅠ', 'ㅠ'],
#  ['열', '일', '하', '는', '선풍기'],
#  ['웜톤', '도', '쿨톤', '도', '왜케', 'ㄷ', 'ㅏ', '잘', '어울리셔요', 'ㅠㅠㅠㅠㅠㅠㅠㅠ'],
#  ['언니', '눈썹', '문신', '하신거에요'],
#  ['진진', '님', '해주시', '면', '진짜', '좋을것', '같아여', '..'],
#  ['와', '언니', '메이크업', '완전', '찰떡'],
#  ['센', '화장', '도', '잘', '어울리고', 'ㅜㅜ', '최고', '되', '신다'],
#  ['헥', '오랜', '만', '에', '아이라인', '그리셨', '네', '욤'],
#  ['무슨', '미국', '년대', '하이', '틴', '스타', '같다', '...', '너무', '예뻐요', 'ㅠㅠ'],
#  ['와', '보라색', '진짜', '잘', '어울려요'],
#  ['ㅠㅜㅜㅠ', '언니', '존예'],
#  ['피부', '커버', '진짜', '잘', '된다', '..'],
#  ['진짜', '이번', '메이크업', '너무', '이뻐요', 'ㅠㅠㅠㅠ'],
#  ['진진', '뭔들'],
#  ['병원', '원장', '님', '이랑', '인연', '무엇', '입', '니까', '친화력', '쩔어', 'ㅠ'],
#  ['저',
#   '포니',
#   '이펙트',
#   '립',
#   '틴트',
#   '엄청',
#   '좋은데',
#   '향',
#   '이',
#   '진짜',
#   '넘',
#   '별',
#   '루',
#   '예',
#   '욥'],
#  ['이번', '에', '아이라인', '그렸', '네', '욧', '아라', '그려도', '여신'],
#  ['미친', '미친', '대미', '친'],
#  ['언니', '만', '하루', '종일', '봤어요', 'ㅠㅠ'],
#  ['최애', '언니'],
#  ['아이라인'],
#  ['예쁘세요', 'ㅠㅠㅠ'],
#  ['너무', '이뻐', 'ㅠㅠ'],
#  ['언니', '인스타그램', '하세여'],
#  ['진진', '임', '밑', '트임', '하신건', '가요'],
#  ['천사', '같아요', '여신', '..'],
#  ['그냥', '옙', '허', '..', '그냥'],
#  ['언니', '입술', '도', '뚫어주세용'],
#  ['으윽', '기다렸어요', 'ㅠㅠ'],
#  ['항상', '봐도', '세상', '이쁜', '언니', '얌'],
#  ['진짜', '너무', '예뻐요'],
#  ['예뻐용', 'ㅎ', '오오오'],
#  ['왕', '아아'],
#  ['언니', '태닝', '왜', '해', '요', '궁금해서요']]
